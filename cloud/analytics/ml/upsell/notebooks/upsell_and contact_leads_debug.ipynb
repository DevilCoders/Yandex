# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from os.path import join as path_join
from clan_tools.data_adapters.YTAdapter import YTAdapter
from clan_tools.data_adapters.YQLAdapter import YQLAdapter
import spyt
import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark.sql.functions import col, lit
from pyspark.sql.window import Window
from clan_tools.utils.spark import SPARK_CONF_MEDIUM

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 250)
os.environ['NUMEXPR_MAX_THREADS'] = '32'

# %%
from clan_tools.secrets.Vault import Vault
Vault().get_secrets('sec-01fm06fw1zsqp08cxtyd247tm5')
yt_adapter = YTAdapter()

spark = spyt.connect(spark_conf_args=SPARK_CONF_MEDIUM)
spyt.info(spark)
# Out:
# 2022-01-28 11:27:59,052 - WARNING - spyt.conf - Your SPYT library has version 1.3.5 which is older than your cluster version 3.0.1-1.23.1+yandex. Some new features may not work as expected. Please update your cluster with spark-launch-yt utility
# 2022-01-28 11:28:23,976 - INFO - spyt.client - SPYT Cluster version: 3.0.1-1.23.1+yandex
# 2022-01-28 11:28:23,978 - INFO - spyt.client - SPYT library version: 1.3.5
#             <div>
#                 <p><b>SPYT</b></p>
#
#                 <p><a href="sas4-8133-node-hahn.sas.yp-c.yandex.net:27002">Master Web UI</a></p>
#                 <dl>
#                   <dt>Yt Cluster</dt>
#                     <dd><code>hahn.yt.yandex.net</code></dd>
#                   <dt>SPYT Cluster version</dt>
#                     <dd><code>3.0.1-1.23.1+yandex</code></dd>
#                   <dt>SPYT Library version</dt>
#                     <dd><code>1.3.5</code></dd>
#                 </dl>
#
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://jupyter-cloud-pavelvasilev.sas.yp-c.yandex.net:27002">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://sas4-8133-node-hahn.sas.yp-c.yandex.net:27001</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySpark for pavelvasilev</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
def max_by(colname_max, colname_by):
    return F.expr(f"Max_by(`{colname_max}`, `{colname_by}`)")

def min_by(colname_min, colname_by):
    return F.expr(f"Min_by(`{colname_min}`, `{colname_by}`)")

def min_where(colname_min, colname_where, value_where):
    return F.min(F.when(col(colname_where)==value_where, col(colname_min)))

def max_where(colname_max, colname_where, value_where):
    return F.max(F.when(col(colname_where)==value_where, col(colname_max)))

def nvl(colname, value_if_null):
    return F.when(col(colname).isNull(), value_if_null).otherwise(col(colname)).alias(colname)

def str_today():
    return datetime.now().strftime('%Y-%m-%d')

def add_days(n):
    return (datetime.now()+timedelta(days=n)).strftime('%Y-%m-%d')

# %%
crm_company_accs_path = '//home/cloud_analytics/import/crm/business_accounts/data'
dwh_bas_prod_path = '//home/cloud-dwh/data/prod/ods/billing/billing_accounts'
yc_cons_prod_path = '//home/cloud-dwh/data/prod/cdm/dm_yc_consumption'
crm_tag_prod_path = '//home/cloud-dwh/data/prod/cdm/dm_ba_crm_tags'

crm_calls_path = '//home/cloud-dwh/data/prod/raw/mysql/crm-cloud/cloud8_calls'
leads_cube_path = '//home/cloud_analytics/kulaga/leads_cube'
oppty_cube_path = '//home/cloud_analytics/kulaga/oppty_cube'
sales_cube_path = '//home/cloud_analytics/kulaga/acc_sales_ba_cube'

dwh_accs = (
    spark.read.yt(dwh_bas_prod_path)
    .select(
        'billing_account_id',
        'person_type',
        'state',
        'usage_status',
        'is_suspended_by_antifraud',
        'block_reason',
        F.to_date(F.to_timestamp('created_at')).alias('date_created')
    )
    .withColumn('tech_date', F.date_add('date_created', 45))
    .join(
        spark.read.yt(crm_tag_prod_path).select('billing_account_id', 'segment_current').distinct(),
        on='billing_account_id', how='left'
    )
    .cache()
)

dwh_accs.limit(10).toPandas()
# Out:
#      billing_account_id person_type      state usage_status  \
# 0  dn200bv4qsjb0fec9sbh  individual  suspended        trial
# 1  dn2013u8biata15k2fl0  individual  suspended        trial
# 2  dn201banbibsg37ihit9  individual  suspended        trial
# 3  dn201v2m3ae57drbp08q  individual  suspended         paid
# 4  dn202b0kplcdmrfjbvf8     company     active         paid
# 5  dn202bihmmoecv31i6bg  individual  suspended        trial
# 6  dn202nk7gs5smf1q71do  individual  suspended        trial
# 7  dn203incdkndainhl85s  individual  suspended        trial
# 8  dn2055uk17oict9rin1t  individual  suspended         paid
# 9  dn2056up18j1q6vhp0ee  individual  suspended        trial
#
#    is_suspended_by_antifraud   block_reason date_created   tech_date  \
# 0                      False  trial_expired   2020-04-26  2020-06-10
# 1                      False  trial_expired   2019-09-18  2019-11-02
# 2                      False  trial_expired   2020-09-22  2020-11-06
# 3                      False   unbound_card   2020-01-26  2020-03-11
# 4                      False           None   2019-04-15  2019-05-30
# 5                       True         manual   2021-02-20  2021-04-06
# 6                      False  trial_expired   2021-09-05  2021-10-20
# 7                       True      antifraud   2021-10-11  2021-11-25
# 8                       True         manual   2021-06-30  2021-08-14
# 9                      False  trial_expired   2021-01-04  2021-02-18
#
#   segment_current
# 0            Mass
# 1            Mass
# 2            Mass
# 3            Mass
# 4            Mass
# 5            Mass
# 6            Mass
# 7            Mass
# 8            Mass
# 9            Mass

# %%
crm_company_accs = (
    spark.read.yt(crm_company_accs_path)
    .select('billing_account_id')
    .distinct()
)

dwh_company_accs = (
    dwh_accs
    .filter(col('person_type').isin([
        'company',
        'kazakhstan_company',
        'switzerland_nonresident_company'
    ]))
    .select('billing_account_id')
    .distinct()
)

all_company_accs = (
    crm_company_accs
    .union(dwh_company_accs)
    .join(dwh_accs, on='billing_account_id', how='inner')
    .distinct()
    .filter(~col('block_reason').isin(['manual', 'mining']))
    .filter(col('usage_status')=='paid')
    .filter(col('is_suspended_by_antifraud')==False)
    .filter(~col('state').isin(['inactive', 'payment_not_confirmed', 'deleted']))
    .filter(col('segment_current')=='Mass')
)

tt = all_company_accs.toPandas()
tt
# Out:
#         billing_account_id person_type      state usage_status  \
# 0     dn25moooa0morhnir4fg  individual  suspended         paid
# 1     dn25v42i0vm2t99llf28     company  suspended         paid
# 2     dn29ol2kieog4otqb6uu     company     active         paid
# 3     dn2b9d01hsi21qbe6rf7     company     active         paid
# 4     dn2c096hiroj7nq99s54     company     active         paid
# ...                    ...         ...        ...          ...
# 2593  dn2ndffs3iinkru5s9eg     company     active         paid
# 2594  dn2qo3vl45ah8inoof3d     company     active         paid
# 2595  dn2qq8be5aggb6gs8ouu     company  suspended         paid
# 2596  dn2u2dojhsmqka305tgo     company     active         paid
# 2597  dn2uro3im9fi2a21gqtm  individual     active         paid
#
#       is_suspended_by_antifraud   block_reason date_created   tech_date  \
# 0                         False           debt   2019-10-04  2019-11-18
# 1                         False           debt   2019-07-22  2019-09-05
# 2                         False  trial_expired   2020-10-15  2020-11-29
# 3                         False  trial_expired   2020-01-10  2020-02-24
# 4                         False  trial_expired   2021-11-10  2021-12-25
# ...                         ...            ...          ...         ...
# 2593                      False  trial_expired   2020-12-04  2021-01-18
# 2594                      False  trial_expired   2021-04-26  2021-06-10
# 2595                      False           debt   2021-03-02  2021-04-16
# 2596                      False  trial_expired   2020-10-28  2020-12-12
# 2597                      False  trial_expired   2021-02-19  2021-04-05
#
#      segment_current
# 0               Mass
# 1               Mass
# 2               Mass
# 3               Mass
# 4               Mass
# ...              ...
# 2593            Mass
# 2594            Mass
# 2595            Mass
# 2596            Mass
# 2597            Mass
#
# [2598 rows x 9 columns]

# %%
pd_accs = all_company_accs.select('billing_account_id').distinct().toPandas()
pd_accs['key'] = '0'

pd_dates = pd.Series(pd.date_range(add_days(-14), add_days(-1))).dt.strftime('%Y-%m-%d')
pd_dates = pd.DataFrame(pd_dates, columns=['billing_record_msk_date'])
pd_dates['key'] = '0'

pd_accs_dates = pd_accs.merge(pd_dates, on='key', how='outer')
pd_accs_dates = pd_accs_dates[['billing_account_id', 'billing_record_msk_date']]
spdf_accs_dates = spark.createDataFrame(pd_accs_dates)

ba_cons = (
    spark.read.yt(yc_cons_prod_path)
    .filter(col('billing_record_msk_date')<str_today())
    .filter(col('billing_record_msk_date')>=add_days(-14))
    .groupby('billing_account_id', 'billing_record_msk_date')
    .agg(
        F.sum('billing_record_real_consumption_rub').alias('billing_record_real_consumption_rub'),
        F.sum((col('sku_service_name')!='cloud_ai').astype('decimal')).alias('no_ml_cons'),
    )
    .join(spdf_accs_dates, on=['billing_account_id', 'billing_record_msk_date'], how='right')
    .select(
        'billing_account_id',
        'billing_record_msk_date',
        nvl('billing_record_real_consumption_rub', 0),
        nvl('no_ml_cons', 0)
    )
    .groupby('billing_account_id')
    .agg(
        (F.sum('no_ml_cons')>0).astype('decimal').alias('no_ml_cons'),
        F.greatest(F.mean('billing_record_real_consumption_rub'), lit(0.01)).alias('avg_consumption'),
        F.greatest(F.stddev('billing_record_real_consumption_rub'), lit(0.01)).alias('std_consumption')
    )
    .withColumn('is_plateau', (1.000*col('std_consumption')/col('avg_consumption')<=0.1).astype('decimal'))
    .select('billing_account_id', 'no_ml_cons', 'is_plateau')
    .cache()
)

ba_cons.limit(10).toPandas()
# Out:
#      billing_account_id no_ml_cons is_plateau
# 0  dn2s4hknn3l7r8hd5pih          1          1
# 1  dn2p5qehd37rvi8sh1o5          1          1
# 2  dn245t02o8rt6bh9emuv          1          1
# 3  dn28nrfdokovbhnnql2r          0          0
# 4  dn2iue3d0f30l7sihh0k          1          1
# 5  dn2nu92425o7v0jdo8os          0          0
# 6  dn213jc4mq90jicgolql          1          0
# 7  dn29qak94or9p8fktu2p          0          0
# 8  dn2md3doqn6om4jl01i6          0          0
# 9  dn27i8cfpo42acgn4qgr          0          0

# %%
current_staff = (
    spark.read.yt('//home/cloud-dwh/data/prod/ods/staff/persons')
    .join(
        spark.read.yt('//home/cloud-dwh/data/prod/ods/staff/PII/persons'),
        on='staff_user_id', how='left'
    )
    .filter(col('department_id')==10701)
    .filter(col('official_is_dismissed')==False)
    .select('staff_user_login')
)

stf_list = current_staff.toPandas()['staff_user_login'].tolist()

date_of_last_lead = (
    spark.read.yt(leads_cube_path)
    .filter(col('lead_source')=='upsell')
    .filter(~col('billing_account_id').isNull())
    .filter(
        col('lead_source_description').isin([
            "Upsell", "upsell", "contact more then 70 days",
            "Consumed more than 40k over last 30 days",
        ]) |
        (F.substring('lead_source_description', 0, 19)=='Potential candidate')
    )
    .withColumn('user_name', F.when(col('user_name').isin(stf_list), col('user_name')))
    .withColumn('user_name', F.last('user_name', ignorenulls=True).over(
        Window
        .partitionBy('billing_account_id')
        .orderBy('date_entered')
        .rowsBetween(Window.unboundedPreceding, Window.currentRow)
    ))
    .groupby('billing_account_id')
    .agg(
        F.max(F.to_date('date_entered')).alias('last_lead_date'),
        max_by('user_name', 'date_entered').alias('last_actual_manager')
    )
)

date_of_last_lead.limit(10).toPandas()
# Out:
#      billing_account_id last_lead_date last_actual_manager
# 0  dn20019hmsotshd3h00m     2021-08-21          moiseeva-m
# 1  dn2002tb4so3qiuv5pug     2020-12-16          moiseeva-m
# 2  dn2003veg3dhst66v202     2021-05-30          gingerkote
# 3  dn2005cbd7mvmnqq9umb     2021-10-12                None
# 4  dn2008o4f5a257jlva1j     2021-04-08          gingerkote
# 5  dn20092p4c9ad4t9ut98     2020-08-01                None
# 6  dn200aim29ftg1mvs525     2021-10-12                None
# 7  dn200gfvhov6bb06vic1     2021-10-12          moiseeva-m
# 8  dn200jvrdepehoosl1g6     2021-06-11                None
# 9  dn200kfe3vgf6n6aq6tk     2020-02-05          gingerkote

# %%
spdf_leads = (
    spark.read.yt(leads_cube_path)
    .select(col('billing_account_id').alias('leads_ba_id'), col('lead_id').alias('parent_id'))
    .distinct()
)

spdf_oppty = (
    spark.read.yt(oppty_cube_path)
    .select(col('ba_id').alias('oppty_ba_id'), col('opp_id').alias('parent_id'))
    .distinct()
)

spdf_sales = (
    spark.read.yt(sales_cube_path)
    .select(col('ba_id').alias('sales_ba_id'), col('acc_id').alias('parent_id'))
    .distinct()
)

date_of_last_held_call = (
    spark.read.yt(crm_calls_path).alias('calls')
    .filter(col('deleted')==0)
    .filter(col('status')=='Held')
    .filter(col('parent_type').isin(['Accounts', 'Leads', 'Opportunities']))
    .join(spdf_leads, on='parent_id', how='left')
    .join(spdf_oppty, on='parent_id', how='left')
    .join(spdf_sales, on='parent_id', how='left')
    .select(
        'id',
        'parent_type',
        F.to_date(F.to_timestamp(col('date_start')/1000000)).alias('call_date'),
        'status',
        'leads_ba_id',
        'oppty_ba_id',
        'sales_ba_id',
        F.coalesce('leads_ba_id', 'oppty_ba_id', 'sales_ba_id').alias('billing_account_id')
    )
    .distinct()
    .filter(~col('billing_account_id').isNull())
    .groupby('billing_account_id')
    .agg(F.max('call_date').alias('last_held_call_date'))
    .cache()
)

print(date_of_last_held_call.count())
date_of_last_held_call.limit(10).toPandas()
# Out:
# 23021
#      billing_account_id last_held_call_date
# 0  dn24qbie9257ikmo66gm          2019-07-08
# 1  dn2tn03v0unji215ltoj          2020-11-27
# 2  dn2083nldm21nm6jcojo          2019-04-18
# 3  dn220sd1g2focm6o31oq          2019-04-22
# 4  dn2tmnooc200usdtgo0v          2021-07-09
# 5  dn26hf5vrjbvtrjso7v5          2019-04-18
# 6  dn28babda192gsq6tbru          2021-07-20
# 7  dn28t8k4jhf8ag71c2c0          2019-04-18
# 8  dn25juk3qbihksh29dgm          2021-10-21
# 9  dn2plcfroihbg6cs71mf          2022-01-21

# %%
person_data_path = '//home/cloud_analytics/import/crm/leads/contact_info'

contact_info = spark.read.yt(person_data_path)

contact_info.toPandas()
# Out:
#           billing_account_id                  display_name  \
# 0       dn200017upuhslibj3i4    Евгения Леонидовна Ульдина
# 1       dn200028bphsvjlgqvrj    Вячеслав Романович Машичев
# 2       dn200044hmorna15pjap      Vadim Andreevich Kiselev
# 3       dn200086ohv8mj7r444s          Илья Валерьевич Смит
# 4       dn2000jkhome4jed828a      Радик Фаритович Мингажев
# ...                      ...                           ...
# 273500  dn2vvv5v29n4v39nk92c  Варвара Дмитриевна Ковригина
# 273501  dn2vvv9h240ugjstsgem      Андрей Дмитриевич Иванов
# 273502  dn2vvvhdfj02lamfm70d          Петр Иванович Иванов
# 273503  dn2vvvsam1kcabhqkli0       Михаил Владимирович Бак
# 273504  dn2vvvt7lgrlh6nt602q     Руслан Викторович Жеребин
#
#                              email first_name  last_name         phone
# 0            Uldina0vrn7@yandex.ru    Евгения    Ульдина   79510297261
# 1         Mashichev0n1ax@yandex.ru   Вячеслав    Машичев   79089712526
# 2            fortyfack76@yandex.ru      Vadim    Kiselev   79772886560
# 3             smit.illya@yandex.ru       Илья       Смит   79641389015
# 4       radick.mingazhev@yandex.ru      Радик   Мингажев   79914702594
# ...                            ...        ...        ...           ...
# 273500         Onlimusik@yandex.ru    Варвара  Ковригина   79217578285
# 273501           m4rrras@yandex.ru     Андрей     Иванов   79610230500
# 273502       sdfhdfshsdh@yandex.ru       Петр     Иванов   79677105568
# 273503        michaelbak@yandex.ru     Михаил        Бак   79991216496
# 273504     Zherebin0pgf9@yandex.ru     Руслан    Жеребин  447405889960
#
# [273505 rows x 6 columns]

# %%
spdf_mdb = (
    spark.read.yt(yc_cons_prod_path)
    .filter(col('sku_service_name')=='mdb')
    .groupby('billing_account_id')
    .agg((F.sum('billing_record_cost_rub')>0).astype('decimal').alias('use_mdb'))
)

spdf_mdb.limit(10).toPandas()
# Out:
#      billing_account_id use_mdb
# 0  dn2cqs65j4ko95ndmnae       1
# 1  dn2hnuh5ijte2755t899       1
# 2  dn2ncin3k2vaju3m0a8t       1
# 3  dn2si0vorjs7irnc83p9       1
# 4  dn204o23s4l9jajhq6v3       1
# 5  dn26r5fg7edsoaki2epq       1
# 6  dn2j34hc2cu4p8mvd2bn       1
# 7  dn2d76mm2l18hnp7n14a       1
# 8  dn2decccj6g8mruq939l       1
# 9  dn2g9hioevncb3ot3e5a       1

# %%
spdf_db_on_vm = (
    spark.read.yt('//home/cloud_analytics/import/network-logs/db-on-vm/data')
    .filter(col('billing_account_id')!='')
    .groupby('billing_account_id')
    .agg(F.array_join(F.collect_set('db'), ', ').alias('db_on_vm'))
)

spdf_db_on_vm.limit(10).toPandas()
# Out:
#      billing_account_id                              db_on_vm
# 0  dn200017upuhslibj3i4         mysql, postgresql, clickhouse
# 1  dn200028bphsvjlgqvrj         mysql, postgresql, clickhouse
# 2  dn200086ohv8mj7r444s  mysql, redis, postgresql, clickhouse
# 3  dn2000mso2sk0dqp60c6         mysql, postgresql, clickhouse
# 4  dn20019hmsotshd3h00m  mysql, redis, postgresql, clickhouse
# 5  dn2002dnc3fh79gh2s32                            postgresql
# 6  dn2002uqiske4gmnm4t8         mysql, postgresql, clickhouse
# 7  dn2003crp0li9o8npa7m  mysql, redis, postgresql, clickhouse
# 8  dn2003cu9hr6ljmf9nda  mysql, redis, postgresql, clickhouse
# 9  dn2003g4ddtk99obdaat         mysql, postgresql, clickhouse

# %%
spdf_main = (
    all_company_accs
    .join(ba_cons, on='billing_account_id', how='left')
    .join(date_of_last_lead, on='billing_account_id', how='left')
    .join(date_of_last_held_call, on='billing_account_id', how='left')
    .join(contact_info, on='billing_account_id', how='left')
    .join(spdf_mdb, on='billing_account_id', how='left')
    .join(spdf_db_on_vm, on='billing_account_id', how='left')
    .withColumn('last_lead_date', F.coalesce('last_lead_date', 'tech_date'))
    .withColumn('last_held_call_date', F.coalesce('last_held_call_date', 'tech_date'))
    .select(
        '*',
        F.datediff(lit(str_today()), col('last_lead_date')).alias('last_lead_days_ago'),
        F.datediff(lit(str_today()), col('last_held_call_date')).alias('last_call_days_ago'),
    )
    .withColumn('use_mdb', nvl('use_mdb', 0))
    .withColumn(
        'description',
        F.when(
            (col('use_mdb')==0) & col('db_on_vm').isNotNull(),
            F.concat(lit('Client Use BD on VM: '), 'db_on_vm')
        ).otherwise(lit(''))
    )
    .cache()
)

tt = spdf_main.toPandas()
tt
# Out:
#         billing_account_id person_type      state usage_status  \
# 0     dn25moooa0morhnir4fg  individual  suspended         paid
# 1     dn25v42i0vm2t99llf28     company  suspended         paid
# 2     dn29ol2kieog4otqb6uu     company     active         paid
# 3     dn2b9d01hsi21qbe6rf7     company     active         paid
# 4     dn2c096hiroj7nq99s54     company     active         paid
# ...                    ...         ...        ...          ...
# 2593  dn2ndffs3iinkru5s9eg     company     active         paid
# 2594  dn2qo3vl45ah8inoof3d     company     active         paid
# 2595  dn2qq8be5aggb6gs8ouu     company  suspended         paid
# 2596  dn2u2dojhsmqka305tgo     company     active         paid
# 2597  dn2uro3im9fi2a21gqtm  individual     active         paid
#
#       is_suspended_by_antifraud   block_reason date_created   tech_date  \
# 0                         False           debt   2019-10-04  2019-11-18
# 1                         False           debt   2019-07-22  2019-09-05
# 2                         False  trial_expired   2020-10-15  2020-11-29
# 3                         False  trial_expired   2020-01-10  2020-02-24
# 4                         False  trial_expired   2021-11-10  2021-12-25
# ...                         ...            ...          ...         ...
# 2593                      False  trial_expired   2020-12-04  2021-01-18
# 2594                      False  trial_expired   2021-04-26  2021-06-10
# 2595                      False           debt   2021-03-02  2021-04-16
# 2596                      False  trial_expired   2020-10-28  2020-12-12
# 2597                      False  trial_expired   2021-02-19  2021-04-05
#
#      segment_current no_ml_cons is_plateau last_lead_date last_actual_manager  \
# 0               Mass          0          0     2020-02-03          gingerkote
# 1               Mass          0          0     2021-09-06          gingerkote
# 2               Mass          1          1     2021-05-16       nikitagrekhov
# 3               Mass          1          0     2020-11-15          gingerkote
# 4               Mass          1          1     2021-12-25                None
# ...              ...        ...        ...            ...                 ...
# 2593            Mass          0          0     2021-01-18                None
# 2594            Mass          0          0     2021-06-10                None
# 2595            Mass          0          0     2021-11-14          moiseeva-m
# 2596            Mass          0          0     2021-02-02                None
# 2597            Mass          1          0     2022-01-14                None
#
#      last_held_call_date                                       display_name  \
# 0             2019-10-28                                          Mds __ __
# 1             2019-09-05                                    ООО "Волга-Тур"
# 2             2021-10-11   Общество с ограниченной ответственностью «Ю-СРМ»
# 3             2020-11-20                                          ООО Хорум
# 4             2022-01-21  Общество с ограниченной ответсвенностью "Образ...
# ...                  ...                                                ...
# 2593          2021-01-18  Индивидуальный предприниматель Кочнева Анастас...
# 2594          2021-06-10  Общество с ограниченной ответственностью "Техн...
# 2595          2021-11-24  Общество с ограниченной ответственностью «Прес...
# 2596          2021-06-10                         ИП Ищенко Олег Анатольевич
# 2597          2021-03-16                          Максим Алексеевич Каширин
#
#                        email first_name                        last_name  \
# 0           mshare@yandex.ru        Mds                               __
# 1       levina@alyanstour.ru       None                        Волга-Тур
# 2            tcapb@yandex.ru       None                      ООО «Ю-СРМ»
# 3            admin@horum.dev       None                            Хорум
# 4         alex@enjoy-camp.ru       None  ООО "Образовательные инновации"
# ...                      ...        ...                              ...
# 2593      check@rukodelov.ru       None     ИП Кочнева Анастасия Юрьевна
# 2594              piv@cce.su       None                       ООО "ТУиС"
# 2595  KardosRiteil@yandex.ru       None                  ООО "Пресса ру"
# 2596    cloudbaser@yandex.ru       None       ИП Ищенко Олег Анатольевич
# 2597      kashimax@yandex.ru     Максим                          Каширин
#
#             phone use_mdb                              db_on_vm  \
# 0     79165403339       0  mysql, redis, postgresql, clickhouse
# 1     79873955682       0  mysql, redis, postgresql, clickhouse
# 2     79112474576       0                                  None
# 3     79217485037       0  mysql, redis, postgresql, clickhouse
# 4     79164447737       0  mysql, redis, postgresql, clickhouse
# ...           ...     ...                                   ...
# 2593  79165073868       0                                  None
# 2594  79138298719       0                                  None
# 2595  79268005301       0                                  None
# 2596  79175243178       0                                  None
# 2597  79031504181       0  mysql, redis, postgresql, clickhouse
#
#       last_lead_days_ago  last_call_days_ago  \
# 0                    725                 823
# 1                    144                 876
# 2                    257                 109
# 3                    439                 434
# 4                     34                   7
# ...                  ...                 ...
# 2593                 375                 375
# 2594                 232                 232
# 2595                  75                  65
# 2596                 360                 232
# 2597                  14                 318
#
#                                             description
# 0     Client Use BD on VM: mysql, redis, postgresql,...
# 1     Client Use BD on VM: mysql, redis, postgresql,...
# 2
# 3     Client Use BD on VM: mysql, redis, postgresql,...
# 4     Client Use BD on VM: mysql, redis, postgresql,...
# ...                                                 ...
# 2593
# 2594
# 2595
# 2596
# 2597  Client Use BD on VM: mysql, redis, postgresql,...
#
# [2598 rows x 24 columns]

# %%
upsell_leads_temp = (
    spdf_main
    .filter(col('is_plateau')==1)
    .filter(col('no_ml_cons')==1)
    .filter(col('last_lead_days_ago')>70)
    .filter(col('last_call_days_ago')>30)
    .sort(nvl('last_lead_days_ago', 1000).desc())
    .limit(40)
)

curr_timestamp = int(datetime.today().timestamp())
upsell_leads = (
    upsell_leads_temp
    .select(
        lit(curr_timestamp).alias('Timestamp'),
        lit(None).astype(T.StringType()).alias('CRM_Lead_ID'),
        F.concat(lit('["'), 'billing_account_id', lit('"]')).alias('Billing_account_id'),
        lit(None).astype(T.StringType()).alias('Status'),
        col('description').alias('Description'),
        F.coalesce('last_actual_manager', lit('admin')).alias('Assigned_to'),
        col('first_name').alias('First_name'),
        col('last_name').alias('Last_name'),
        col('phone').alias('Phone_1'),
        lit(None).astype(T.StringType()).alias('Phone_2'),
        col('email').alias('Email'),
        lit('upsell').alias('Lead_Source'),
        lit('upsell').alias('Lead_Source_Description'),
        lit(None).astype(T.StringType()).alias('Callback_date'),
        lit(None).astype(T.StringType()).alias('Last_communication_date'),
        lit(None).astype(T.StringType()).alias('Promocode'),
        lit(None).astype(T.StringType()).alias('Promocode_sum'),
        lit(None).astype(T.StringType()).alias('Notes'),
        lit(None).astype(T.StringType()).alias('Dimensions'),
        lit(None).astype(T.StringType()).alias('Tags'),
        lit('').alias('Timezone'),
        col('display_name').alias('Account_name')
    )
)

upsell_leads.toPandas()
# Out:
#      Timestamp CRM_Lead_ID        Billing_account_id Status  \
# 0   1643358877        None  ["dn2muo28g4her430cks9"]   None
# 1   1643358877        None  ["dn2t3ceqst6b6ut9teel"]   None
# 2   1643358877        None  ["dn2onlje8gci28lvburl"]   None
# 3   1643358877        None  ["dn2kth2vqfuvcq3ra2l4"]   None
# 4   1643358877        None  ["dn24u79dcdqah89752i4"]   None
# 5   1643358877        None  ["dn2k0668h8mgpa9rf3u9"]   None
# 6   1643358877        None  ["dn2aveanh9rephqmpnah"]   None
# 7   1643358877        None  ["dn2flcq7v1cqejo2aitl"]   None
# 8   1643358877        None  ["dn2qf0atlki5khrj4462"]   None
# 9   1643358877        None  ["dn2iuvntil6a189jcfrp"]   None
# 10  1643358877        None  ["dn2ichgsbadb9da2pa8o"]   None
# 11  1643358877        None  ["dn2rabss5dgimhg7q08s"]   None
# 12  1643358877        None  ["dn2gegl8deqrdd9h9icd"]   None
# 13  1643358877        None  ["dn27c256fgpb7bsojum8"]   None
# 14  1643358877        None  ["dn2mvjevs4nu884d6b35"]   None
# 15  1643358877        None  ["dn2pacooaf46504jjad9"]   None
# 16  1643358877        None  ["dn2fo5j0782u1a5tvn5r"]   None
# 17  1643358877        None  ["dn2drjveqmhioapm3dge"]   None
# 18  1643358877        None  ["dn2csht8nnf7rnjsp1p2"]   None
# 19  1643358877        None  ["dn2o8mbegea1e60nsmjk"]   None
# 20  1643358877        None  ["dn2c2sjmev48ea6ke3js"]   None
# 21  1643358877        None  ["dn2m8pjr6p58fa52kti8"]   None
# 22  1643358877        None  ["dn2sulv4049if0u9qfnb"]   None
# 23  1643358877        None  ["dn2uhqkhigsoh8nobq5r"]   None
# 24  1643358877        None  ["dn20ch4d1q4u66m44gla"]   None
# 25  1643358877        None  ["dn2n43tj1ma06mav7k5i"]   None
# 26  1643358877        None  ["dn2vhvae82j73c5b2vfj"]   None
# 27  1643358877        None  ["dn2uficp9be4k91go0hm"]   None
# 28  1643358877        None  ["dn2hbkupbtu29cb6mmnt"]   None
# 29  1643358877        None  ["dn2dvtik3v6j43kc5608"]   None
# 30  1643358877        None  ["dn24n0nqlkr3l00hlbts"]   None
# 31  1643358877        None  ["dn2uo0qs0ec3snmfbf25"]   None
# 32  1643358877        None  ["dn2bj448mflaoveruaj3"]   None
# 33  1643358877        None  ["dn2qh2b1k30rke57t8f4"]   None
# 34  1643358877        None  ["dn2tm3a676dikd5i3rna"]   None
# 35  1643358877        None  ["dn283a0jhjra7f9l7u2d"]   None
# 36  1643358877        None  ["dn2cg68303n3p2n949cs"]   None
# 37  1643358877        None  ["dn2ba0rnj76g4k7lsrpu"]   None
# 38  1643358877        None  ["dn21fs6f5tvg1f7l5h46"]   None
# 39  1643358877        None  ["dn2578ott4uhs6gdva9d"]   None
#
#                                           Description    Assigned_to  \
# 0   Client Use BD on VM: mysql, redis, postgresql,...          admin
# 1   Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 2   Client Use BD on VM: mysql, redis, postgresql,...         dmtroe
# 3                                                         gingerkote
# 4   Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 5   Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 6   Client Use BD on VM: mysql, redis, postgresql,...  nikitagrekhov
# 7                                                         gingerkote
# 8                                                         gingerkote
# 9   Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 10                                                             admin
# 11  Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 12                                                        gingerkote
# 13                                                             admin
# 14  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 15  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 16                                                     nikitagrekhov
# 17  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 18                                                             admin
# 19                                                        gingerkote
# 20                                                             admin
# 21  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 22  Client Use BD on VM: mysql, redis, postgresql,...          admin
# 23                                                             admin
# 24                                                     nikitagrekhov
# 25  Client Use BD on VM: mysql, redis, postgresql,...          admin
# 26  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 27                                                        gingerkote
# 28  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 29  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 30  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 31                                                        moiseeva-m
# 32  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 33  Client Use BD on VM: mysql, redis, postgresql,...  nikitagrekhov
# 34  Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 35                                                       sosnovskikh
# 36                                                             admin
# 37  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 38  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 39                                                        moiseeva-m
#
#    First_name                                          Last_name  \
# 0        Иван                                           Варанкин
# 1      Максим                                             Волков
# 2     Алексей                                          Прибытков
# 3      Руслан                                          Сеитханов
# 4     Евгений                                          Головинов
# 5      Максим                                             Лаптев
# 6   Александр                                          Миловидов
# 7       Захар                                            Давыдов
# 8        None                       ИП Попков Альберт Михайлович
# 9      Сергей                                            Тишинов
# 10     Сергей                                           Савельев
# 11    Дмитрий                                           Петренко
# 12   Владимир                                            Самойло
# 13    Евгений                                            Неверов
# 14     Михаил                                            Матвеев
# 15    Евгений                                       Мирошниченко
# 16       Юсиф                                            Насирли
# 17      Денис                                            Голиков
# 18       None                       AL FAKHER FACTORY Sp. z o.o.
# 19    Дмитрий                                          Козубский
# 20       Нина                                             Сырова
# 21      Ольга                                            Акинина
# 22  Alexander                                         Sarachakov
# 23       None                                    Лава Технолоджи
# 24       None                       ИП "Петров Сергей Сергеевич"
# 25       None                                          ООО "МИР"
# 26       None                                          АО "ФАСП"
# 27       None                         ООО "Диспетчер ЖКХ онлайн"
# 28       None                                               ДЕКА
# 29       None                                      ООО "ЭКО-САД"
# 30       None                                       ООО "ФРЕГАТ"
# 31       None                                      ООО "Фалькон"
# 32       None                         ООО «Лобненский Водоканал»
# 33       None                           ООО "Иностудио Солюшинс"
# 34       None                                 ООО «Ю-Менеджмент»
# 35       None  ИНДИВИДУАЛЬНЫЙ ПРЕДПРИНИМАТЕЛЬ ЦЫГАНКОВ АЛЕКСА...
# 36       None                          Infortrend Technology Inc
# 37       None                                    ООО "Альтеркей"
# 38       None                                      ООО "Комплай"
# 39       None                                     ИП Романов И.В
#
#                  Phone_1 Phone_2                          Email Lead_Source  \
# 0            79112207276    None           varankin54@yandex.ru      upsell
# 1            79106631052    None              marahal@yandex.ru      upsell
# 2            79276126473    None             ladavtor@yandex.ru      upsell
# 3            77016438757    None  r.seitkhanov@solo-interier.kz      upsell
# 4            79268125031    None          evgeny@golovinov.info      upsell
# 5            79686381277    None     maxim.laptev2014@yandex.ru      upsell
# 6            79169534164    None                 manowar@aha.ru      upsell
# 7           447455190769    None          davydov@studiodart.eu      upsell
# 8            79255458055    None         albertpopkov@yandex.ru      upsell
# 9            79168054161    None            tishinovs@gmail.com      upsell
# 10           79281853869    None    absolut-avto61.ru@yandex.ru      upsell
# 11           79024485580    None           d.petr3nko@yandex.ru      upsell
# 12           79263515380    None              Nadmozg@yandex.ru      upsell
# 13           79246081977    None               info@jetlearn.io      upsell
# 14           79202948046    None              bilanz2@yandex.ru      upsell
# 15           79222954511    None                john@i-mati.org      upsell
# 16           79053384880    None          pro.nasirli@yandex.ru      upsell
# 17           79167982218    None         Native-Faalh@yandex.ru      upsell
# 18          971565267775    None     digitalalfakher@yandex.com      upsell
# 19           79539105129    None              kozubsky@inbox.ru      upsell
# 20           79122718300    None            mobbuhasb@yandex.ru      upsell
# 21           79226828389    None               info@meinstil.ru      upsell
# 22           79659993494    None     alekssarachakov@yandex.com      upsell
# 23           79052220085    None          lavatop2020@yandex.ru      upsell
# 24           79261408252    None            sergey@goodit.works      upsell
# 25           74997556298    None           i.toropov@machaon.ru      upsell
# 26  84956412413,доб.3030    None                    fin@fasp.ru      upsell
# 27           79606269147    None              gkh.onl@yandex.ru      upsell
# 28           79178695712    None         infrastructure@deck.lc      upsell
# 29           79603775564    None                info@sreda.guru      upsell
# 30           79021690095    None               alex.s@votak.org      upsell
# 31           78452651650    None    buhgalter@falcon-saratov.ru      upsell
# 32           79067664966    None           lobnyavoda@yandex.ru      upsell
# 33           79185269815    None   inostudio.ya.cloud@yandex.ru      upsell
# 34           79090796815    None               umngmt@yandex.ru      upsell
# 35           79899512077    None            pistonsky@yandex.ru      upsell
# 36          886222260126    None       Roson.lee@infortrend.com      upsell
# 37           79219350999    None               tmex20@yandex.ru      upsell
# 38           79169681554    None      sergei.saiganov@comply.ru      upsell
# 39           79048922470    None            romanov@tehnocam.ru      upsell
#
#    Lead_Source_Description Callback_date Last_communication_date Promocode  \
# 0                   upsell          None                    None      None
# 1                   upsell          None                    None      None
# 2                   upsell          None                    None      None
# 3                   upsell          None                    None      None
# 4                   upsell          None                    None      None
# 5                   upsell          None                    None      None
# 6                   upsell          None                    None      None
# 7                   upsell          None                    None      None
# 8                   upsell          None                    None      None
# 9                   upsell          None                    None      None
# 10                  upsell          None                    None      None
# 11                  upsell          None                    None      None
# 12                  upsell          None                    None      None
# 13                  upsell          None                    None      None
# 14                  upsell          None                    None      None
# 15                  upsell          None                    None      None
# 16                  upsell          None                    None      None
# 17                  upsell          None                    None      None
# 18                  upsell          None                    None      None
# 19                  upsell          None                    None      None
# 20                  upsell          None                    None      None
# 21                  upsell          None                    None      None
# 22                  upsell          None                    None      None
# 23                  upsell          None                    None      None
# 24                  upsell          None                    None      None
# 25                  upsell          None                    None      None
# 26                  upsell          None                    None      None
# 27                  upsell          None                    None      None
# 28                  upsell          None                    None      None
# 29                  upsell          None                    None      None
# 30                  upsell          None                    None      None
# 31                  upsell          None                    None      None
# 32                  upsell          None                    None      None
# 33                  upsell          None                    None      None
# 34                  upsell          None                    None      None
# 35                  upsell          None                    None      None
# 36                  upsell          None                    None      None
# 37                  upsell          None                    None      None
# 38                  upsell          None                    None      None
# 39                  upsell          None                    None      None
#
#    Promocode_sum Notes Dimensions  Tags Timezone  \
# 0           None  None       None  None
# 1           None  None       None  None
# 2           None  None       None  None
# 3           None  None       None  None
# 4           None  None       None  None
# 5           None  None       None  None
# 6           None  None       None  None
# 7           None  None       None  None
# 8           None  None       None  None
# 9           None  None       None  None
# 10          None  None       None  None
# 11          None  None       None  None
# 12          None  None       None  None
# 13          None  None       None  None
# 14          None  None       None  None
# 15          None  None       None  None
# 16          None  None       None  None
# 17          None  None       None  None
# 18          None  None       None  None
# 19          None  None       None  None
# 20          None  None       None  None
# 21          None  None       None  None
# 22          None  None       None  None
# 23          None  None       None  None
# 24          None  None       None  None
# 25          None  None       None  None
# 26          None  None       None  None
# 27          None  None       None  None
# 28          None  None       None  None
# 29          None  None       None  None
# 30          None  None       None  None
# 31          None  None       None  None
# 32          None  None       None  None
# 33          None  None       None  None
# 34          None  None       None  None
# 35          None  None       None  None
# 36          None  None       None  None
# 37          None  None       None  None
# 38          None  None       None  None
# 39          None  None       None  None
#
#                                          Account_name
# 0                         Иван Александрович Варанкин
# 1                             Максим Леондович Волков
# 2                         Алексей Андреевич Прибытков
# 3                        Руслан Сейтканович Сеитханов
# 4                        Евгений Эдуардович Головинов
# 5                         Максим Александрович Лаптев
# 6                      Александр Николаевич Миловидов
# 7                             Захар Андреевич Давыдов
# 8                        ИП Попков Альберт Михайлович
# 9                          Сергей Григорьевич Тишинов
# 10                      Сергей Александрович Савельев
# 11                         Дмитрий Сергеевич Петренко
# 12                          Владимир Петрович Самойло
# 13                         Евгений Евгеньевич Неверов
# 14                           Михаил Сергеевич Матвеев
# 15                     Евгений Сергеевич Мирошниченко
# 16                          Юсиф Ибрагим оглы Насирли
# 17                           Денис Николаевич Голиков
# 18                       AL FAKHER FACTORY Sp. z o.o.
# 19                    Дмитрий Владиславович Козубский
# 20                               Нина Ивановна Сырова
# 21                            Ольга Андреевна Акинина
# 22                    Alexander Evgenevich Sarachakov
# 23                              ООО "Лава Технолоджи"
# 24                       ИП "Петров Сергей Сергеевич"
# 25     ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МИР"
# 26  Акционерное общество "Финансовое Агентство по ...
# 27                         ООО "Диспетчер ЖКХ онлайн"
# 28                                         ООО «ДЕКА»
# 29  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКО-...
# 30  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФРЕГАТ"
# 31                                      ООО "Фалькон"
# 32  Общество с ограниченной ответственностью «Лобн...
# 33  Общество с ограниченной ответственностью "Инос...
# 34  Общество с ограниченной ответственностью «Ю-Ме...
# 35  ИНДИВИДУАЛЬНЫЙ ПРЕДПРИНИМАТЕЛЬ ЦЫГАНКОВ АЛЕКСА...
# 36                          Infortrend Technology Inc
# 37  Общество с ограниченной ответственностью "Альт...
# 38  Общество с ограниченной ответственностью "Комп...
# 39  Индивидуальный предприниматель Романов Игорь В...

# %%
contact_more_than_70_days = (
    spdf_main
    .join(upsell_leads_temp, on='billing_account_id', how='leftanti')
    .filter(col('last_held_call_date').isNotNull())
    .filter(col('last_lead_days_ago')>70)
    .filter(col('last_call_days_ago')>70)
    .sort(nvl('last_call_days_ago', 1000).desc())
    .limit(40)
    .select(
        lit(curr_timestamp).alias('Timestamp'),
        lit(None).astype(T.StringType()).alias('CRM_Lead_ID'),
        F.concat(lit('["'), 'billing_account_id', lit('"]')).alias('Billing_account_id'),
        lit(None).astype(T.StringType()).alias('Status'),
        col('description').alias('Description'),
        F.coalesce('last_actual_manager', lit('admin')).alias('Assigned_to'),
        col('first_name').alias('First_name'),
        col('last_name').alias('Last_name'),
        col('phone').alias('Phone_1'),
        lit(None).astype(T.StringType()).alias('Phone_2'),
        col('email').alias('Email'),
        lit('upsell').alias('Lead_Source'),
        lit('contact more then 70 days').alias('Lead_Source_Description'),
        lit(None).astype(T.StringType()).alias('Callback_date'),
        lit(None).astype(T.StringType()).alias('Last_communication_date'),
        lit(None).astype(T.StringType()).alias('Promocode'),
        lit(None).astype(T.StringType()).alias('Promocode_sum'),
        lit(None).astype(T.StringType()).alias('Notes'),
        lit(None).astype(T.StringType()).alias('Dimensions'),
        lit(None).astype(T.StringType()).alias('Tags'),
        lit('').alias('Timezone'),
        col('display_name').alias('Account_name')
    )
)

print(contact_more_than_70_days.count())

contact_more_than_70_days.toPandas()
# Out:
# 40
#      Timestamp CRM_Lead_ID        Billing_account_id Status  \
# 0   1643358877        None  ["dn2tiund0b32idhph3me"]   None
# 1   1643358877        None  ["dn2vv6a9075kq276hpi2"]   None
# 2   1643358877        None  ["dn2nhou3kuqvpvjiono1"]   None
# 3   1643358877        None  ["dn27alahfginpr1o19gp"]   None
# 4   1643358877        None  ["dn2nhbgq6g78f065o3md"]   None
# 5   1643358877        None  ["dn2kmtp654vg0jmjkmv2"]   None
# 6   1643358877        None  ["dn2ufei2650d1espulju"]   None
# 7   1643358877        None  ["dn22pm653ddlbk8mjsu3"]   None
# 8   1643358877        None  ["dn23ev2dfipdonjentp2"]   None
# 9   1643358877        None  ["dn29bvbf4jke72or96d9"]   None
# 10  1643358877        None  ["dn2gvjj61pglo2rccoaf"]   None
# 11  1643358877        None  ["dn2tqkug810p16uuv8l7"]   None
# 12  1643358877        None  ["dn2o1aap2jda6tvkb3s1"]   None
# 13  1643358877        None  ["dn2eki7f21iumtpfriqn"]   None
# 14  1643358877        None  ["dn2um41cp8c8sbtvkhoj"]   None
# 15  1643358877        None  ["dn2ghssekvkpe41u02ha"]   None
# 16  1643358877        None  ["dn2jv5la9vcqvabo6kmt"]   None
# 17  1643358877        None  ["dn2unsrefjdda66lu7si"]   None
# 18  1643358877        None  ["dn2hq4nejick1g3solh7"]   None
# 19  1643358877        None  ["dn2bmvkdhcueaae1pf9p"]   None
# 20  1643358877        None  ["dn2d2qt42n2r8a0436qt"]   None
# 21  1643358877        None  ["dn2mrclhla5073icaka6"]   None
# 22  1643358877        None  ["dn28evns89ljluni3r16"]   None
# 23  1643358877        None  ["dn2du59skabpskpmrkr6"]   None
# 24  1643358877        None  ["dn2krrcb5mv5kct14k20"]   None
# 25  1643358877        None  ["dn29c3jvr8ik7mald5o9"]   None
# 26  1643358877        None  ["dn23krfha8nj36ih9cuh"]   None
# 27  1643358877        None  ["dn2qre387c3ao9i1jsoi"]   None
# 28  1643358877        None  ["dn213qqdi3vecumlfchr"]   None
# 29  1643358877        None  ["dn2mjkmi628vhg0o36c4"]   None
# 30  1643358877        None  ["dn2g360vl5igipfjm06c"]   None
# 31  1643358877        None  ["dn25v42i0vm2t99llf28"]   None
# 32  1643358877        None  ["dn2pik8e1lmelmm58frm"]   None
# 33  1643358877        None  ["dn2d8qang8opciir9jo4"]   None
# 34  1643358877        None  ["dn2q9ti2g0shqhne3k4c"]   None
# 35  1643358877        None  ["dn2ufoogthotplsvt03o"]   None
# 36  1643358877        None  ["dn2nok3p7p7uivrao6tf"]   None
# 37  1643358877        None  ["dn23mvce7vf5a5ulq8nu"]   None
# 38  1643358877        None  ["dn2frp7sn8khph78c2he"]   None
# 39  1643358877        None  ["dn23plg4373uodte7q05"]   None
#
#                                           Description    Assigned_to  \
# 0                                                              admin
# 1                                                              admin
# 2                                                              admin
# 3                                                              admin
# 4   Client Use BD on VM: mysql, redis, postgresql,...  nikitagrekhov
# 5                                                         gingerkote
# 6                                                              admin
# 7                                                              admin
# 8                                                              admin
# 9                                                             dmtroe
# 10                                                             admin
# 11                                                        gingerkote
# 12                                                         efremov-n
# 13                                                             admin
# 14                                                             admin
# 15                                                             admin
# 16                                                             admin
# 17                                                        gingerkote
# 18                                                             admin
# 19                                                            dmtroe
# 20                                                             admin
# 21  Client Use BD on VM: mysql, redis, postgresql,...         dmtroe
# 22                                                             admin
# 23                                                             admin
# 24                                                        gingerkote
# 25                                                             admin
# 26                                                             admin
# 27                                                       sosnovskikh
# 28                                                             admin
# 29                                                             admin
# 30                                                             admin
# 31  Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 32                                                             admin
# 33  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 34                                                             admin
# 35                                                        gingerkote
# 36                                                         efremov-n
# 37  Client Use BD on VM: mysql, redis, postgresql,...          admin
# 38  Client Use BD on VM: mysql, redis, postgresql,...         dmtroe
# 39  Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
#
#    First_name                        Last_name      Phone_1 Phone_2  \
# 0        None                 ООО «МишельАвто»  79251760977    None
# 1        None                   ТИМКА-ТИМКА.РУ  79213290269    None
# 2        None                          Олпрайм  78312128981    None
# 3        None                  Test Yandex LLC  79645777830    None
# 4   Анастасия                         Морозова  79095406401    None
# 5        None                    ООО "ФИНПОРТ"  79163245770    None
# 6        None                           АО ДКИ  79201911686    None
# 7     Евгений                         Ожиганов  79524444921    None
# 8      Сергей                         Бормотов  79265507635    None
# 9        None               ООО "МЕДТРЕЙД СПБ"  79676303378    None
# 10       None               НП ДО и ДПО “БВШД”  79262587553    None
# 11       None                   Диджитал Рокет  84952552567    None
# 12       None                       ООО «САВА»  79175341092    None
# 13       None             Платформа Технологий  79060588699    None
# 14       None       ИП Чуров Алексей Сергеевич  79023532800    None
# 15  Елизавета                          Князева  79032094473    None
# 16       None           ООО "Ричо франчайзинг"  79033132183    None
# 17       None                  ООО "ПЛАТФОРМА"  74959959330    None
# 18    Василий                          Ульянов  79999857535    None
# 19       None   ИП Новокшонова Ирина Сергеевна  79220390005    None
# 20     Никита                        Дорошенко  79504172234    None
# 21       None                       ООО "МЭТР"  79136235555    None
# 22       None               ИП КОШХАДЗЕ ГИОРГИ  79255142504    None
# 23       None                            Волна  79147076131    None
# 24       None               ООО «ХЕД ЭНД ХАРТ»  79635035313    None
# 25       None                ООО "Инсейлс Рус"  79268906380    None
# 26       None       ИП Довбня Андрей Андреевич  79685334748    None
# 27       None                  ИП Кожевина Г.И  79319714241    None
# 28       None            ООО "Трейд-Универсал"  79881177595    None
# 29       None          ИП Манолов Андрей Ильич  79263573317    None
# 30       None                            Фьюче  74993409471    None
# 31       None                        Волга-Тур  79873955682    None
# 32       None  ИП Колобаев Алексей Геннадиевич  79107087878    None
# 33       None          ООО «Нейрогейминг Парк»  79163614453    None
# 34     Михаил                           Собаев  79521821824    None
# 35       None                 Frank Shikhaliev  79263790123    None
# 36       None                   Magicbit, Inc.  18774246051    None
# 37       None                       ИП Михалев  79630765071    None
# 38       None                          ИП Ткач  79221433591    None
# 39       None                      ИП Епифанов  79326086709    None
#
#                                                 Email Lead_Source  \
# 0                                  admmavto@yandex.ru      upsell
# 1                                     marat@popeye.ws      upsell
# 2                                   olprime@yandex.ru      upsell
# 3                                    yc.sag@yandex.ru      upsell
# 4                                m3.npk.ett@yandex.ru      upsell
# 5                                     info@finport.ru      upsell
# 6                               erofeev.org@yandex.ru      upsell
# 7                                      cloud@vozro.ru      upsell
# 8                                foxvillage@yandex.ru      upsell
# 9                               medtrade.vm@yandex.ru      upsell
# 10                                 uu.cloud@yandex.ru      upsell
# 11                                 alexey@dirocket.ru      upsell
# 12                        cloud.yandex@savasensors.ru      upsell
# 13                                      info@ireg.pro      upsell
# 14                                alex@bytehunter.org      upsell
# 15                               eoknyazeva@yandex.ru      upsell
# 16                               owner@richopizza.com      upsell
# 17                           info@platforma-online.ru      upsell
# 18                                 gf-cloud@yandex.ru      upsell
# 19                            AVNovokshonov@yandex.ru      upsell
# 20                             overpsot1234@yandex.ru      upsell
# 21                               developer@metr.world      upsell
# 22                              ariadna3000@yandex.ru      upsell
# 23                                     sgtx@yandex.ru      upsell
# 24                                    thiro@yandex.ru      upsell
# 25                            kementarindur@yandex.ru      upsell
# 26                                  Dovbnya@elifan.ru      upsell
# 27                               egrncentre@yandex.ru      upsell
# 28                                  lev-stv@yandex.ru      upsell
# 29                                      mr@riftman.ru      upsell
# 30  promo-future@yandex.ru;shevlyakov.n@future-gro...      upsell
# 31                               levina@alyanstour.ru      upsell
# 32                                   flagmankit@ya.ru      upsell
# 33                              neurogaming@yandex.ru      upsell
# 34                                  sobaeff@yandex.ru      upsell
# 35                         frank.shikhaliev@yandex.ru      upsell
# 36                              magicbit@magicbit.org      upsell
# 37                            ip-mihalev-ip@yandex.ru      upsell
# 38                              ip-tkach-ip@yandex.ru      upsell
# 39                           ip-epifanov-ip@yandex.ru      upsell
#
#       Lead_Source_Description Callback_date Last_communication_date Promocode  \
# 0   contact more then 70 days          None                    None      None
# 1   contact more then 70 days          None                    None      None
# 2   contact more then 70 days          None                    None      None
# 3   contact more then 70 days          None                    None      None
# 4   contact more then 70 days          None                    None      None
# 5   contact more then 70 days          None                    None      None
# 6   contact more then 70 days          None                    None      None
# 7   contact more then 70 days          None                    None      None
# 8   contact more then 70 days          None                    None      None
# 9   contact more then 70 days          None                    None      None
# 10  contact more then 70 days          None                    None      None
# 11  contact more then 70 days          None                    None      None
# 12  contact more then 70 days          None                    None      None
# 13  contact more then 70 days          None                    None      None
# 14  contact more then 70 days          None                    None      None
# 15  contact more then 70 days          None                    None      None
# 16  contact more then 70 days          None                    None      None
# 17  contact more then 70 days          None                    None      None
# 18  contact more then 70 days          None                    None      None
# 19  contact more then 70 days          None                    None      None
# 20  contact more then 70 days          None                    None      None
# 21  contact more then 70 days          None                    None      None
# 22  contact more then 70 days          None                    None      None
# 23  contact more then 70 days          None                    None      None
# 24  contact more then 70 days          None                    None      None
# 25  contact more then 70 days          None                    None      None
# 26  contact more then 70 days          None                    None      None
# 27  contact more then 70 days          None                    None      None
# 28  contact more then 70 days          None                    None      None
# 29  contact more then 70 days          None                    None      None
# 30  contact more then 70 days          None                    None      None
# 31  contact more then 70 days          None                    None      None
# 32  contact more then 70 days          None                    None      None
# 33  contact more then 70 days          None                    None      None
# 34  contact more then 70 days          None                    None      None
# 35  contact more then 70 days          None                    None      None
# 36  contact more then 70 days          None                    None      None
# 37  contact more then 70 days          None                    None      None
# 38  contact more then 70 days          None                    None      None
# 39  contact more then 70 days          None                    None      None
#
#    Promocode_sum Notes Dimensions  Tags Timezone  \
# 0           None  None       None  None
# 1           None  None       None  None
# 2           None  None       None  None
# 3           None  None       None  None
# 4           None  None       None  None
# 5           None  None       None  None
# 6           None  None       None  None
# 7           None  None       None  None
# 8           None  None       None  None
# 9           None  None       None  None
# 10          None  None       None  None
# 11          None  None       None  None
# 12          None  None       None  None
# 13          None  None       None  None
# 14          None  None       None  None
# 15          None  None       None  None
# 16          None  None       None  None
# 17          None  None       None  None
# 18          None  None       None  None
# 19          None  None       None  None
# 20          None  None       None  None
# 21          None  None       None  None
# 22          None  None       None  None
# 23          None  None       None  None
# 24          None  None       None  None
# 25          None  None       None  None
# 26          None  None       None  None
# 27          None  None       None  None
# 28          None  None       None  None
# 29          None  None       None  None
# 30          None  None       None  None
# 31          None  None       None  None
# 32          None  None       None  None
# 33          None  None       None  None
# 34          None  None       None  None
# 35          None  None       None  None
# 36          None  None       None  None
# 37          None  None       None  None
# 38          None  None       None  None
# 39          None  None       None  None
#
#                                          Account_name
# 0   Общество с ограниченной ответственностью «Мише...
# 1                                ООО "ТИМКА-ТИМКА.РУ"
# 2                                         ООО Олпрайм
# 3                                     Test Yandex LLC
# 4                       Анастасия Викторовна Морозова
# 5   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
# 6                                  АО "ДомКом Инвест"
# 7                         Евгений Николаевич Ожиганов
# 8                            Сергей Иванович Бормотов
# 9   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МЕДТ...
# 10  Некоммерческое партнерство дополнительного обр...
# 11                               ООО "Диджитал Рокет"
# 12    Общество с ограниченной ответственностью «САВА»
# 13  Общество с ограниченной ответственностью "Плат...
# 14  Индивидуальный предприниматель Чуров Алексей С...
# 15                         Елизавета Олеговна Князева
# 16  Обшество с ограниченной ответственностью "Ричо...
# 17  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЛАТ...
# 18                           Василий Игоревич Ульянов
# 19  Индивидуальный предприниматель Новокшонова Ири...
# 20                        Никита Николаевич Дорошенко
# 21    Общество с ограниченной ответственностью "МЭТР"
# 22     Индивидуальный Предприниматель Кошхадзе Гиорги
# 23                                        ООО "Волна"
# 24  Общество с ограниченной ответственностью "ХЕД ...
# 25  Общество с ограниченной ответственностью «Инсе...
# 26                         ИП Довбня Андрей Андреевич
# 27                                    ИП Кожевина Г.И
# 28                              ООО "Трейд-Универсал"
# 29                            ИП Манолов Андрей Ильич
# 30                                        ООО «Фьюче»
# 31                                    ООО "Волга-Тур"
# 32  Индивидуальный предприниматель Колобаев Алексе...
# 33  Общество с ограниченной ответственностью «Нейр...
# 34                           Михаил Викторович Собаев
# 35                                       ООО Майндсэт
# 36                                     Magicbit, Inc.
# 37                                         ИП Михалев
# 38                                            ИП Ткач
# 39                                        ИП Епифанов

# %%
upsell_leads.union(contact_more_than_70_days).toPandas()
# Out:
#      Timestamp CRM_Lead_ID        Billing_account_id Status  \
# 0   1643358877        None  ["dn2muo28g4her430cks9"]   None
# 1   1643358877        None  ["dn2t3ceqst6b6ut9teel"]   None
# 2   1643358877        None  ["dn2onlje8gci28lvburl"]   None
# 3   1643358877        None  ["dn2kth2vqfuvcq3ra2l4"]   None
# 4   1643358877        None  ["dn24u79dcdqah89752i4"]   None
# 5   1643358877        None  ["dn2k0668h8mgpa9rf3u9"]   None
# 6   1643358877        None  ["dn2aveanh9rephqmpnah"]   None
# 7   1643358877        None  ["dn2flcq7v1cqejo2aitl"]   None
# 8   1643358877        None  ["dn2qf0atlki5khrj4462"]   None
# 9   1643358877        None  ["dn2iuvntil6a189jcfrp"]   None
# 10  1643358877        None  ["dn2ichgsbadb9da2pa8o"]   None
# 11  1643358877        None  ["dn2rabss5dgimhg7q08s"]   None
# 12  1643358877        None  ["dn2gegl8deqrdd9h9icd"]   None
# 13  1643358877        None  ["dn27c256fgpb7bsojum8"]   None
# 14  1643358877        None  ["dn2mvjevs4nu884d6b35"]   None
# 15  1643358877        None  ["dn2pacooaf46504jjad9"]   None
# 16  1643358877        None  ["dn2fo5j0782u1a5tvn5r"]   None
# 17  1643358877        None  ["dn2drjveqmhioapm3dge"]   None
# 18  1643358877        None  ["dn2csht8nnf7rnjsp1p2"]   None
# 19  1643358877        None  ["dn2o8mbegea1e60nsmjk"]   None
# 20  1643358877        None  ["dn2c2sjmev48ea6ke3js"]   None
# 21  1643358877        None  ["dn2m8pjr6p58fa52kti8"]   None
# 22  1643358877        None  ["dn2sulv4049if0u9qfnb"]   None
# 23  1643358877        None  ["dn2uhqkhigsoh8nobq5r"]   None
# 24  1643358877        None  ["dn20ch4d1q4u66m44gla"]   None
# 25  1643358877        None  ["dn2n43tj1ma06mav7k5i"]   None
# 26  1643358877        None  ["dn2vhvae82j73c5b2vfj"]   None
# 27  1643358877        None  ["dn2uficp9be4k91go0hm"]   None
# 28  1643358877        None  ["dn2hbkupbtu29cb6mmnt"]   None
# 29  1643358877        None  ["dn2dvtik3v6j43kc5608"]   None
# 30  1643358877        None  ["dn24n0nqlkr3l00hlbts"]   None
# 31  1643358877        None  ["dn2uo0qs0ec3snmfbf25"]   None
# 32  1643358877        None  ["dn2bj448mflaoveruaj3"]   None
# 33  1643358877        None  ["dn2qh2b1k30rke57t8f4"]   None
# 34  1643358877        None  ["dn2tm3a676dikd5i3rna"]   None
# 35  1643358877        None  ["dn283a0jhjra7f9l7u2d"]   None
# 36  1643358877        None  ["dn2cg68303n3p2n949cs"]   None
# 37  1643358877        None  ["dn2ba0rnj76g4k7lsrpu"]   None
# 38  1643358877        None  ["dn21fs6f5tvg1f7l5h46"]   None
# 39  1643358877        None  ["dn2578ott4uhs6gdva9d"]   None
# 40  1643358877        None  ["dn2tiund0b32idhph3me"]   None
# 41  1643358877        None  ["dn2vv6a9075kq276hpi2"]   None
# 42  1643358877        None  ["dn2nhou3kuqvpvjiono1"]   None
# 43  1643358877        None  ["dn2nhbgq6g78f065o3md"]   None
# 44  1643358877        None  ["dn27alahfginpr1o19gp"]   None
# 45  1643358877        None  ["dn2kmtp654vg0jmjkmv2"]   None
# 46  1643358877        None  ["dn2ufei2650d1espulju"]   None
# 47  1643358877        None  ["dn23ev2dfipdonjentp2"]   None
# 48  1643358877        None  ["dn22pm653ddlbk8mjsu3"]   None
# 49  1643358877        None  ["dn29bvbf4jke72or96d9"]   None
# 50  1643358877        None  ["dn2gvjj61pglo2rccoaf"]   None
# 51  1643358877        None  ["dn2tqkug810p16uuv8l7"]   None
# 52  1643358877        None  ["dn2o1aap2jda6tvkb3s1"]   None
# 53  1643358877        None  ["dn2eki7f21iumtpfriqn"]   None
# 54  1643358877        None  ["dn2um41cp8c8sbtvkhoj"]   None
# 55  1643358877        None  ["dn2ghssekvkpe41u02ha"]   None
# 56  1643358877        None  ["dn2jv5la9vcqvabo6kmt"]   None
# 57  1643358877        None  ["dn2unsrefjdda66lu7si"]   None
# 58  1643358877        None  ["dn2hq4nejick1g3solh7"]   None
# 59  1643358877        None  ["dn2bmvkdhcueaae1pf9p"]   None
# 60  1643358877        None  ["dn2mrclhla5073icaka6"]   None
# 61  1643358877        None  ["dn2d2qt42n2r8a0436qt"]   None
# 62  1643358877        None  ["dn28evns89ljluni3r16"]   None
# 63  1643358877        None  ["dn2du59skabpskpmrkr6"]   None
# 64  1643358877        None  ["dn2krrcb5mv5kct14k20"]   None
# 65  1643358877        None  ["dn23krfha8nj36ih9cuh"]   None
# 66  1643358877        None  ["dn29c3jvr8ik7mald5o9"]   None
# 67  1643358877        None  ["dn2qre387c3ao9i1jsoi"]   None
# 68  1643358877        None  ["dn213qqdi3vecumlfchr"]   None
# 69  1643358877        None  ["dn2mjkmi628vhg0o36c4"]   None
# 70  1643358877        None  ["dn2g360vl5igipfjm06c"]   None
# 71  1643358877        None  ["dn25v42i0vm2t99llf28"]   None
# 72  1643358877        None  ["dn2pik8e1lmelmm58frm"]   None
# 73  1643358877        None  ["dn2d8qang8opciir9jo4"]   None
# 74  1643358877        None  ["dn2q9ti2g0shqhne3k4c"]   None
# 75  1643358877        None  ["dn2nok3p7p7uivrao6tf"]   None
# 76  1643358877        None  ["dn2ufoogthotplsvt03o"]   None
# 77  1643358877        None  ["dn2frp7sn8khph78c2he"]   None
# 78  1643358877        None  ["dn2oakl3761s9qfn85nv"]   None
# 79  1643358877        None  ["dn2lm8bnejlbovdjqoor"]   None
#
#                                           Description    Assigned_to  \
# 0   Client Use BD on VM: mysql, redis, postgresql,...          admin
# 1   Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 2   Client Use BD on VM: mysql, redis, postgresql,...         dmtroe
# 3                                                         gingerkote
# 4   Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 5   Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 6   Client Use BD on VM: mysql, redis, postgresql,...  nikitagrekhov
# 7                                                         gingerkote
# 8                                                         gingerkote
# 9   Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 10                                                             admin
# 11  Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 12                                                        gingerkote
# 13                                                             admin
# 14  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 15  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 16                                                     nikitagrekhov
# 17  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 18                                                             admin
# 19                                                        gingerkote
# 20                                                             admin
# 21  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 22  Client Use BD on VM: mysql, redis, postgresql,...          admin
# 23                                                             admin
# 24                                                     nikitagrekhov
# 25  Client Use BD on VM: mysql, redis, postgresql,...          admin
# 26  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 27                                                        gingerkote
# 28  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 29  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 30  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 31                                                        moiseeva-m
# 32  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 33  Client Use BD on VM: mysql, redis, postgresql,...  nikitagrekhov
# 34  Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 35                                                       sosnovskikh
# 36                                                             admin
# 37  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 38  Client Use BD on VM: mysql, redis, postgresql,...     moiseeva-m
# 39                                                        moiseeva-m
# 40                                                             admin
# 41                                                             admin
# 42                                                             admin
# 43  Client Use BD on VM: mysql, redis, postgresql,...  nikitagrekhov
# 44                                                             admin
# 45                                                        gingerkote
# 46                                                             admin
# 47                                                             admin
# 48                                                             admin
# 49                                                            dmtroe
# 50                                                             admin
# 51                                                        gingerkote
# 52                                                         efremov-n
# 53                                                             admin
# 54                                                             admin
# 55                                                             admin
# 56                                                             admin
# 57                                                        gingerkote
# 58                                                             admin
# 59                                                            dmtroe
# 60  Client Use BD on VM: mysql, redis, postgresql,...         dmtroe
# 61                                                             admin
# 62                                                             admin
# 63                                                             admin
# 64                                                        gingerkote
# 65                                                             admin
# 66                                                             admin
# 67                                                       sosnovskikh
# 68                                                             admin
# 69                                                             admin
# 70                                                             admin
# 71  Client Use BD on VM: mysql, redis, postgresql,...     gingerkote
# 72                                                             admin
# 73  Client Use BD on VM: mysql, redis, postgresql,...    sosnovskikh
# 74                                                             admin
# 75                                                         efremov-n
# 76                                                        gingerkote
# 77  Client Use BD on VM: mysql, redis, postgresql,...         dmtroe
# 78  Client Use BD on VM: mysql, redis, postgresql,...          admin
# 79  Client Use BD on VM: mysql, redis, postgresql,...          admin
#
#    First_name                                          Last_name  \
# 0        Иван                                           Варанкин
# 1      Максим                                             Волков
# 2     Алексей                                          Прибытков
# 3      Руслан                                          Сеитханов
# 4     Евгений                                          Головинов
# 5      Максим                                             Лаптев
# 6   Александр                                          Миловидов
# 7       Захар                                            Давыдов
# 8        None                       ИП Попков Альберт Михайлович
# 9      Сергей                                            Тишинов
# 10     Сергей                                           Савельев
# 11    Дмитрий                                           Петренко
# 12   Владимир                                            Самойло
# 13    Евгений                                            Неверов
# 14     Михаил                                            Матвеев
# 15    Евгений                                       Мирошниченко
# 16       Юсиф                                            Насирли
# 17      Денис                                            Голиков
# 18       None                       AL FAKHER FACTORY Sp. z o.o.
# 19    Дмитрий                                          Козубский
# 20       Нина                                             Сырова
# 21      Ольга                                            Акинина
# 22  Alexander                                         Sarachakov
# 23       None                                    Лава Технолоджи
# 24       None                       ИП "Петров Сергей Сергеевич"
# 25       None                                          ООО "МИР"
# 26       None                                          АО "ФАСП"
# 27       None                         ООО "Диспетчер ЖКХ онлайн"
# 28       None                                               ДЕКА
# 29       None                                      ООО "ЭКО-САД"
# 30       None                                       ООО "ФРЕГАТ"
# 31       None                                      ООО "Фалькон"
# 32       None                         ООО «Лобненский Водоканал»
# 33       None                           ООО "Иностудио Солюшинс"
# 34       None                                 ООО «Ю-Менеджмент»
# 35       None  ИНДИВИДУАЛЬНЫЙ ПРЕДПРИНИМАТЕЛЬ ЦЫГАНКОВ АЛЕКСА...
# 36       None                          Infortrend Technology Inc
# 37       None                                    ООО "Альтеркей"
# 38       None                                      ООО "Комплай"
# 39       None                                     ИП Романов И.В
# 40       None                                   ООО «МишельАвто»
# 41       None                                     ТИМКА-ТИМКА.РУ
# 42       None                                            Олпрайм
# 43  Анастасия                                           Морозова
# 44       None                                    Test Yandex LLC
# 45       None                                      ООО "ФИНПОРТ"
# 46       None                                             АО ДКИ
# 47     Сергей                                           Бормотов
# 48    Евгений                                           Ожиганов
# 49       None                                 ООО "МЕДТРЕЙД СПБ"
# 50       None                                 НП ДО и ДПО “БВШД”
# 51       None                                     Диджитал Рокет
# 52       None                                         ООО «САВА»
# 53       None                               Платформа Технологий
# 54       None                         ИП Чуров Алексей Сергеевич
# 55  Елизавета                                            Князева
# 56       None                             ООО "Ричо франчайзинг"
# 57       None                                    ООО "ПЛАТФОРМА"
# 58    Василий                                            Ульянов
# 59       None                     ИП Новокшонова Ирина Сергеевна
# 60       None                                         ООО "МЭТР"
# 61     Никита                                          Дорошенко
# 62       None                                 ИП КОШХАДЗЕ ГИОРГИ
# 63       None                                              Волна
# 64       None                                 ООО «ХЕД ЭНД ХАРТ»
# 65       None                         ИП Довбня Андрей Андреевич
# 66       None                                  ООО "Инсейлс Рус"
# 67       None                                    ИП Кожевина Г.И
# 68       None                              ООО "Трейд-Универсал"
# 69       None                            ИП Манолов Андрей Ильич
# 70       None                                              Фьюче
# 71       None                                          Волга-Тур
# 72       None                    ИП Колобаев Алексей Геннадиевич
# 73       None                            ООО «Нейрогейминг Парк»
# 74     Михаил                                             Собаев
# 75       None                                     Magicbit, Inc.
# 76       None                                   Frank Shikhaliev
# 77       None                                            ИП Ткач
# 78       None                                       ИП Талевнина
# 79       None                                         ИП Чекурак
#
#                  Phone_1 Phone_2  \
# 0            79112207276    None
# 1            79106631052    None
# 2            79276126473    None
# 3            77016438757    None
# 4            79268125031    None
# 5            79686381277    None
# 6            79169534164    None
# 7           447455190769    None
# 8            79255458055    None
# 9            79168054161    None
# 10           79281853869    None
# 11           79024485580    None
# 12           79263515380    None
# 13           79246081977    None
# 14           79202948046    None
# 15           79222954511    None
# 16           79053384880    None
# 17           79167982218    None
# 18          971565267775    None
# 19           79539105129    None
# 20           79122718300    None
# 21           79226828389    None
# 22           79659993494    None
# 23           79052220085    None
# 24           79261408252    None
# 25           74997556298    None
# 26  84956412413,доб.3030    None
# 27           79606269147    None
# 28           79178695712    None
# 29           79603775564    None
# 30           79021690095    None
# 31           78452651650    None
# 32           79067664966    None
# 33           79185269815    None
# 34           79090796815    None
# 35           79899512077    None
# 36          886222260126    None
# 37           79219350999    None
# 38           79169681554    None
# 39           79048922470    None
# 40           79251760977    None
# 41           79213290269    None
# 42           78312128981    None
# 43           79095406401    None
# 44           79645777830    None
# 45           79163245770    None
# 46           79201911686    None
# 47           79265507635    None
# 48           79524444921    None
# 49           79676303378    None
# 50           79262587553    None
# 51           84952552567    None
# 52           79175341092    None
# 53           79060588699    None
# 54           79023532800    None
# 55           79032094473    None
# 56           79033132183    None
# 57           74959959330    None
# 58           79999857535    None
# 59           79220390005    None
# 60           79136235555    None
# 61           79504172234    None
# 62           79255142504    None
# 63           79147076131    None
# 64           79635035313    None
# 65           79685334748    None
# 66           79268906380    None
# 67           79319714241    None
# 68           79881177595    None
# 69           79263573317    None
# 70           74993409471    None
# 71           79873955682    None
# 72           79107087878    None
# 73           79163614453    None
# 74           79521821824    None
# 75           18774246051    None
# 76           79263790123    None
# 77           79221433591    None
# 78           79090736714    None
# 79           79024106906    None
#
#                                                 Email Lead_Source  \
# 0                                varankin54@yandex.ru      upsell
# 1                                   marahal@yandex.ru      upsell
# 2                                  ladavtor@yandex.ru      upsell
# 3                       r.seitkhanov@solo-interier.kz      upsell
# 4                               evgeny@golovinov.info      upsell
# 5                          maxim.laptev2014@yandex.ru      upsell
# 6                                      manowar@aha.ru      upsell
# 7                               davydov@studiodart.eu      upsell
# 8                              albertpopkov@yandex.ru      upsell
# 9                                 tishinovs@gmail.com      upsell
# 10                        absolut-avto61.ru@yandex.ru      upsell
# 11                               d.petr3nko@yandex.ru      upsell
# 12                                  Nadmozg@yandex.ru      upsell
# 13                                   info@jetlearn.io      upsell
# 14                                  bilanz2@yandex.ru      upsell
# 15                                    john@i-mati.org      upsell
# 16                              pro.nasirli@yandex.ru      upsell
# 17                             Native-Faalh@yandex.ru      upsell
# 18                         digitalalfakher@yandex.com      upsell
# 19                                  kozubsky@inbox.ru      upsell
# 20                                mobbuhasb@yandex.ru      upsell
# 21                                   info@meinstil.ru      upsell
# 22                         alekssarachakov@yandex.com      upsell
# 23                              lavatop2020@yandex.ru      upsell
# 24                                sergey@goodit.works      upsell
# 25                               i.toropov@machaon.ru      upsell
# 26                                        fin@fasp.ru      upsell
# 27                                  gkh.onl@yandex.ru      upsell
# 28                             infrastructure@deck.lc      upsell
# 29                                    info@sreda.guru      upsell
# 30                                   alex.s@votak.org      upsell
# 31                        buhgalter@falcon-saratov.ru      upsell
# 32                               lobnyavoda@yandex.ru      upsell
# 33                       inostudio.ya.cloud@yandex.ru      upsell
# 34                                   umngmt@yandex.ru      upsell
# 35                                pistonsky@yandex.ru      upsell
# 36                           Roson.lee@infortrend.com      upsell
# 37                                   tmex20@yandex.ru      upsell
# 38                          sergei.saiganov@comply.ru      upsell
# 39                                romanov@tehnocam.ru      upsell
# 40                                 admmavto@yandex.ru      upsell
# 41                                    marat@popeye.ws      upsell
# 42                                  olprime@yandex.ru      upsell
# 43                               m3.npk.ett@yandex.ru      upsell
# 44                                   yc.sag@yandex.ru      upsell
# 45                                    info@finport.ru      upsell
# 46                              erofeev.org@yandex.ru      upsell
# 47                               foxvillage@yandex.ru      upsell
# 48                                     cloud@vozro.ru      upsell
# 49                              medtrade.vm@yandex.ru      upsell
# 50                                 uu.cloud@yandex.ru      upsell
# 51                                 alexey@dirocket.ru      upsell
# 52                        cloud.yandex@savasensors.ru      upsell
# 53                                      info@ireg.pro      upsell
# 54                                alex@bytehunter.org      upsell
# 55                               eoknyazeva@yandex.ru      upsell
# 56                               owner@richopizza.com      upsell
# 57                           info@platforma-online.ru      upsell
# 58                                 gf-cloud@yandex.ru      upsell
# 59                            AVNovokshonov@yandex.ru      upsell
# 60                               developer@metr.world      upsell
# 61                             overpsot1234@yandex.ru      upsell
# 62                              ariadna3000@yandex.ru      upsell
# 63                                     sgtx@yandex.ru      upsell
# 64                                    thiro@yandex.ru      upsell
# 65                                  Dovbnya@elifan.ru      upsell
# 66                            kementarindur@yandex.ru      upsell
# 67                               egrncentre@yandex.ru      upsell
# 68                                  lev-stv@yandex.ru      upsell
# 69                                      mr@riftman.ru      upsell
# 70  promo-future@yandex.ru;shevlyakov.n@future-gro...      upsell
# 71                               levina@alyanstour.ru      upsell
# 72                                   flagmankit@ya.ru      upsell
# 73                              neurogaming@yandex.ru      upsell
# 74                                  sobaeff@yandex.ru      upsell
# 75                              magicbit@magicbit.org      upsell
# 76                         frank.shikhaliev@yandex.ru      upsell
# 77                              ip-tkach-ip@yandex.ru      upsell
# 78                              talevina-ip@yandex.ru      upsell
# 79                              chekurak-ip@yandex.ru      upsell
#
#       Lead_Source_Description Callback_date Last_communication_date Promocode  \
# 0                      upsell          None                    None      None
# 1                      upsell          None                    None      None
# 2                      upsell          None                    None      None
# 3                      upsell          None                    None      None
# 4                      upsell          None                    None      None
# 5                      upsell          None                    None      None
# 6                      upsell          None                    None      None
# 7                      upsell          None                    None      None
# 8                      upsell          None                    None      None
# 9                      upsell          None                    None      None
# 10                     upsell          None                    None      None
# 11                     upsell          None                    None      None
# 12                     upsell          None                    None      None
# 13                     upsell          None                    None      None
# 14                     upsell          None                    None      None
# 15                     upsell          None                    None      None
# 16                     upsell          None                    None      None
# 17                     upsell          None                    None      None
# 18                     upsell          None                    None      None
# 19                     upsell          None                    None      None
# 20                     upsell          None                    None      None
# 21                     upsell          None                    None      None
# 22                     upsell          None                    None      None
# 23                     upsell          None                    None      None
# 24                     upsell          None                    None      None
# 25                     upsell          None                    None      None
# 26                     upsell          None                    None      None
# 27                     upsell          None                    None      None
# 28                     upsell          None                    None      None
# 29                     upsell          None                    None      None
# 30                     upsell          None                    None      None
# 31                     upsell          None                    None      None
# 32                     upsell          None                    None      None
# 33                     upsell          None                    None      None
# 34                     upsell          None                    None      None
# 35                     upsell          None                    None      None
# 36                     upsell          None                    None      None
# 37                     upsell          None                    None      None
# 38                     upsell          None                    None      None
# 39                     upsell          None                    None      None
# 40  contact more then 70 days          None                    None      None
# 41  contact more then 70 days          None                    None      None
# 42  contact more then 70 days          None                    None      None
# 43  contact more then 70 days          None                    None      None
# 44  contact more then 70 days          None                    None      None
# 45  contact more then 70 days          None                    None      None
# 46  contact more then 70 days          None                    None      None
# 47  contact more then 70 days          None                    None      None
# 48  contact more then 70 days          None                    None      None
# 49  contact more then 70 days          None                    None      None
# 50  contact more then 70 days          None                    None      None
# 51  contact more then 70 days          None                    None      None
# 52  contact more then 70 days          None                    None      None
# 53  contact more then 70 days          None                    None      None
# 54  contact more then 70 days          None                    None      None
# 55  contact more then 70 days          None                    None      None
# 56  contact more then 70 days          None                    None      None
# 57  contact more then 70 days          None                    None      None
# 58  contact more then 70 days          None                    None      None
# 59  contact more then 70 days          None                    None      None
# 60  contact more then 70 days          None                    None      None
# 61  contact more then 70 days          None                    None      None
# 62  contact more then 70 days          None                    None      None
# 63  contact more then 70 days          None                    None      None
# 64  contact more then 70 days          None                    None      None
# 65  contact more then 70 days          None                    None      None
# 66  contact more then 70 days          None                    None      None
# 67  contact more then 70 days          None                    None      None
# 68  contact more then 70 days          None                    None      None
# 69  contact more then 70 days          None                    None      None
# 70  contact more then 70 days          None                    None      None
# 71  contact more then 70 days          None                    None      None
# 72  contact more then 70 days          None                    None      None
# 73  contact more then 70 days          None                    None      None
# 74  contact more then 70 days          None                    None      None
# 75  contact more then 70 days          None                    None      None
# 76  contact more then 70 days          None                    None      None
# 77  contact more then 70 days          None                    None      None
# 78  contact more then 70 days          None                    None      None
# 79  contact more then 70 days          None                    None      None
#
#    Promocode_sum Notes Dimensions  Tags Timezone  \
# 0           None  None       None  None
# 1           None  None       None  None
# 2           None  None       None  None
# 3           None  None       None  None
# 4           None  None       None  None
# 5           None  None       None  None
# 6           None  None       None  None
# 7           None  None       None  None
# 8           None  None       None  None
# 9           None  None       None  None
# 10          None  None       None  None
# 11          None  None       None  None
# 12          None  None       None  None
# 13          None  None       None  None
# 14          None  None       None  None
# 15          None  None       None  None
# 16          None  None       None  None
# 17          None  None       None  None
# 18          None  None       None  None
# 19          None  None       None  None
# 20          None  None       None  None
# 21          None  None       None  None
# 22          None  None       None  None
# 23          None  None       None  None
# 24          None  None       None  None
# 25          None  None       None  None
# 26          None  None       None  None
# 27          None  None       None  None
# 28          None  None       None  None
# 29          None  None       None  None
# 30          None  None       None  None
# 31          None  None       None  None
# 32          None  None       None  None
# 33          None  None       None  None
# 34          None  None       None  None
# 35          None  None       None  None
# 36          None  None       None  None
# 37          None  None       None  None
# 38          None  None       None  None
# 39          None  None       None  None
# 40          None  None       None  None
# 41          None  None       None  None
# 42          None  None       None  None
# 43          None  None       None  None
# 44          None  None       None  None
# 45          None  None       None  None
# 46          None  None       None  None
# 47          None  None       None  None
# 48          None  None       None  None
# 49          None  None       None  None
# 50          None  None       None  None
# 51          None  None       None  None
# 52          None  None       None  None
# 53          None  None       None  None
# 54          None  None       None  None
# 55          None  None       None  None
# 56          None  None       None  None
# 57          None  None       None  None
# 58          None  None       None  None
# 59          None  None       None  None
# 60          None  None       None  None
# 61          None  None       None  None
# 62          None  None       None  None
# 63          None  None       None  None
# 64          None  None       None  None
# 65          None  None       None  None
# 66          None  None       None  None
# 67          None  None       None  None
# 68          None  None       None  None
# 69          None  None       None  None
# 70          None  None       None  None
# 71          None  None       None  None
# 72          None  None       None  None
# 73          None  None       None  None
# 74          None  None       None  None
# 75          None  None       None  None
# 76          None  None       None  None
# 77          None  None       None  None
# 78          None  None       None  None
# 79          None  None       None  None
#
#                                          Account_name
# 0                         Иван Александрович Варанкин
# 1                             Максим Леондович Волков
# 2                         Алексей Андреевич Прибытков
# 3                        Руслан Сейтканович Сеитханов
# 4                        Евгений Эдуардович Головинов
# 5                         Максим Александрович Лаптев
# 6                      Александр Николаевич Миловидов
# 7                             Захар Андреевич Давыдов
# 8                        ИП Попков Альберт Михайлович
# 9                          Сергей Григорьевич Тишинов
# 10                      Сергей Александрович Савельев
# 11                         Дмитрий Сергеевич Петренко
# 12                          Владимир Петрович Самойло
# 13                         Евгений Евгеньевич Неверов
# 14                           Михаил Сергеевич Матвеев
# 15                     Евгений Сергеевич Мирошниченко
# 16                          Юсиф Ибрагим оглы Насирли
# 17                           Денис Николаевич Голиков
# 18                       AL FAKHER FACTORY Sp. z o.o.
# 19                    Дмитрий Владиславович Козубский
# 20                               Нина Ивановна Сырова
# 21                            Ольга Андреевна Акинина
# 22                    Alexander Evgenevich Sarachakov
# 23                              ООО "Лава Технолоджи"
# 24                       ИП "Петров Сергей Сергеевич"
# 25     ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МИР"
# 26  Акционерное общество "Финансовое Агентство по ...
# 27                         ООО "Диспетчер ЖКХ онлайн"
# 28                                         ООО «ДЕКА»
# 29  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКО-...
# 30  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФРЕГАТ"
# 31                                      ООО "Фалькон"
# 32  Общество с ограниченной ответственностью «Лобн...
# 33  Общество с ограниченной ответственностью "Инос...
# 34  Общество с ограниченной ответственностью «Ю-Ме...
# 35  ИНДИВИДУАЛЬНЫЙ ПРЕДПРИНИМАТЕЛЬ ЦЫГАНКОВ АЛЕКСА...
# 36                          Infortrend Technology Inc
# 37  Общество с ограниченной ответственностью "Альт...
# 38  Общество с ограниченной ответственностью "Комп...
# 39  Индивидуальный предприниматель Романов Игорь В...
# 40  Общество с ограниченной ответственностью «Мише...
# 41                               ООО "ТИМКА-ТИМКА.РУ"
# 42                                        ООО Олпрайм
# 43                      Анастасия Викторовна Морозова
# 44                                    Test Yandex LLC
# 45  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
# 46                                 АО "ДомКом Инвест"
# 47                           Сергей Иванович Бормотов
# 48                        Евгений Николаевич Ожиганов
# 49  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МЕДТ...
# 50  Некоммерческое партнерство дополнительного обр...
# 51                               ООО "Диджитал Рокет"
# 52    Общество с ограниченной ответственностью «САВА»
# 53  Общество с ограниченной ответственностью "Плат...
# 54  Индивидуальный предприниматель Чуров Алексей С...
# 55                         Елизавета Олеговна Князева
# 56  Обшество с ограниченной ответственностью "Ричо...
# 57  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЛАТ...
# 58                           Василий Игоревич Ульянов
# 59  Индивидуальный предприниматель Новокшонова Ири...
# 60    Общество с ограниченной ответственностью "МЭТР"
# 61                        Никита Николаевич Дорошенко
# 62     Индивидуальный Предприниматель Кошхадзе Гиорги
# 63                                        ООО "Волна"
# 64  Общество с ограниченной ответственностью "ХЕД ...
# 65                         ИП Довбня Андрей Андреевич
# 66  Общество с ограниченной ответственностью «Инсе...
# 67                                    ИП Кожевина Г.И
# 68                              ООО "Трейд-Универсал"
# 69                            ИП Манолов Андрей Ильич
# 70                                        ООО «Фьюче»
# 71                                    ООО "Волга-Тур"
# 72  Индивидуальный предприниматель Колобаев Алексе...
# 73  Общество с ограниченной ответственностью «Нейр...
# 74                           Михаил Викторович Собаев
# 75                                     Magicbit, Inc.
# 76                                       ООО Майндсэт
# 77                                            ИП Ткач
# 78                                       ИП Талевнина
# 79                                         ИП Чекурак

# %%
spyt.stop(spark)
