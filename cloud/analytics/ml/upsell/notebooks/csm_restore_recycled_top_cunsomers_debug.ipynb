# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from os.path import join as path_join
from clan_tools.data_adapters.YTAdapter import YTAdapter
from clan_tools.data_adapters.YQLAdapter import YQLAdapter
import spyt
import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark.sql.functions import col, lit
from pyspark.sql.window import Window
from pyspark.sql.session import SparkSession
from clan_tools.utils.spark import SPARK_CONF_MEDIUM
import re
from os.path import join as path_join
import pickle
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 250)
os.environ['NUMEXPR_MAX_THREADS'] = '32'

# %%
from clan_tools.secrets.Vault import Vault
Vault().get_secrets(secret_id='sec-01fm06fw1zsqp08cxtyd247tm5')
yt_adapter = YTAdapter()

spark = spyt.connect(spark_conf_args=SPARK_CONF_MEDIUM)
spyt.info(spark)
# Out:
# 2022-02-07 19:44:19,563 - WARNING - spyt.conf - Your SPYT library has version 1.3.5 which is older than your cluster version 3.0.1-1.23.1+yandex. Some new features may not work as expected. Please update your cluster with spark-launch-yt utility
# 2022-02-07 19:44:30,621 - INFO - spyt.client - SPYT Cluster version: 3.0.1-1.23.1+yandex
# 2022-02-07 19:44:30,623 - INFO - spyt.client - SPYT library version: 1.3.5
#             <div>
#                 <p><b>SPYT</b></p>
#
#                 <p><a href="sas4-8624-node-hahn.sas.yp-c.yandex.net:27002">Master Web UI</a></p>
#                 <dl>
#                   <dt>Yt Cluster</dt>
#                     <dd><code>hahn.yt.yandex.net</code></dd>
#                   <dt>SPYT Cluster version</dt>
#                     <dd><code>3.0.1-1.23.1+yandex</code></dd>
#                   <dt>SPYT Library version</dt>
#                     <dd><code>1.3.5</code></dd>
#                 </dl>
#
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://jupyter-cloud-pavelvasilev.sas.yp-c.yandex.net:27002">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://sas4-8624-node-hahn.sas.yp-c.yandex.net:27001</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySpark for pavelvasilev</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Generate CSM leads

# %%
from clan_tools.data_adapters.crm.CRMHistoricalDataAdapter import CRMHistoricalDataAdapter
PARAMS = {
    'TARGET_PAID_COND': 50000,
    'MIN_PAID_LAST_30D': 5000,
    'MIN_CALIBR_PROBA': 0.001,
    'MAX_CALIBR_PROBA': 0.851,
    'PRED_PROBA_BRD': 0.3,
    'CONF_INTERVAL': 0.95
}

results_path = "//home/cloud_analytics/ml/scoring/consumption_predictor_v2/data/prod_results"
features_path = "//home/cloud_analytics/ml/scoring/consumption_predictor_v2/data/actual_features"
leads_path = "//home/cloud_analytics/ml/scoring/consumption_predictor_v2/crm/upsell"
calib_path = "//home/cloud_analytics/ml/scoring/consumption_predictor_v2/model/prod/calibrators_history/csm"
contact_info = "//home/cloud_analytics/import/crm/leads/contact_info"

# %%
threshold_th = PARAMS['TARGET_PAID_COND'] // 1000
pred_colname = f"{threshold_th:.0f}k_pred"
leads_count = 100
rep_date = (datetime.now()+timedelta(days=-1)).strftime("%Y-%m-%d")

calib_name = max(yt_adapter.yt.list(calib_path))
calibr_ser = yt_adapter.yt.read_file(path_join(calib_path, calib_name)).read()
calibr = pickle.loads(calibr_ser)

def make_proba(x):
    return calibr.predict([x])[0]
# Out:
# /home/pavelvasilev/miniconda3/envs/python37/lib/python3.7/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator IsotonicRegression from version 0.22.2 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
spdf_info = (
    spark.read.yt(results_path)
    .filter(col("billing_record_msk_date")==rep_date)
    .join(spark.read.yt(features_path), on=["billing_account_id", "billing_record_msk_date"], how="inner")
    .filter(F.coalesce("prev_30d_cons", lit(0)) < PARAMS['TARGET_PAID_COND'])
    .filter(F.coalesce("prev_30d_cons", lit(0)) > PARAMS['MIN_PAID_LAST_30D'])
    .filter(F.coalesce("billing_account_state", lit("active"))=="active")
    .filter(~F.coalesce("billing_account_is_suspended_by_antifraud", lit(False)))
    .filter(~F.coalesce("billing_account_is_isv", lit(False)))
    .filter(~F.coalesce("billing_account_is_var", lit(False)))
    .filter(col("crm_segment").isin(["Mass", "Medium"]))
    .withColumn(pred_colname, col("prev_15d_cons")+col("billing_record_total_rub")+col("next_14d_cons_pred"))
    .select(
        "billing_account_id",
        "billing_record_msk_date",
        "billing_account_usage_status",
        "billing_account_person_type",
        "billing_account_currency",
        "billing_account_state",
        "billing_account_is_fraud",
        "billing_account_is_suspended_by_antifraud",
        "billing_account_is_isv",
        "billing_account_is_var",
        "billing_account_is_crm_account",
        "crm_segment",
        "days_from_created",
        "prev_30d_cons",
        "prev_15d_cons",
        "next_14d_cons_pred",
        pred_colname
    ).cache()
)

filter_crm = (
    CRMHistoricalDataAdapter(yt_adapter, spark)
    .historical_preds()
    .select("billing_account_id", col("lead_source_crm").alias("lead_source"))
    .union(
        spark.read.yt("//home/cloud_analytics/kulaga/leads_cube").select("billing_account_id", "lead_source"))
    .filter(~col("billing_account_id").isNull())
    .filter(col("billing_account_id")!='{{BILLING_ACCOUNT_ID}}')
    .filter(col("lead_source")!="trial")
)

dff = spdf_info["billing_account_id", "billing_record_msk_date", pred_colname].toPandas()
dff['proba'] = calibr.predict(dff[pred_colname])
spdf_pred = spark.createDataFrame(dff[["billing_account_id", "billing_record_msk_date", "proba"]])

spdf_main = spdf_info.join(spdf_pred,
                            on=["billing_account_id", "billing_record_msk_date"],
                            how="left").cache()

print(spdf_main.count())
spdf_main.limit(3).toPandas()
# Out:
# 2103
#      billing_account_id billing_record_msk_date billing_account_usage_status  \
# 0  dn219pa215mkq9mv0hr6              2022-02-06                         paid
# 1  dn22us53siqqv2dkoq54              2022-02-06                         paid
# 2  dn2309b3sbeeaq1f1m80              2022-02-06                         paid
#
#   billing_account_person_type billing_account_currency billing_account_state  \
# 0                  individual                      RUB                active
# 1                     company                      RUB                active
# 2                  individual                      RUB                active
#
#    billing_account_is_fraud  billing_account_is_suspended_by_antifraud  \
# 0                     False                                      False
# 1                      True                                      False
# 2                     False                                      False
#
#    billing_account_is_isv  billing_account_is_var  \
# 0                   False                   False
# 1                   False                   False
# 2                   False                   False
#
#    billing_account_is_crm_account crm_segment  days_from_created  \
# 0                           False        Mass                365
# 1                           False        Mass                 26
# 2                            True        Mass                365
#
#    prev_30d_cons  prev_15d_cons  next_14d_cons_pred      50k_pred     proba
# 0    5698.388400      11.734800           -0.083626     11.651174  0.001000
# 1   14049.191719   11039.338844         9965.975547  21562.642989  0.851000
# 2   13381.253921    6693.519214         6502.149828  13578.553748  0.022727

# %%
spdf_contacts = spark.read.yt(contact_info).cache()

leads_source_1 = (
    CRMHistoricalDataAdapter(yt_adapter, spark)
    .historical_preds()
    .select(
        "billing_account_id",
        col("lead_source_crm").alias("lead_source"),
        F.to_date(F.to_timestamp(col("date_entered")/1000000)).alias("lead_date")
    )
    .distinct()
)

leads_source_2 = (
    spark.read.yt("//home/cloud_analytics/kulaga/leads_cube")
    .select("billing_account_id", "lead_source", F.to_date("date_entered").alias("lead_date"))
    .distinct()
)

crm_leads = (
    leads_source_1
    .union(leads_source_2)
    .distinct()
    .filter(~col("billing_account_id").isNull())
    .filter(col("billing_account_id")!='{{BILLING_ACCOUNT_ID}}')
)

crm_ba_filter = (
    crm_leads.filter(col("lead_source")=='upsell')
    .select("billing_account_id", lit(1).alias("has_upsell_lead"))
    .distinct()
)
crm_date_filter = crm_leads.groupby("billing_account_id").agg(F.max("lead_date").alias("lead_date"))

# %%
spdf_res_leads = (
    spdf_main
    .join(crm_ba_filter, on=['billing_account_id'], how="left")
    .join(crm_date_filter, on=['billing_account_id'], how="left")
    .join(spdf_contacts, on=['billing_account_id'], how="left")
    .sort(col("proba").desc())
    .cache()
    .filter(col("has_upsell_lead").isNull())
    .filter(F.coalesce(F.datediff("billing_record_msk_date", "lead_date"), lit(1000)) > 30)
    .filter(col("proba")>0.3)
    .select(
        lit(int(datetime.now().timestamp())).alias('Timestamp'),
        lit(None).astype('string').alias('CRM_Lead_ID'),
        F.concat(lit('["'), "billing_account_id", lit('"]')).alias("Billing_account_id"),
        lit(None).astype('string').alias('Status'),
        F.concat(
            lit('Confidence that "'),
            col('billing_account_id'),
            lit('" is target is '),
            F.round(col('proba')*100),
            lit('%.')
        ).alias('Description'),
        lit('admin').alias('Assigned_to'),
        col("first_name").alias('First_name'),
        col("last_name").alias('Last_name'),
        col("phone").alias('Phone_1'),
        lit(None).astype('string').alias('Phone_2'),
        col("email").alias('Email'),
        lit('upsell').alias('Lead_Source'),
        lit('Potential candidate for 50k over 28 days period').alias('Lead_Source_Description'),
        lit(None).astype('string').alias('Callback_date'),
        lit(None).astype('string').alias('Last_communication_date'),
        lit(None).astype('string').alias('Promocode'),
        lit(None).astype('string').alias('Promocode_sum'),
        lit(None).astype('string').alias('Notes'),
        lit(None).astype('string').alias('Dimensions'),
        lit(None).astype('string').alias('Tags'),
        lit('').alias('Timezone'),
        col("display_name").alias('Account_name')
    )
)

spdf_res_leads.toPandas()
# Out:
#      Timestamp CRM_Lead_ID        Billing_account_id Status  \
# 0   1644252551        None  ["dn2jvtiq2co0osi7160e"]   None
# 1   1644252551        None  ["dn2ip3eamftuhtrpo6ie"]   None
# 2   1644252551        None  ["dn2ne1hr313nifao7ni9"]   None
# 3   1644252551        None  ["dn287flat7n6f0puvfml"]   None
# 4   1644252551        None  ["dn2p7pm9pdo5lopoqp0s"]   None
# 5   1644252551        None  ["dn2fhisotf1hpcen8t2n"]   None
# 6   1644252551        None  ["dn208mklvsmmlgactn1u"]   None
# 7   1644252551        None  ["dn21csmjctdva54ur8th"]   None
# 8   1644252551        None  ["dn27beosenkq8rqaecsg"]   None
# 9   1644252551        None  ["dn2o94kk9ijaighavbl2"]   None
# 10  1644252551        None  ["dn2eu2t9aan486dih9qf"]   None
# 11  1644252551        None  ["dn2f7dbrd48l8osatssv"]   None
# 12  1644252551        None  ["dn2990a0guieftebe349"]   None
# 13  1644252551        None  ["dn2tftg1es90nhpdnoih"]   None
# 14  1644252551        None  ["dn24cccv01p5iiteuoej"]   None
# 15  1644252551        None  ["dn22b823ok0ko7g5sspv"]   None
# 16  1644252551        None  ["dn2s81hvkk50nod1ehrb"]   None
# 17  1644252551        None  ["dn2ute5b591t5k9794be"]   None
# 18  1644252551        None  ["dn2o2etchsqv3k4hehc3"]   None
# 19  1644252551        None  ["dn24urb66ogmnf0bmdd1"]   None
# 20  1644252551        None  ["dn219f4lt3jno7024gts"]   None
# 21  1644252551        None  ["dn27m5hshi2ehoql7jlg"]   None
# 22  1644252551        None  ["dn27kgiqkgoar0peks2l"]   None
# 23  1644252551        None  ["dn27dsnk0unr9lkljton"]   None
# 24  1644252551        None  ["dn2qovl06odj7rqaqq1j"]   None
# 25  1644252551        None  ["dn2uic32s6n6qqka4kt1"]   None
# 26  1644252551        None  ["dn2frbdu0eva2adelssh"]   None
# 27  1644252551        None  ["dn2odi9s62llefpq5lhk"]   None
# 28  1644252551        None  ["dn2cqa3gik13vk7jrfhu"]   None
# 29  1644252551        None  ["dn2semkee41urekn07uo"]   None
# 30  1644252551        None  ["dn2cd3q9hr8ni42df77v"]   None
# 31  1644252551        None  ["dn29facunsogqjr6m5kc"]   None
# 32  1644252551        None  ["dn22oig2mjccqges7uqi"]   None
# 33  1644252551        None  ["dn2embue85ahg436rcnv"]   None
# 34  1644252551        None  ["dn2vaknhjs53hsfesdlq"]   None
#
#                                           Description Assigned_to First_name  \
# 0   Confidence that "dn2jvtiq2co0osi7160e" is targ...       admin       None
# 1   Confidence that "dn2ip3eamftuhtrpo6ie" is targ...       admin     Максим
# 2   Confidence that "dn2ne1hr313nifao7ni9" is targ...       admin       None
# 3   Confidence that "dn287flat7n6f0puvfml" is targ...       admin      Тихон
# 4   Confidence that "dn2p7pm9pdo5lopoqp0s" is targ...       admin     Агамир
# 5   Confidence that "dn2fhisotf1hpcen8t2n" is targ...       admin       None
# 6   Confidence that "dn208mklvsmmlgactn1u" is targ...       admin       None
# 7   Confidence that "dn21csmjctdva54ur8th" is targ...       admin       Иван
# 8   Confidence that "dn27beosenkq8rqaecsg" is targ...       admin       None
# 9   Confidence that "dn2o94kk9ijaighavbl2" is targ...       admin       None
# 10  Confidence that "dn2eu2t9aan486dih9qf" is targ...       admin       None
# 11  Confidence that "dn2f7dbrd48l8osatssv" is targ...       admin       None
# 12  Confidence that "dn2990a0guieftebe349" is targ...       admin       None
# 13  Confidence that "dn2tftg1es90nhpdnoih" is targ...       admin       None
# 14  Confidence that "dn24cccv01p5iiteuoej" is targ...       admin       None
# 15  Confidence that "dn22b823ok0ko7g5sspv" is targ...       admin       None
# 16  Confidence that "dn2s81hvkk50nod1ehrb" is targ...       admin       None
# 17  Confidence that "dn2ute5b591t5k9794be" is targ...       admin       None
# 18  Confidence that "dn2o2etchsqv3k4hehc3" is targ...       admin       None
# 19  Confidence that "dn24urb66ogmnf0bmdd1" is targ...       admin       None
# 20  Confidence that "dn219f4lt3jno7024gts" is targ...       admin     Оганес
# 21  Confidence that "dn27m5hshi2ehoql7jlg" is targ...       admin       None
# 22  Confidence that "dn27kgiqkgoar0peks2l" is targ...       admin       None
# 23  Confidence that "dn27dsnk0unr9lkljton" is targ...       admin       None
# 24  Confidence that "dn2qovl06odj7rqaqq1j" is targ...       admin      Артём
# 25  Confidence that "dn2uic32s6n6qqka4kt1" is targ...       admin       None
# 26  Confidence that "dn2frbdu0eva2adelssh" is targ...       admin       None
# 27  Confidence that "dn2odi9s62llefpq5lhk" is targ...       admin       None
# 28  Confidence that "dn2cqa3gik13vk7jrfhu" is targ...       admin       None
# 29  Confidence that "dn2semkee41urekn07uo" is targ...       admin       None
# 30  Confidence that "dn2cd3q9hr8ni42df77v" is targ...       admin       None
# 31  Confidence that "dn29facunsogqjr6m5kc" is targ...       admin       None
# 32  Confidence that "dn22oig2mjccqges7uqi" is targ...       admin       None
# 33  Confidence that "dn2embue85ahg436rcnv" is targ...       admin      Zkail
# 34  Confidence that "dn2vaknhjs53hsfesdlq" is targ...       admin     Андрей
#
#                                             Last_name       Phone_1 Phone_2  \
# 0                                         УК  КВАДРАТ    8352380488    None
# 1                                               Демах   79518650746    None
# 2                ООО “ПВК Технологический Консалтинг”   79857603115    None
# 3                                             Чумаков   79957874202    None
# 4                                               Алиев   79217415897    None
# 5                   ООО «Гулливер энд Ко Интернейшнл»   79193012636    None
# 6                             KNOMARY PRODUCTION CJSC  375293572366    None
# 7                                               Целых   79778680891    None
# 8                                                 hsr   84994000236    None
# 9                                         ООО "ДИВЬЮ"   79037400787    None
# 10                                        ООО "УБЕКС"   79175216388    None
# 11                            ГАУ ТРК РТВ-Подмосковье   79859177359    None
# 12                                       ООО «Омега»:   79999964647    None
# 13                                          ООО «РИА»   79122300467    None
# 14                                ООО "Хеппивеар Юг"     9275105469    None
# 15                                       ГК РосДеньги   79217966381    None
# 16                                    Магнит-Косметик   79299663709    None
# 17                                             tayyab   77078223377    None
# 18                                         profitbase   73432380274    None
# 19                              НовосибирскЭнергоСбыт   73832298669    None
# 20                                          Саруханян   79037290442    None
# 21                                     ООО Мастерград   79819306784    None
# 22                            Сафонов Кирилл Олегович   79990344148    None
# 23                        ООО «ТЭК «Желдоринтеграция»   79122871796    None
# 24                                          Востряков   79857941159    None
# 25                                  Термал Мастер Рус   78312340203    None
# 26                                    ООО «Джи Эф Си»   79778075051    None
# 27  Общество с ограниченной ответственностью «МТГЕЙМ»   79661299324    None
# 28                                           INMYROOM   79107163594    None
# 29                          ООО "Флорист.ру-Диджитал"   79871800034    None
# 30                                       ООО «БАСФОР»   79127634592    None
# 31                              ООО "Шишкин Лес Торг"   79037388625    None
# 32                                           ПИКВАРИО   79096770440    None
# 33                                         Semembayev   77788746233    None
# 34                                           Толмачев   79038361808    None
#
#                                               Email Lead_Source  \
# 0                                squaremc@yandex.ru      upsell
# 1                             enkisoftvrn@gmail.com      upsell
# 2                                pwccloud@yandex.ru      upsell
# 3                           kondrashov.it@yandex.ru      upsell
# 4                                   bot@smileson.ru      upsell
# 5                          cloud.gulliver@yandex.ru      upsell
# 6                                  info@knomary.com      upsell
# 7                       sashagreysuhareva@yandex.ru      upsell
# 8                          hsr24.techteam@yandex.ru      upsell
# 9                                      dvue@dvue.ru      upsell
# 10                   alexandra.alexandrova@ubex.com      upsell
# 11                                 site@radio1.news      upsell
# 12                                eg00rka@yandex.ru      upsell
# 13                                  ria@artsofte.ru      upsell
# 14                                 it@happything.ru      upsell
# 15                                     it@rd-net.ru      upsell
# 16                          magnit-k-voca@yandex.ru      upsell
# 17                                   info@tayyab.co      upsell
# 18                         profitbase-ops@yandex.ru      upsell
# 19                     naumen-novosibirsk@yandex.ru      upsell
# 20                          oosarukhanyan@gmail.com      upsell
# 21                               ads@mastergrad.com      upsell
# 22                                andb.kb@yandex.ru      upsell
# 23                           a.v.shipulin@yandex.ru      upsell
# 24                          deniscloud123@yandex.ru      upsell
# 25                           termalmaster@yandex.ru      upsell
# 26                              tech.hrct@yandex.ru      upsell
# 27                             amlysenkov@mtgame.ru      upsell
# 28                               imrcloud@yandex.ru      upsell
# 29                         floristdigital@yandex.ru      upsell
# 30  bbc.teamru@yandex.ru;andrey.lapin@blablacar.com      upsell
# 31                            CForest2019@yandex.ru      upsell
# 32                         martirosyan@picvario.com      upsell
# 33                            jasventures@yandex.kz      upsell
# 34                                tolmachev@assi.ai      upsell
#
#                             Lead_Source_Description Callback_date  \
# 0   Potential candidate for 50k over 28 days period          None
# 1   Potential candidate for 50k over 28 days period          None
# 2   Potential candidate for 50k over 28 days period          None
# 3   Potential candidate for 50k over 28 days period          None
# 4   Potential candidate for 50k over 28 days period          None
# 5   Potential candidate for 50k over 28 days period          None
# 6   Potential candidate for 50k over 28 days period          None
# 7   Potential candidate for 50k over 28 days period          None
# 8   Potential candidate for 50k over 28 days period          None
# 9   Potential candidate for 50k over 28 days period          None
# 10  Potential candidate for 50k over 28 days period          None
# 11  Potential candidate for 50k over 28 days period          None
# 12  Potential candidate for 50k over 28 days period          None
# 13  Potential candidate for 50k over 28 days period          None
# 14  Potential candidate for 50k over 28 days period          None
# 15  Potential candidate for 50k over 28 days period          None
# 16  Potential candidate for 50k over 28 days period          None
# 17  Potential candidate for 50k over 28 days period          None
# 18  Potential candidate for 50k over 28 days period          None
# 19  Potential candidate for 50k over 28 days period          None
# 20  Potential candidate for 50k over 28 days period          None
# 21  Potential candidate for 50k over 28 days period          None
# 22  Potential candidate for 50k over 28 days period          None
# 23  Potential candidate for 50k over 28 days period          None
# 24  Potential candidate for 50k over 28 days period          None
# 25  Potential candidate for 50k over 28 days period          None
# 26  Potential candidate for 50k over 28 days period          None
# 27  Potential candidate for 50k over 28 days period          None
# 28  Potential candidate for 50k over 28 days period          None
# 29  Potential candidate for 50k over 28 days period          None
# 30  Potential candidate for 50k over 28 days period          None
# 31  Potential candidate for 50k over 28 days period          None
# 32  Potential candidate for 50k over 28 days period          None
# 33  Potential candidate for 50k over 28 days period          None
# 34  Potential candidate for 50k over 28 days period          None
#
#    Last_communication_date Promocode Promocode_sum Notes Dimensions  Tags  \
# 0                     None      None          None  None       None  None
# 1                     None      None          None  None       None  None
# 2                     None      None          None  None       None  None
# 3                     None      None          None  None       None  None
# 4                     None      None          None  None       None  None
# 5                     None      None          None  None       None  None
# 6                     None      None          None  None       None  None
# 7                     None      None          None  None       None  None
# 8                     None      None          None  None       None  None
# 9                     None      None          None  None       None  None
# 10                    None      None          None  None       None  None
# 11                    None      None          None  None       None  None
# 12                    None      None          None  None       None  None
# 13                    None      None          None  None       None  None
# 14                    None      None          None  None       None  None
# 15                    None      None          None  None       None  None
# 16                    None      None          None  None       None  None
# 17                    None      None          None  None       None  None
# 18                    None      None          None  None       None  None
# 19                    None      None          None  None       None  None
# 20                    None      None          None  None       None  None
# 21                    None      None          None  None       None  None
# 22                    None      None          None  None       None  None
# 23                    None      None          None  None       None  None
# 24                    None      None          None  None       None  None
# 25                    None      None          None  None       None  None
# 26                    None      None          None  None       None  None
# 27                    None      None          None  None       None  None
# 28                    None      None          None  None       None  None
# 29                    None      None          None  None       None  None
# 30                    None      None          None  None       None  None
# 31                    None      None          None  None       None  None
# 32                    None      None          None  None       None  None
# 33                    None      None          None  None       None  None
# 34                    None      None          None  None       None  None
#
#    Timezone                                       Account_name
# 0                                            ООО "УК "Квадрат"
# 1                                       Максим Сергеевич Демах
# 2            Общество с Ограниченной ответственностью “Прай...
# 3                                  Тихон Александрович Чумаков
# 4                                       Агамир Тофикофич Алиев
# 5            Общество с ограниченной ответственностью «Гулл...
# 6                                      KNOMARY PRODUCTION CJSC
# 7                                        Иван Дмитриевич Целых
# 8                                       ООО «Хом шоппинг Раша»
# 9             ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДИВЬЮ"
# 10            ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УБЕКС"
# 11           Государственное автономное учреждение Московск...
# 12            Общество с ограниченной ответственностью «Омега»
# 13           Общество с ограниченной ответственностью «Реше...
# 14           Общество с ограниченной ответственностью "Хепп...
# 15                                          ООО "ФинансСервис"
# 16                                                 АО «Тандер»
# 17                               ЧК "Tayyab Central Asia" ltd.
# 18                                            ООО «Бизерра.ру»
# 19                                  АО «Новосибирскэнергосбыт»
# 20                                 Оганес Оганесович Саруханян
# 21           Общество с ограниченной ответственностью "Маст...
# 22                                  ИП Сафонов Кирилл Олегович
# 23           Общество с ограниченной ответственностью «Тран...
# 24                                   Артём Сергеевич Востряков
# 25                                     ООО «Термал Мастер Рус»
# 26           Общество с ограниченной ответственностью «Джи ...
# 27                                                ООО "МТГЕЙМ"
# 28                                              ООО «ИНМАЙРУМ»
# 29           ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "Флор...
# 30           Общество с ограниченной ответственностью "БАСФОР"
# 31           Общество с ограниченной ответственностью "Шишк...
# 32           Общество с ограниченной  ответственностью «ПИК...
# 33                                            Zkail Semembayev
# 34                                  Андрей Евгеньевич Толмачев

# %% [markdown]
# ### Restore recycled

# %%
def max_by(x, y):
    return F.expr(f'max_by({x}, {y})')


class Generate_CSM_Leads:
    dm_yc_consumption_path = '//home/cloud-dwh/data/prod/cdm/dm_yc_consumption'
    dm_crm_tags = '//home/cloud-dwh/data/prod/cdm/dm_ba_crm_tags'

    def __init__(self, spark: SparkSession, yt_adapter: YTAdapter, days_period: int = 90, consumption_threshold: int = 150000) -> None:
        self.spark = spark
        self.consumption_threshold = consumption_threshold
        self.historical_data_adapter = CRMHistoricalDataAdapter(yt_adapter, spark)
        self.days_period = days_period
        self.today = datetime.now().date()
        self.date_from = self.today - timedelta(days_period)

    def get_ba_over_threshold(self):
        crm_tags_filter = (
            self.spark.read.yt(self.dm_crm_tags)
            .select(
                'billing_account_id',
                'account_owner_current',
                'usage_status_current',
                'segment_current',
                'state_current',
                'is_suspended_by_antifraud_current',
                'is_var_current'
            )
            .distinct()
        )
        ba_over_threshold = (
            self.spark.read.yt(self.dm_yc_consumption_path)
            .filter(F.to_date('billing_record_msk_date') >= self.date_from)
            .filter(F.to_date('billing_record_msk_date') < self.today)
            .groupby('billing_account_id')
            .agg(F.sum('billing_record_real_consumption_rub').alias('paid_cons'))
            .filter(col('paid_cons')>self.consumption_threshold)
            .join(crm_tags_filter, on='billing_account_id', how='left')
            .filter(col('usage_status_current')=='paid')
            .filter(col('segment_current').isin(['Mass', 'Medium']))
            .filter(col('account_owner_current')=='No Account Owner')
            .filter(col('state_current')=='active')
            .filter(~col('is_suspended_by_antifraud_current'))
            .filter(~col('is_var_current'))
            .select('billing_account_id', 'paid_cons')
            .cache()
        )

        rows_num = ba_over_threshold.count()
        days_num = self.days_period
        thrsh = self.consumption_threshold
        print(f'Loaded BAs with consumption exceeded {thrsh} RUB in {days_num} days period: {rows_num} row(s)')

        return ba_over_threshold

    def restore_recycled(self):
        ba_over_threshold = self.get_ba_over_threshold()
        crm_historical_data = self.historical_data_adapter.historical_preds().cache()
        recycled_ba = (
            crm_historical_data
            .filter(col('lead_source').like('%30k%') | col('lead_source').like('%50k%'))
            .groupby('billing_account_id')
            .agg(
                F.max('date_modified').alias("date_modified"),
                max_by('status', 'date_modified').alias("last_status")
            )
            .filter(F.lower(col("last_status")) == 'recycled')
            .filter(F.from_unixtime(col('date_modified')/1000000) < self.date_from)
            .cache()
        )
        qualified_ba = (
            crm_historical_data
            .filter(col('lead_source_crm')!='trial')
            .filter(col('status')=='Converted')
            .filter(~col('billing_account_id').isNull())
            .select('billing_account_id')
        )
        recycled = (
            crm_historical_data
            .join(recycled_ba, on=['billing_account_id', 'date_modified'], how='inner')
        )
        recycled_to_restore = (
            recycled
            .join(ba_over_threshold, how='leftsemi', on='billing_account_id')
            .withColumn('description',
                        lit('Restored from recycled, since consumed more'+
                            f'than {self.consumption_threshold} over {self.days_period} days'))
        )
        max_date = (
            recycled_to_restore
            .groupby('billing_account_id')
            .agg(F.max(col('date_entered')).alias('date_entered'))
        )
        filtered_restore = (
            recycled_to_restore
            .join(max_date, on=['billing_account_id', 'date_entered'], how='leftsemi')
            .join(qualified_ba, on='billing_account_id', how='leftanti')
        )
        return filtered_restore

    def top_cunsomers(self):
        ba_over_threshold = self.get_ba_over_threshold()
        crm_wo_trial = (
            self.historical_data_adapter
            .historical_preds()
            .filter(col('lead_source_crm')!='trial')
            .cache()
        )
        top_cunsomers = (
            ba_over_threshold
            .join(crm_wo_trial, on='billing_account_id', how='leftanti')
            .withColumn(
                'description',
                F.concat(
                    lit('Account "'),
                    col('billing_account_id'),
                    lit('" has consumption '),
                    F.round(col('paid_cons'), 2),
                    lit(f'rub over last {self.days_period} days')
                )
            )
        )
        return top_cunsomers

spdf_res = Generate_CSM_Leads(spark,
                              yt_adapter,
                              consumption_threshold=150000,
                              days_period=90).restore_recycled()

df_fr = spdf_res.toPandas()
print(df_fr.shape)
df_fr
# Out:
# Loaded BAs with consumption exceeded 150000 RUB in 90 days period: 69 row(s)
# (13, 18)
#       billing_account_id      date_entered     date_modified  \
# 0   dn2k17tluvqbeip2nclb  1631109662000000  1631623433000000
# 1   dn2k17tluvqbeip2nclb  1631109662000000  1631623433000000
# 2   dn2eht2pbri1plgtldl3  1619355601000000  1631694819000000
# 3   dn2qbr3hb10t6l3sis6i  1623070801000000  1628160583000000
# 4   dn2qk8bmmo4gm6ssudv0  1631537461000000  1631537723000000
# 5   dn28u5fiq1pbl47tol5r  1632747721000000  1633001215000000
# 6   dn28u5fiq1pbl47tol5r  1632747721000000  1633001215000000
# 7   dn2n9j7q5h8hv1unjvh1  1623242401000000  1632986204000000
# 8   dn2ai7epnn4r2thoj1k6  1613041201000000  1620814745000000
# 9   dn20k53ptrc5nvh4hqlr  1631537461000000  1631693789000000
# 10  dn2kbppkbeacsck5n6dv  1631109061000000  1631712980000000
# 11  dn28h691n944hfqfe8f7  1635853861000000  1635854351000000
# 12  dn2ivhgierstat7570t6  1607943601000000  1618228058000000
#
#                                  lead_id first_name       last_name  \
# 0   4dc57b2a-10ad-11ec-ab73-9216a807bccf  Екатерина        Решетник
# 1   4dc57b2a-10ad-11ec-ab73-9216a807bccf  Екатерина        Решетник
# 2   387125c8-a5c6-11eb-8545-5840e080c8fc       Юрий      Киберспорт
# 3   69422346-c790-11eb-adc6-a93a7ead6470       Иван          Лебедь
# 4   7823f256-1491-11ec-af10-1110359b52e8    Support         MineBet
# 5   2034264e-1f93-11ec-aeb6-c57929b23bc0      Марат     Шайхетдинов
# 6   2034264e-1f93-11ec-aeb6-c57929b23bc0      Марат     Шайхетдинов
# 7   d151d892-c91f-11eb-8ef6-5cf32889de6c      Админ         Хайсмит
# 8   55ab71a4-6c58-11eb-a3e9-a6c7e7fbf937      Артём        Круковец
# 9   72defb38-1491-11ec-860f-97c413777ae0     Ксения       Бухгалтер
# 10  26ac7134-10ac-11ec-875f-e6f2c84ac77b       None  ИП Белов М. А.
# 11  50ce88ce-3bd3-11ec-a3f0-73950d3f3e23     Сергей         Новиков
# 12  9c85242a-3dfb-11eb-a4c9-45fea5dffff8  Александр           Зобов
#
#                     client_name title         phone  \
# 0     Веденеев Михаил Андреевич  None   79254099451
# 1     Веденеев Михаил Андреевич  None   79254099451
# 2                    КИБЕРСПОРТ  None   79689755854
# 3    Фонд «Образование и наука»  None   79057471804
# 4   Богер Константин Викторович  None   79139227503
# 5   Шайхетдинов Марат Гадилович  None   79372920862
# 6   Шайхетдинов Марат Гадилович  None   79372920862
# 7                   ООО ХайСмит  None   79165707929
# 8                       ООО КСК  None   79629316108
# 9                          Tips  None   79251738482
# 10               ИП Белов М. А.  None  +79150349022
# 11     Новиков Сергей Сергеевич  None   79164154710
# 12                    printfest  None   79139406578
#
#                                           description            timezone  \
# 0   Restored from recycled, since consumed moretha...       Europe/Moscow
# 1   Restored from recycled, since consumed moretha...       Europe/Moscow
# 2   Restored from recycled, since consumed moretha...  Asia/Yekaterinburg
# 3   Restored from recycled, since consumed moretha...       Europe/Moscow
# 4   Restored from recycled, since consumed moretha...    Asia/Novosibirsk
# 5   Restored from recycled, since consumed moretha...       Europe/Moscow
# 6   Restored from recycled, since consumed moretha...       Europe/Moscow
# 7   Restored from recycled, since consumed moretha...       Europe/Moscow
# 8   Restored from recycled, since consumed moretha...       Europe/Moscow
# 9   Restored from recycled, since consumed moretha...       Europe/Moscow
# 10  Restored from recycled, since consumed moretha...       Europe/Moscow
# 11  Restored from recycled, since consumed moretha...       Europe/Moscow
# 12  Restored from recycled, since consumed moretha...    Asia/Novosibirsk
#
#       status                                      lead_source lead_priority  \
# 0   Recycled  Potential candidate for 30k over 28 days period        Medium
# 1   Recycled  Potential candidate for 30k over 28 days period        Medium
# 2   Recycled  Potential candidate for 30k over 28 days period        Medium
# 3   Recycled  Potential candidate for 30k over 28 days period        Medium
# 4   Recycled  Potential candidate for 30k over 28 days period        Medium
# 5   Recycled  Potential candidate for 50k over 28 days period        Medium
# 6   Recycled  Potential candidate for 50k over 28 days period        Medium
# 7   Recycled  Potential candidate for 30k over 28 days period        Medium
# 8   Recycled  Potential candidate for 30k over 28 days period        Medium
# 9   Recycled  Potential candidate for 30k over 28 days period        Medium
# 10  Recycled  Potential candidate for 30k over 28 days period        Medium
# 11  Recycled  Potential candidate for 30k over 28 days period        Medium
# 12  Recycled  Potential candidate for 30k over 28 days period        Medium
#
#       user_name                          email lead_source_crm last_status
# 0   m-pisarenko  reshetnik-ecaterina@yandex.ru          upsell    Recycled
# 1   m-pisarenko  reshetnik.ecaterina@yandex.ru          upsell    Recycled
# 2      dmayudin               cto@sport-pay.ru          upsell    Recycled
# 3       ipivnev           iwan-lebed@yandex.ru          upsell    Recycled
# 4   m-pisarenko            support@minebet.com          upsell    Recycled
# 5   m-pisarenko  schaihetdinov-marat@yandex.ru          upsell    Recycled
# 6   m-pisarenko  schaihetdinov.marat@yandex.ru          upsell    Recycled
# 7   askryuchkov            a-hismith@yandex.ru          upsell    Recycled
# 8   askryuchkov               krukovets@bfs.su          upsell    Recycled
# 9       ipivnev             tips-uit@yandex.ru          upsell    Recycled
# 10      ipivnev                   it@likebg.ru          upsell    Recycled
# 11  m-pisarenko             solsidus@yandex.ru          upsell    Recycled
# 12      gadirov       printfestcloud@yandex.ru          upsell    Recycled

# %%
def get_current_upsell_staff_logins(spark):
    staff_info_path = '//home/cloud-dwh/data/prod/ods/staff/persons'
    staff_pii_info_path = '//home/cloud-dwh/data/prod/ods/staff/PII/persons'
    current_staff = (
        spark.read.yt(staff_info_path)
        .join(
            spark.read.yt(staff_pii_info_path),
            on='staff_user_id', how='left'
        )
        .filter(col('department_id').isin([16682, 13473]))
        .filter(~col('official_is_dismissed'))
        .select('staff_user_login')
    )
    staff_list = current_staff.toPandas()['staff_user_login'].tolist()
    return staff_list

contact_info_path = '//home/cloud_analytics/import/crm/leads/contact_info'
spdf_contacts = spark.read.yt(contact_info_path)
leads_timestamp = int((datetime.now()+timedelta(hours=3)).timestamp())  # adapting to Moscow timezone (on system is UTC+0)
actual_logins = get_current_upsell_staff_logins(spark)

spdf_res_leads = (
    spdf_res
    .join(spdf_contacts, on=['billing_account_id'], how="left")
    .withColumn('null_prev_names', spdf_res.first_name.isNull() & spdf_res.last_name.isNull())
    .withColumn('crm_phone', F.regexp_replace(spdf_res.phone, '[+\\-\\s\\(\\)]', ''))
    .select(
        lit(leads_timestamp).alias('Timestamp'),
        lit(None).astype('string').alias('CRM_Lead_ID'),
        F.concat(lit('["'), "billing_account_id", lit('"]')).alias("Billing_account_id"),
        lit(None).astype('string').alias('Status'),
        col('description').alias('Description'),
        F.when(col('user_name').isin(actual_logins), col('user_name')).otherwise(lit('admin')).alias('Assigned_to'),
        F.when(col('null_prev_names'), spdf_contacts.first_name).otherwise(spdf_res.first_name).alias('First_name'),
        F.when(col('null_prev_names'), spdf_contacts.last_name).otherwise(spdf_res.last_name).alias('Last_name'),
        spdf_contacts.phone.alias('Phone_1'),
        F.when(spdf_contacts.phone==col('crm_phone'), lit(None).astype('string')).otherwise(col('crm_phone')).alias('Phone_2'),
        spdf_res.email.alias('Email'),
        lit('upsell').alias('Lead_Source'),
        col('lead_source').alias('Lead_Source_Description'),
        lit(None).astype('string').alias('Callback_date'),
        lit(None).astype('string').alias('Last_communication_date'),
        lit(None).astype('string').alias('Promocode'),
        lit(None).astype('string').alias('Promocode_sum'),
        lit(None).astype('string').alias('Notes'),
        lit(None).astype('string').alias('Dimensions'),
        lit(None).astype('string').alias('Tags'),
        lit('').alias('Timezone'),
        col("display_name").alias('Account_name')
    )
)

spdf_res_leads.toPandas()
# Out:
#      Timestamp CRM_Lead_ID        Billing_account_id Status  \
# 0   1644263631        None  ["dn2n9j7q5h8hv1unjvh1"]   None
# 1   1644263631        None  ["dn2qbr3hb10t6l3sis6i"]   None
# 2   1644263631        None  ["dn2ivhgierstat7570t6"]   None
# 3   1644263631        None  ["dn2eht2pbri1plgtldl3"]   None
# 4   1644263631        None  ["dn2kbppkbeacsck5n6dv"]   None
# 5   1644263631        None  ["dn20k53ptrc5nvh4hqlr"]   None
# 6   1644263631        None  ["dn2k17tluvqbeip2nclb"]   None
# 7   1644263631        None  ["dn2k17tluvqbeip2nclb"]   None
# 8   1644263631        None  ["dn2qk8bmmo4gm6ssudv0"]   None
# 9   1644263631        None  ["dn28h691n944hfqfe8f7"]   None
# 10  1644263631        None  ["dn28u5fiq1pbl47tol5r"]   None
# 11  1644263631        None  ["dn28u5fiq1pbl47tol5r"]   None
# 12  1644263631        None  ["dn2ai7epnn4r2thoj1k6"]   None
#
#                                           Description  Assigned_to First_name  \
# 0   Restored from recycled, since consumed moretha...        admin      Админ
# 1   Restored from recycled, since consumed moretha...        admin       Иван
# 2   Restored from recycled, since consumed moretha...      gadirov  Александр
# 3   Restored from recycled, since consumed moretha...     dmayudin       Юрий
# 4   Restored from recycled, since consumed moretha...        admin       None
# 5   Restored from recycled, since consumed moretha...        admin     Ксения
# 6   Restored from recycled, since consumed moretha...  m-pisarenko  Екатерина
# 7   Restored from recycled, since consumed moretha...  m-pisarenko  Екатерина
# 8   Restored from recycled, since consumed moretha...  m-pisarenko    Support
# 9   Restored from recycled, since consumed moretha...  m-pisarenko     Сергей
# 10  Restored from recycled, since consumed moretha...  m-pisarenko      Марат
# 11  Restored from recycled, since consumed moretha...  m-pisarenko      Марат
# 12  Restored from recycled, since consumed moretha...        admin      Артём
#
#          Last_name      Phone_1      Phone_2                          Email  \
# 0          Хайсмит  79165707929         None            a-hismith@yandex.ru
# 1           Лебедь  79057471804         None           iwan-lebed@yandex.ru
# 2            Зобов  79139406578         None       printfestcloud@yandex.ru
# 3       Киберспорт  79689755854         None               cto@sport-pay.ru
# 4   ИП Белов М. А.  79150349022         None                   it@likebg.ru
# 5        Бухгалтер  79251738482         None             tips-uit@yandex.ru
# 6         Решетник  79254099451         None  reshetnik-ecaterina@yandex.ru
# 7         Решетник  79254099451         None  reshetnik.ecaterina@yandex.ru
# 8          MineBet  79139227503         None            support@minebet.com
# 9          Новиков  79164154710         None             solsidus@yandex.ru
# 10     Шайхетдинов  79179349352  79372920862  schaihetdinov-marat@yandex.ru
# 11     Шайхетдинов  79179349352  79372920862  schaihetdinov.marat@yandex.ru
# 12        Круковец  79629316108         None               krukovets@bfs.su
#
#    Lead_Source                          Lead_Source_Description Callback_date  \
# 0       upsell  Potential candidate for 30k over 28 days period          None
# 1       upsell  Potential candidate for 30k over 28 days period          None
# 2       upsell  Potential candidate for 30k over 28 days period          None
# 3       upsell  Potential candidate for 30k over 28 days period          None
# 4       upsell  Potential candidate for 30k over 28 days period          None
# 5       upsell  Potential candidate for 30k over 28 days period          None
# 6       upsell  Potential candidate for 30k over 28 days period          None
# 7       upsell  Potential candidate for 30k over 28 days period          None
# 8       upsell  Potential candidate for 30k over 28 days period          None
# 9       upsell  Potential candidate for 30k over 28 days period          None
# 10      upsell  Potential candidate for 50k over 28 days period          None
# 11      upsell  Potential candidate for 50k over 28 days period          None
# 12      upsell  Potential candidate for 30k over 28 days period          None
#
#    Last_communication_date Promocode Promocode_sum Notes Dimensions  Tags  \
# 0                     None      None          None  None       None  None
# 1                     None      None          None  None       None  None
# 2                     None      None          None  None       None  None
# 3                     None      None          None  None       None  None
# 4                     None      None          None  None       None  None
# 5                     None      None          None  None       None  None
# 6                     None      None          None  None       None  None
# 7                     None      None          None  None       None  None
# 8                     None      None          None  None       None  None
# 9                     None      None          None  None       None  None
# 10                    None      None          None  None       None  None
# 11                    None      None          None  None       None  None
# 12                    None      None          None  None       None  None
#
#    Timezone                                       Account_name
# 0             Общество с Ограниченной Ответственностью ХАЙСМИТ
# 1            Фонд поддержки инновационных программ «Образов...
# 2            ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФАБР...
# 3            ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ «КИБЕ...
# 4            Индивидуальный предприниматель Белов Максим Ал...
# 5                                                  Umbrella IT
# 6                                    Михаил Андреевич Веденеев
# 7                                    Михаил Андреевич Веденеев
# 8                                  Константин Викторович Богер
# 9                                     Сергей Сергеевич Новиков
# 10           Общество с ограниченной ответственностью "Серв...
# 11           Общество с ограниченной ответственностью "Серв...
# 12                                            ООО "АТМ Маркет"

# %% [markdown]
# ### top_cunsomers

# %%
spdf_res = Generate_CSM_Leads(spark,
                              yt_adapter,
                              consumption_threshold=40000,
                              days_period=30).top_cunsomers()

df_fr = spdf_res.toPandas()
print(df_fr.shape)
df_fr
# Out:
# Loaded BAs with consumption exceeded 40000 RUB in 30 days period: 129 row(s)
# (7, 3)
#      billing_account_id     paid_cons  \
# 0  dn27beosenkq8rqaecsg  44360.259435
# 1  dn2eu2t9aan486dih9qf  46412.544205
# 2  dn2edncqd067knrv4j4s  95763.816960
# 3  dn24urb66ogmnf0bmdd1  45256.555887
# 4  dn27kgiqkgoar0peks2l  43040.425642
# 5  dn29pbfcvt99lj5f9708  84030.954340
# 6  dn244ju40phs755rvvs9  44068.451944
#
#                                          description
# 0  Account "dn27beosenkq8rqaecsg" has consumption...
# 1  Account "dn2eu2t9aan486dih9qf" has consumption...
# 2  Account "dn2edncqd067knrv4j4s" has consumption...
# 3  Account "dn24urb66ogmnf0bmdd1" has consumption...
# 4  Account "dn27kgiqkgoar0peks2l" has consumption...
# 5  Account "dn29pbfcvt99lj5f9708" has consumption...
# 6  Account "dn244ju40phs755rvvs9" has consumption...

# %%
exclude_csm_leads = '//home/cloud_analytics/ml/scoring/consumption_predictor_v2/crm/upsell/csm_history_test'
contact_info_path = '//home/cloud_analytics/import/crm/leads/contact_info'
spdf_contacts = spark.read.yt(contact_info_path)
leads_timestamp = int((datetime.now()+timedelta(hours=3)).timestamp())  # adapting to Moscow timezone (on system is UTC+0)

leads_to_exclude = (
    spark.read.yt(exclude_csm_leads)
    .select(F.regexp_replace('Billing_account_id', r'[\[\]"]', '').alias('billing_account_id'))
    .distinct()
)

spdf_res_leads = (
    spdf_res
    .join(spdf_contacts, on='billing_account_id', how="left")
    .join(leads_to_exclude, on='billing_account_id', how="leftanti")
    .select(
        lit(leads_timestamp).alias('Timestamp'),
        lit(None).astype('string').alias('CRM_Lead_ID'),
        F.concat(lit('["'), "billing_account_id", lit('"]')).alias("Billing_account_id"),
        lit(None).astype('string').alias('Status'),
        col('description').alias('Description'),
        lit('admin').alias('Assigned_to'),
        col('first_name').alias('First_name'),
        col('last_name').alias('Last_name'),
        col('phone').alias('Phone_1'),
        lit(None).astype('string').alias('Phone_2'),
        col('email').alias('Email'),
        lit('upsell').alias('Lead_Source'),
        lit('Consumed more than 40k over last 30 days').alias('Lead_Source_Description'),
        lit(None).astype('string').alias('Callback_date'),
        lit(None).astype('string').alias('Last_communication_date'),
        lit(None).astype('string').alias('Promocode'),
        lit(None).astype('string').alias('Promocode_sum'),
        lit(None).astype('string').alias('Notes'),
        lit(None).astype('string').alias('Dimensions'),
        lit(None).astype('string').alias('Tags'),
        lit('').alias('Timezone'),
        col("display_name").alias('Account_name')
    )
)

spdf_res_leads.toPandas()
# Out:
#     Timestamp CRM_Lead_ID        Billing_account_id Status  \
# 0  1644263834        None  ["dn2edncqd067knrv4j4s"]   None
# 1  1644263834        None  ["dn29pbfcvt99lj5f9708"]   None
# 2  1644263834        None  ["dn244ju40phs755rvvs9"]   None
#
#                                          Description Assigned_to First_name  \
# 0  Account "dn2edncqd067knrv4j4s" has consumption...       admin       None
# 1  Account "dn29pbfcvt99lj5f9708" has consumption...       admin       None
# 2  Account "dn244ju40phs755rvvs9" has consumption...       admin       None
#
#           Last_name      Phone_1 Phone_2                        Email  \
# 0           NOP RTK  79056658899    None             noprtk@yandex.ru
# 1  ООО «12 историй»  79775026184    None  a.mokronosova@12storeez.com
# 2                ТК  89090020880    None    aleksandr.sabirov@gt-m.ru
#
#   Lead_Source                   Lead_Source_Description Callback_date  \
# 0      upsell  Consumed more than 40k over last 30 days          None
# 1      upsell  Consumed more than 40k over last 30 days          None
# 2      upsell  Consumed more than 40k over last 30 days          None
#
#   Last_communication_date Promocode Promocode_sum Notes Dimensions  Tags  \
# 0                    None      None          None  None       None  None
# 1                    None      None          None  None       None  None
# 2                    None      None          None  None       None  None
#
#   Timezone                                       Account_name
# 0                                                     NOP RTK
# 1           Общество с ограниченной ответственностью «12 и...
# 2                                                 ООО "ГТ ИТ"
