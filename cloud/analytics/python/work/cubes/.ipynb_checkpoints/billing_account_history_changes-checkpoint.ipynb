# %%
import pandas as pd, datetime, ast, numpy as np, telebot, json, requests, os, sys, pymysql
module_path = os.path.abspath(os.path.join('/home/ktereshin/yandex/arcadia/cloud/analytics/python/work'))
if module_path not in sys.path:
    sys.path.append(module_path)
from nile.api.v1 import (
    clusters,
    aggregators as na,
    extractors as ne,
    filters as nf,
    Record
)
from vault_client import instances

from global_variables import (
    metrika_clickhouse_param_dict,
    cloud_clickhouse_param_dict
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-00d2a2ac2f9e> in <module>()
# ----> 1 import pandas as pd, datetime, ast, numpy as np, telebot, json, requests, os, sys, pymysql
#       2 module_path = os.path.abspath(os.path.join('/home/ktereshin/yandex/arcadia/cloud/analytics/python/work'))
#       3 if module_path not in sys.path:
#       4     sys.path.append(module_path)
#       5 from nile.api.v1 import (
#
# ImportError: No module named pymysql

# %%
client = instances.Production()
yt_creds = client.get_version('ver-01d33pgv8pzc7t99s3egm24x47')
crm_sql_creds = client.get_version('ver-01d3ktedjm6ptsvwf1xq161hwk')
metrika_creds = client.get_version('ver-01d2z36msatt9mp9pcfptezksp')
yc_ch_creds = client.get_version('ver-01d2z39xj02xw7gqvv9wq757ne')

cluster = clusters.yt.Hahn(
    token = yt_creds['value']['token'],
    pool = yt_creds['value']['pool']
)
metrika_clickhouse_param_dict['user'] = metrika_creds['value']['login']
metrika_clickhouse_param_dict['password'] = metrika_creds['value']['pass']

cloud_clickhouse_param_dict['user'] = yc_ch_creds['value']['login']
cloud_clickhouse_param_dict['password'] = yc_ch_creds['value']['pass']

# %%
paths_dict_test = {
    'calls': '//home/cloud_analytics_test/cooking_cubes/crm_leads/calls',
    'leads_history': '//home/cloud_analytics_test/cooking_cubes/crm_leads/leads_history',
    'event_cube': '//home/cloud_analytics_test/cubes/acquisition_cube/cube',
    'crm_leads_cube': '//home/cloud_analytics_test/cubes/crm_leads/cube'
}
paths_dict_prod = {
    'calls': '//home/cloud_analytics/cooking_cubes/crm_leads/calls',
    'leads_history': '//home/cloud_analytics/cooking_cubes/crm_leads/leads_history',
    'event_cube': '//home/cloud_analytics/cubes/acquisition_cube/cube',
    'crm_leads_cube': '//home/cloud_analytics/cubes/crm_leads/cube'
}

mode = 'test'
if mode == 'test':
    paths_dict = paths_dict_test
elif mode == 'prod':
    paths_dict = paths_dict_prod

# %%
sales_dict = {
    'golubin': 'enterprise',
    'dtishin': 'enterprise',
    'mpolikarpova': 'isv',
    'mvoytko': 'isv',
    'ntkachev': 'isv',
    'dtishin': 'enterprise',
    'mashmellow': 'yandex',
    'glebmarkevich': 'mass',
    'andreigusev': 'isv'
}

# %%
sales_dict = {
    'dmtroe': 'mass',
    'la-n': 'mass',
    'anbalu': 'mass',
    'glebmarkevich': 'csm',
    'golubin': 'enterprise',
    'niktk': 'isv',
    'voytko': 'isv',
    'datishin': 'enterprise',
    'mblagutin': 'mass',
    'andreigusev': 'isv',
    'marinapolik': 'isv',
    'timag': 'mass',
    'mashmellow': 'yandex'
}

# %%
cnx = pymysql.connect(user='readonly', password=crm_sql_creds['value']['readonly'],
                              host='percona.prod.ya-cloud-crm.stable.qloud-d.yandex.net',
                              port = 5678,
                              database='cloud8'
                             )

query = '''
SELECT
    IFNULL(accounts.id,'') account_id,
    IFNULL(accounts.ba_id,'') billing_account_id,
    accounts.date_entered account_created_at,
    IFNULL(accounts.name,'') account_name,
    IFNULL(accounts.description,'') account_description,
    IFNULL(accounts.account_type,'') account_type,
    IFNULL(l1.status,'') account_status,
    IFNULL(l1.user_name,'') sales_name,
    IFNULL(accounts.segment,'') accounts_segment
FROM accounts
INNER JOIN users l1
ON accounts.assigned_user_id=l1.id AND l1.deleted=0
WHERE
     accounts.deleted=0 
'''

accounts = pd.read_sql_query(query, cnx)
cnx.close()

# %%
accounts[accounts['billing_account_id'] != '']
# Out:
#                                account_id    billing_account_id  \
# 2    024e5f96-5083-11e9-a310-e0fc2c762fc2  dn24rksev9on2bb8jqd0
# 12   046f6e86-4c97-11e9-8946-d4197eff0c7e  dn2i85qaju401hoq3if4
# 22   0783a5a4-496f-11e9-a097-8e64c482fb7d  dn2tmas5odfq7h0h4ms1
# 23   08064228-459d-11e9-9be7-1e90c927451e  dn2rj84tqlc2p7t8fi8n
# 26   09941eca-4b07-11e9-9da1-e225f8fec9aa  dn26i44mp7k1ab9kbisp
# 28   0a3c0a0e-4a26-11e9-ace4-9ad2bc3ace24  dn22ron6bs90dpsngg37
# 31   0ac55ae2-4b17-11e9-b0af-8b12437172c1  dn2u2lpiguafkvh35off
# 33   0b9eaae2-5097-11e9-9b8c-f32795bb3bdb  dn2lgpv6pu597rtjrsrp
# 34   0bcfcb4e-4a44-11e9-8076-26ca05f980b2  dn2dr0b8capanbvab2e5
# 35   0c471c94-43e6-11e9-8810-51563a6143a8  dn2qaqb3h09si6fd4lr8
# 38   0c81c76c-44dc-11e9-9a55-a2299c955b66  dn21m4ffgph98hh8laes
# 41   0d76d9bc-4411-11e9-baa6-82d03dd73c75  dn2mj4bnh0erk0b7s9op
# 42   0d977e0c-5167-11e9-a2a1-6da5a352b6e4  dn24qp6crvlkhpkn0k91
# 45   1038a65c-40d9-11e9-8c58-1bdf7b5f3efc  dn24ga8lijapc38e8ct5
# 55   14033792-3f1d-11e9-9e60-9e6efd9ce848  dn2gkut5b6101u388cn9
# 95   1413d6ba-bcd0-11e8-9b2f-1db431d8a7bd  dn2vrs1e4gdfoocb6r0n
# 123  14e2b8b2-508f-11e9-a490-ed4695af4e3e  dn2b9v2qr3gc7cbkbmjv
# 125  1597ef1a-4b1d-11e9-96ea-eb1b905454ea  dn2rt5hg2lepb1bm7ho1
# 126  1766aca4-4411-11e9-a0b7-d4e8f2f3a5d8  dn2dis8th7q0j5nsl51t
# 127  177bd0fc-44cf-11e9-bc00-b8362212b52d  dn20nr22cq7r3ksslnaj
# 128  18eff784-4bea-11e9-9d10-db943990fd50  dn225or63pgck1dp0066
# 132  19c89ae0-4fc7-11e9-921f-6bbbdb5f6624  dn20cbpnr66uaf5oq9nf
# 135  1aab120c-4a46-11e9-980c-489c12e319a8  dn2t251i5mo27lnrobur
# 702 2019-03-14 12:22:55  ООО "МОСКОВСКИЙ ЗАВОД "ФИЗПРИБОР"
# 703 2019-02-04 14:48:08             ООО "ИДЕАЛ ПЛМ СИАЙЭС"
# 709 2019-03-25 09:53:54                 Бондаренко Ярослав
# 711 2019-03-25 14:33:06                     Швец Александр
# 718 2019-03-12 12:18:13             НиколайКудасов Николай
# 727 2019-03-18 13:29:55                    Filatov Dmitriy
# 731 2019-03-05 11:29:24                  ООО "КВИЗ, ПЛИЗ!"
# 734 2019-03-22 11:09:14                         Орлов Иван
# 737 2019-03-18 07:17:46                 Скшидлевский Антон
# 738 2019-03-25 12:10:08   ООО "ГК "ТЕХНОЛОГИИ АВТОСЕРВИСА"
# 739 2019-02-04 14:41:14                         ООО "ЯСНО"
# 750 2019-03-17 20:48:00                          ООО "МПМ"
# 757 2019-03-17 17:27:39                  Дедегкаев Заурбек
# 761 2019-03-28 10:12:18                   Вечканов Алексей
# 770 2019-03-18 14:56:16                       ООО "ВЕКТОР"
# 771 2019-03-19 11:48:58                   Боровков Дмитрий
# 772 2019-03-25 12:24:48                ООО "НАЛОГИ ОНЛАЙН"
# 776 2019-03-27 12:22:28                   Кодинцев Алексей
# 781 2019-01-29 11:28:24                          Set sales
# 782 2019-03-27 13:34:06                       Слотин Игорь
#
#                                    account_description account_type  \
# 2                                                          Customer
# 12                                       company trial     Customer
# 22                                                         Customer
# 23                                                         Customer
# 26                                                         Customer
# 28                                                         Customer
# 31                                                         Customer
# 33   pk@jalinga.ru\tООО ЦифраЛаб\t0\teducation\tРос...     Customer
# 34                                                         Customer
# 35                                                         Customer
# 38                 end_date 16,03,2019;total_cost 1162     Customer
# 41                                                         Customer
# 42                                                         Customer
# 45                                                         Customer
# 55                                                         Customer
# 95                                                         Customer
# 123                                                        Customer
# 125                        last_week_consumed 1314 руб     Customer
# 126  dn2dis8th7q0j5nsl51t end_date 19/02/2019 total...     Customer
# 127             end_date 15,03,2019;total_cost 2047,92     Customer
# 128                                                        Customer
# 132                                                        Customer
# 135                                                        Customer
# 136                                      company trial     Customer
# 140                                                        Customer
# 149  Подскажите пожалуйста, как указать класс храни...     Customer
# 154                                                        Customer
# 170                                                        Customer
# 171                                                        Customer
# 174                                      company trial     Customer
# ..                                                 ...          ...
# 669                    cost 302,89;cost_last_7d 180,12     Customer
# 670             end_date 18,03,2019;total_cost 2599,04     Customer
# 675                                                        Customer
# 678                                   h1_snapshot_test     Customer
# 679                                                        Customer
# 692                                                        Customer
# 697                                                        Customer
# 698                                                        Customer
# 699                                                        Customer
# 700                                                        Customer
# 702                                                        Customer
# 703                                                        Customer
# 709                                                        Customer
# 711  diospa@yandex.ru\tМосква\tbuilding\tООО Техстр...     Customer
# 718             end_date 16,03,2019;total_cost 3999,56     Customer
# 727                                   h1_snapshot_test     Customer
# 731                                                        Customer
# 734                                                        Customer
# 737                                                        Customer
# 738                                                        Customer
# 739                                                        Customer
# 750                                                        Customer
# 757                                                        Customer
# 761                                                        Customer
# 770                                      company trial     Customer
# 771                                                        Customer
# 772                                                        Customer
# 776                                                        Customer
# 781                                                        Customer
# 782                                                        Customer
#
#     account_status     sales_name accounts_segment
# 2           Active           la-n              smb
# 12          Active           la-n              smb
# 22          Active           la-n              smb
# 23          Active         dmtroe              smb
# 26          Active           la-n              smb
# 28          Active         dmtroe              smb
# 31          Active         dmtroe              smb
# 33          Active         dmtroe              smb
# 34          Active         dmtroe              smb
# 35          Active           la-n              smb
# 38          Active           la-n              smb
# 41          Active           la-n              smb
# 42          Active         anbalu              smb
# 45          Active           la-n              smb
# 55          Active         dmtroe              smb
# 95          Active  glebmarkevich           middle
# 123         Active         anbalu              smb
# 125         Active           la-n              smb
# 126         Active         anbalu              smb
# 127         Active           la-n              smb
# 128         Active           la-n              smb
# 132         Active         anbalu              smb
# 135         Active           la-n              smb
# 136         Active         dmtroe              smb
# 140         Active         anbalu              smb
# 149         Active         dmtroe              smb
# 154         Active           la-n              smb
# 170         Active    andreigusev           middle
# 171         Active         anbalu              smb
# 174         Active           la-n              smb
# ..             ...            ...              ...
# 669         Active         dmtroe              smb
# 670         Active         dmtroe              smb
# 675         Active           la-n              smb
# 678         Active         dmtroe              smb
# 679         Active  glebmarkevich              smb
# 692         Active         anbalu              smb
# 697         Active           la-n              smb
# 698         Active         anbalu              smb
# 699         Active           la-n              smb
# 700         Active         anbalu              smb
# 702         Active       datishin       enterprise
# 703         Active  glebmarkevich           middle
# 709         Active           la-n              smb
# 711         Active         dmtroe              smb
# 718         Active           la-n              smb
# 727         Active           la-n              smb
# 731         Active  glebmarkevich              smb
# 734         Active           la-n              smb
# 737         Active         dmtroe              smb
# 738         Active         anbalu              smb
# 739         Active  glebmarkevich              smb
# 750         Active         anbalu              smb
# 757         Active         anbalu              smb
# 761         Active         anbalu              smb
# 770         Active         anbalu              smb
# 771         Active           la-n              smb
# 772         Active         anbalu              smb
# 776         Active           la-n              smb
# 781         Active  glebmarkevich           middle
# 782         Active         dmtroe              smb
#
# [185 rows x 9 columns]

# %%
accounts['sales_name'].unique()
# Out:
# array(['dmtroe', 'la-n', 'anbalu', 'glebmarkevich', 'golubin', 'niktk',
#        'voytko', 'datishin', 'mblagutin', 'andreigusev', 'marinapolik',
#        'timag', 'mashmellow'], dtype=object)

# %%
cnx = pymysql.connect(user='readonly', password=crm_sql_creds['value']['readonly'],
                              host='percona.prod.ya-cloud-crm.stable.qloud-d.yandex.net',
                              port = 5678,
                              database='cloud8'
                             )

query = '''
SELECT
    acc_hist.parent_id as account_id,
    date_created,
    after_value_string as assigned_by,
    IFNULL(l1.user_name,'') sales_name,
    acc.segment as account_segment,
    IFNULL(acc.name,'') account_name
FROM accounts_audit as acc_hist
LEFT JOIN users l1
ON acc_hist.after_value_string=l1.id AND l1.deleted=0
LEFT JOIN accounts as acc
ON acc_hist.parent_id=acc.id AND acc.deleted=0
WHERE
    field_name = 'assigned_user_id'
'''

test = pd.read_sql_query(query, cnx)
cnx.close()

# %%
test
# Out:
#                                account_id        date_created  \
8ae82e2-ad14-11e8-a0c4-5343ab2a9cb3         dmtroe             smb
# 24   f90fa4bc-b276-11e8-9fcf-aef1db86a4fe         voytko      enterprise
# 25   b8ae82e2-ad14-11e8-a0c4-5343ab2a9cb3         dmtroe             smb
# 26   9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 27   a88d1b78-eda4-11e8-84e3-c64f3ce41c5c  glebmarkevich          middle
# 28   2d33e822-1a30-11e9-8330-2571314e3f8c           la-n             smb
# 29   b8ae82e2-ad14-11e8-a0c4-5343ab2a9cb3         dmtroe             smb
# ..                                    ...            ...             ...
# 815  eeae9dfc-b4d3-11e8-9ba5-4e7cfd79c459    marinapolik      enterprise
# 816  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 817  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 818  a81c63fe-c001-11e8-8556-21ea7ab4930a          niktk             smb
# 819  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 820  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 821  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 822  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 823  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 824  60cd95e6-bcb8-11e8-b8eb-6aeff93c1ed6        golubin      enterprise
# 825  b8ae82e2-ad14-11e8-a0c4-5343ab2a9cb3         dmtroe             smb
# 826  9fcffed6-b273-11e8-be78-46766b7d8163       datishin      enterprise
# 827  a81c63fe-c001-11e8-8556-21ea7ab4930a          niktk      enterprise
# 828  eeae9dfc-b4d3-11e8-9ba5-4e7cfd79c459    marinapolik      enterprise
# 829  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 830  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 831  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 832  2d33e822-1a30-11e9-8330-2571314e3f8c           la-n             smb
# 833  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 834  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be         anbalu             smb
# 835  eeae9dfc-b4d3-11e8-9ba5-4e7cfd79c459    marinapolik          middle
# 836  eeae9dfc-b4d3-11e8-9ba5-4e7cfd79c459    marinapolik      enterprise
# 837  9fcffed6-b273-11e8-be78-46766b7d8163       datishin      enterprise
# 838  2d33e822-1a30-11e9-8330-2571314e3f8c           la-n             smb
# 839  eeae9dfc-b4d3-11e8-9ba5-4e7cfd79c459    marinapolik      enterprise
# 840  a88d1b78-eda4-11e8-84e3-c64f3ce41c5c  glebmarkevich          middle
# 841  a88d1b78-eda4-11e8-84e3-c64f3ce41c5c  glebmarkevich          middle
# 842  2d33e822-1a30-11e9-8330-2571314e3f8c           la-n             smb
# 843  2d33e822-1a30-11e9-8330-2571314e3f8c           la-n             smb
# 844  b8ae82e2-ad14-11e8-a0c4-5343ab2a9cb3         dmtroe             smb
#
#                            account_name
# 0                             Set sales
# 1                           Ртищев Иван
# 2                         ИКЕА ДОМ, ООО
# 3                          ООО "ВИННЕР"
# 4                    Чесноков Александр
# 5                        ООО "ДСП ЛАБС"
# 6                               Marilyn
# 7                           Esin Andrey
# 8                        Головина Дарья
# 9                   ФГУП "ПОЧТА РОССИИ"
# 10                        ООО "АРИАДНА"
# 11              ООО "СВГК" VAR Вебзавод
# 12   ГАЗПРОМНЕФТЬ-АЭРО ШЕРЕМЕТЬЕВО, ООО
# 13                  АО "ДХЛ ИНТЕРНЕШНЛ"
# 14                             ООО "1С"
# 15                              А2, ООО
# 16                         ООО "Адварк"
# 17                         Лидер-Инвест
# 18                        ООО "ПФАЙЗЕР"
# 19                      Новиков Дмитрий
# 20                     ООО "ТЕМП РОСТА"
# 21               ДЖОНСОН & ДЖОНСОН, ООО
# 22                         Зубов Сергей
# 23                   Аверичев Александр
# 24                      ООО "ЛИНГУАЛЕО"
# 25                    ООО "БАЗИС-ЦЕНТР"
# 26                      Быханов Дмитрий
# 27                               time21
# 28                          M Станислав
# 29                     ООО "ГРУППА ЛАД"
# ..                                  ...
# 815                              Кловер
# 816                   Дедегкаев Заурбек
# 817                ООО "КОЛТАЧ СОЛЮШНС"
# 818                ООО "КОЛТАЧ СОЛЮШНС"
# 819                    Васильев Дмитрий
# 820                    Раинский Дмитрий
# 821                    Вечканов Алексей
# 822                ООО "МЕБЕЛЬ ЛИБЕРТИ"
# 823    ИП Елизаров Максим Владиславович
# 824       ТД ЧЕРКИЗОВО, ООО / Черкизово
# 825           Хмара Александр Сергеевич
# 826                      ВТБ ЛИЗИНГ, АО
# 827                   АО "ЛИДЕР-ИНВЕСТ"
# 828                           Сейсмотек
# 829              ООО "ИДЕАЛ ПЛМ СИАЙЭС"
# 830                     ООО "СК КАРДИФ"
# 831                        ООО "ВЕКТОР"
# 832                    Боровков Дмитрий
# 833                 ООО "НАЛОГИ ОНЛАЙН"
# 834                     Хмара Александр
# 835               ООО "СИБЛИОН"/Siblion
# 836                 АНО "БОЛЬШОЙ МУЗЕЙ"
# 837                            РЖД, ОАО
# 838                    Кодинцев Алексей
# 839                              РТСОФТ
# 840               ООО "СИБЛИОН"/Siblion
# 841                           ФСК Лидер
# 842                         ООО "Хабер"
# 843                          Linov Dima
# 844                        Слотин Игорь
#
# [845 rows x 6 columns]

# %%
test.groupby(['sales_name', 'account_segment'])['account_id'].nunique().reset_index()
# Out:
#        sales_name account_segment  account_id
# 0                      enterprise           2
# 1                             smb           1
# 2          anbalu             smb         213
# 3     andreigusev      enterprise          16
# 4     andreigusev          middle          10
# 5     andreigusev             smb           1
# 6        datishin      enterprise          58
# 7        datishin          middle           4
# 8        datishin             smb           1
# 9          dmtroe      enterprise           1
# 10         dmtroe             smb         193
# 11  glebmarkevich      enterprise           1
# 12  glebmarkevich          middle          39
# 13  glebmarkevich             smb          32
# 14        golubin      enterprise          38
# 15        golubin          middle           4
# 16           la-n          middle           1
# 17           la-n             smb         121
# 18    marinapolik      enterprise          24
# 19    marinapolik          middle           6
# 20    marinapolik             smb           1
# 21     mashmellow          middle           1
# 22      mblagutin      enterprise           1
# 23      mblagutin             smb           2
# 24          niktk      enterprise           6
# 25          niktk          middle           9
# 26          niktk             smb          15
# 27          timag      enterprise           1
# 28          timag             smb           1
# 29         voytko      enterprise          21
# 30         voytko          middle           3
# 31         voytko             smb           2

# %%
test[test['account_id'] == 'bed822ac-f8a7-11e8-81bc-8621a2ea9fac']
# Out:
#                                account_id        date_created  \
# 608  bed822ac-f8a7-11e8-81bc-8621a2ea9fac 2018-12-05 16:06:37
#
#                               assigned_by sales_name account_segment  \
# 608  d13ba564-bdb4-11e8-99bc-6355dc8c759d  mblagutin             smb
#
#         account_name
# 608  ФАРМПЕРСПЕКТИВА

# %%
test[(test['sales_name'] == 'mblagutin')]
# Out:
#                                account_id        date_created  \
# 31   08c3e336-080e-11e9-9378-d3f6ca96c046 2018-12-25 06:26:37
# 367  76078808-d8ed-11e8-9174-ea7b61f4791d 2018-10-26 07:05:03
# 608  bed822ac-f8a7-11e8-81bc-8621a2ea9fac 2018-12-05 16:06:37
#
#                               assigned_by sales_name account_segment  \
# 31   d13ba564-bdb4-11e8-99bc-6355dc8c759d  mblagutin             smb
# 367  d13ba564-bdb4-11e8-99bc-6355dc8c759d  mblagutin      enterprise
# 608  d13ba564-bdb4-11e8-99bc-6355dc8c759d  mblagutin             smb
#
#               account_name
# 31   ИВ РОШЕ (Yves Rocher)
# 367              Илим палп
# 608        ФАРМПЕРСПЕКТИВА
