# %%
import pandas as pd, datetime, ast, os,sys, pymysql, time
module_path = os.path.abspath(os.path.join('/home/ktereshin/yandex/arcadia/cloud/analytics/python/work'))
if module_path not in sys.path:
    sys.path.append(module_path)
from data_loader import clickhouse
from yt.transfer_manager.client import TransferManager
from global_variables import (
    metrika_clickhouse_param_dict,
    cloud_clickhouse_param_dict
)
from nile.api.v1 import (
    clusters,
    aggregators as na,
    extractors as ne,
    filters as nf,
    Record
)
from vault_client import instances

# %%
def works_with_emails(mail_):
    mail_parts = str(mail_).split('@')
    if len(mail_parts) > 1:
        if 'yandex.' in mail_parts[1].lower() or 'ya.' in mail_parts[1].lower():
            domain = 'yandex.ru'
            login = mail_parts[0].lower().replace('.', '-')
            return login + '@' + domain
        else:
            return str(mail_).lower()
    else:
        return str(mail_).lower()

def get_last_not_empty_table(folder_path):
    tables_list = sorted([folder_path + '/' + x for x in job.driver.list(folder_path)], reverse=True)
    last_table_rows = 0
    last_table = ''
    for table in tables_list:
        try:
            table_ = job.driver.read(table)
        except:
            continue
        
        if table_.row_count > last_table_rows:
            last_table_rows =  table_.row_count
            last_table = table
    if last_table:
        return last_table
    else:
        return tables_list[0]

def apply_types_in_project(schema_):
    apply_types_dict = {}
    for col in schema_:
        
        if schema_[col] == str:
            apply_types_dict[col] = ne.custom(lambda x: str(x) if x not in ['', None] else None, col)
            
        elif schema_[col] == int:
            apply_types_dict[col] = ne.custom(lambda x: int(x) if x not in ['', None] else None, col)
            
        elif schema_[col] == float:
            apply_types_dict[col] = ne.custom(lambda x: float(x) if x not in ['', None] else None, col)
    return apply_types_dict

def exucute_query(query, hosts):
    for host in hosts.split(','):
        cloud_clickhouse_param_dict['host'] = host
        cloud_clickhouse_param_dict['query'] = query
        clickhouse.get_clickhouse_data(**cloud_clickhouse_param_dict)

client = instances.Production()
yt_creds = client.get_version('ver-01d33pgv8pzc7t99s3egm24x47')
crm_sql_creds = client.get_version('ver-01d3ktedjm6ptsvwf1xq161hwk')
metrika_creds = client.get_version('ver-01d2z36msatt9mp9pcfptezksp')
yc_ch_creds = client.get_version('ver-01d2z39xj02xw7gqvv9wq757ne')

cluster = clusters.yt.Hahn(
    token = yt_creds['value']['token'],
    pool = yt_creds['value']['pool']
)
metrika_clickhouse_param_dict['user'] = metrika_creds['value']['login']
metrika_clickhouse_param_dict['password'] = metrika_creds['value']['pass']

cloud_clickhouse_param_dict['user'] = yc_ch_creds['value']['login']
cloud_clickhouse_param_dict['password'] = yc_ch_creds['value']['pass']

# %%
paths_dict_test = {
    'calls': '//home/cloud_analytics_test/cooking_cubes/crm_leads/calls',
    'leads_history': '//home/cloud_analytics_test/cooking_cubes/crm_leads/leads_history',
    'event_cube': '//home/cloud_analytics_test/cubes/acquisition_cube/cube',
    'crm_leads_cube': '//home/cloud_analytics_test/cubes/crm_leads/cube'
}
paths_dict_prod = {
    'calls': '//home/cloud_analytics/cooking_cubes/crm_leads/calls',
    'leads_history': '//home/cloud_analytics/cooking_cubes/crm_leads/leads_history',
    'event_cube': '//home/cloud_analytics/cubes/acquisition_cube/cube',
    'crm_leads_cube': '//home/cloud_analytics/cubes/crm_leads/cube'
}

mode = 'test'
if mode == 'test':
    paths_dict = paths_dict_test
elif mode == 'prod':
    paths_dict = paths_dict_prod

# %%
cnx = pymysql.connect(user='readonly', password=crm_sql_creds['value']['readonly'],
                              host='percona.prod.ya-cloud-crm.stable.qloud-d.yandex.net',
                              port = 5678,
                              database='cloud8'
                             )

query = '''
SELECT
    IFNULL(calls.id,'') call_id,
    CAST(calls.date_start AS char) event_time,
    IFNULL(calls.description,'') call_description,
    IFNULL(calls.parent_type,'') call_parent_type,
    IFNULL(calls.status,'') call_status,
    IFNULL(l1.id,'') lead_id,
    IFNULL(l1.passport_uid,'') puid,
    IFNULL(l1.ba_id,'') billing_account_id,
    IFNULL(l1.phone_mobile,'') lead_phone,
    IFNULL(l2.email_address,'') lead_email,
    IFNULL(calls.name,'') call_name,
    IFNULL(l3.user_name,'') sales_name,
    'call' as event,
    'call' as lead_state,
    group_concat(CASE WHEN l4.name LIKE '%едозвон%' THEN 'unreachible' ELSE 'reachible' END) call_status,
    group_concat(IFNULL(l4.name,'no_tag')) call_tag
FROM calls
LEFT JOIN  calls_leads l1_1
    ON calls.id=l1_1.call_id
LEFT JOIN  leads l1
    ON l1.id=l1_1.lead_id AND l1.deleted=0
LEFT JOIN  email_addr_bean_rel l2_1
    ON l1.id=l2_1.bean_id AND l2_1.bean_module = 'Leads' AND l2_1.primary_address = 1 AND l2_1.deleted=0
LEFT JOIN  email_addresses l2
    ON l2.id=l2_1.email_address_id AND l2.deleted=0
LEFT JOIN  users l3
    ON calls.assigned_user_id=l3.id AND l3.deleted=0
LEFT JOIN  tag_bean_rel l4_1 
    ON calls.id=l4_1.bean_id AND l4_1.bean_module = 'Calls' AND l4_1.deleted=0
LEFT JOIN  tags l4 ON l4.id=l4_1.tag_id AND l4.deleted=0
WHERE
    calls.status = 'Held'
GROUP BY
    call_id,
    event_time,
    call_description,
    call_parent_type,
    call_status,
    lead_id,
    lead_source,
    lead_source_description,
    lead_phone,
    lead_email,
    call_name,
    sales_name,
    event,
    lead_state,
    puid,
    billing_account_id
'''

calls_df = pd.read_sql_query(query, cnx)
cnx.close()
# Out:
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/pymysql/cursors.py:170: Warning: (1052, "Column 'call_id' in group statement is ambiguous")
#   result = self._query(query)
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/pymysql/cursors.py:170: Warning: (1052, "Column 'lead_id' in group statement is ambiguous")
#   result = self._query(query)

# %%
cluster.write(paths_dict['calls'], calls_df)
# Out:
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/drivers/yt/readwrite.py:470: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   rows = records.to_dict(orient='records')

# %%
cnx = pymysql.connect(user='readonly', password=crm_sql_creds['value']['readonly'],
                              host='percona.prod.ya-cloud-crm.stable.qloud-d.yandex.net',
                              port = 5678,
                              database='cloud8'
                             )

query = '''
SELECT
    sorce.parent_id lead_id,
    CONCAT('lead_changed_',CAST(sorce.field_name as CHAR(50))) as event,
    sorce.after_value_string lead_state,
    MIN(CAST(sorce.date_created as char)) as event_time,
    MIN(IFNULL(l1.account_name,'')) as account_name,
    MIN(IFNULL(l1.passport_uid,''))  as puid,
    MIN(IFNULL(l1.ba_id,'')) as billing_account_id,
    MIN(l1.lead_source) as lead_source,
    MIN(l1.lead_source_description) as lead_source_description,
    MIN(l2.email_address) as lead_email,
    MIN(l3.user_name) sales_name
FROM
    leads_audit as sorce
INNER JOIN  leads l1
    ON l1.id=sorce.parent_id AND l1.deleted = 0
LEFT JOIN  email_addr_bean_rel l2_1
    ON l1.id=l2_1.bean_id AND l2_1.bean_module = 'Leads' AND l2_1.primary_address = 1
LEFT JOIN  email_addresses l2
    ON l2.id=l2_1.email_address_id
LEFT JOIN  users l3
    ON sorce.after_value_string=l3.id
WHERE
    sorce.after_value_string != ''
GROUP BY
    sorce.parent_id,
    CONCAT('lead_changed_',CAST(sorce.field_name as CHAR(50))),
    sorce.after_value_string
'''

leads_history = pd.read_sql_query(query, cnx)
cnx.close()

# %%
cluster.write(paths_dict['leads_history'], leads_history)

# %%
leads_history
# Out:
#                                     lead_id  \
# 0      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 1      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 2      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 3      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 4      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 5      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 6      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 7      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 8      0008fdfa-5f1e-11e9-ba4b-0affedc5af91
# 9      000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 10     000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 11     000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 12     000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 13     000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 14     000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 15     000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 16     000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 17     000e7cd0-5f1e-11e9-beaa-0bd7d7002310
# 18     000f68f2-5f1e-11e9-bda3-62f08071e753
# 19     000f68f2-5f1e-11e9-bda3-62f08071e753
# 20     000f68f2-5f1e-11e9-bda3-62f08071e753
# 21     000f68f2-5f1e-11e9-bda3-62f08071e753
# 22     000f68f2-5f1e-11e9-bda3-62f08071e753
# 23     000f68f2-5f1e-11e9-bda3-62f08071e753
# 24     000f68f2-5f1e-11e9-bda3-62f08071e753
# 25     000f68f2-5f1e-11e9-bda3-62f08071e753
# 26     000f68f2-5f1e-11e9-bda3-62f08071e753
# 27     00104dbc-5f1e-11e9-b184-0f443daa2a52
# 28     00104dbc-5f1e-11e9-b184-0f443daa2a52
# 29     00104dbc-5f1e-11e9-b184-0f443daa2a52
# ...                                     ...
# 73561  ffde1604-4496-11e9-8552-e08b8ef5dda9
# 73562  ffde1604-4496-11e9-8552-e08b8ef5dda9
# 73563  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73564  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73565  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73566  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73567  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73568  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73569  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73570  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73571  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73572  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73573  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73574  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73575  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73576  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73577  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73578  fff88358-3e48-11e9-b8fb-0d280ac8a6b1
# 73579  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73580  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73581  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73582  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73583  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73584  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73585  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73586  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73587  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73588  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73589  fffa4aec-55f1-11e9-a5f9-bd40854388cf
# 73590  fffa4aec-55f1-11e9-a5f9-bd40854388cf
#
#                                       event  \
# 0             lead_changed_assigned_user_id
# 1      lead_changed_dp_consent_last_updated
# 2                        lead_changed_email
# 3                   lead_changed_first_name
# 4                    lead_changed_last_name
# 5                  lead_changed_lead_source
# 6                 lead_changed_phone_mobile
# 7                       lead_changed_status
# 8                      lead_changed_team_id
# 9             lead_changed_assigned_user_id
# 10     lead_changed_dp_consent_last_updated
# 11                       lead_changed_email
# 12                  lead_changed_first_name
# 13                   lead_changed_last_name
# 14                 lead_changed_lead_source
# 15                lead_changed_phone_mobile
# 16                      lead_changed_status
# 17                     lead_changed_team_id
# 18            lead_changed_assigned_user_id
# 19     lead_changed_dp_consent_last_updated
# 20                       lead_changed_email
# 21                  lead_changed_first_name
# 22                   lead_changed_last_name
# 23                 lead_changed_lead_source
# 24                lead_changed_phone_mobile
# 25                      lead_changed_status
# 26                     lead_changed_team_id
# 27            lead_changed_assigned_user_id
# 28     lead_changed_dp_consent_last_updated
# 29                       lead_changed_email
# ...                                     ...
# 73561                  lead_changed_team_id
# 73562              lead_changed_team_set_id
# 73563         lead_changed_assigned_user_id
# 73564         lead_changed_assigned_user_id
# 73565  lead_changed_dp_consent_last_updated
# 73566  lead_changed_dp_consent_last_updated
# 73567               lead_changed_first_name
# 73568               lead_changed_first_name
# 73569                lead_changed_last_name
# 73570                lead_changed_last_name
# 73571              lead_changed_lead_source
# 73572             lead_changed_phone_mobile
# 73573                   lead_changed_status
# 73574                   lead_changed_status
# 73575                   lead_changed_status
# 73576                   lead_changed_status
# 73577                  lead_changed_team_id
# 73578              lead_changed_team_set_id
# 73579         lead_changed_assigned_user_id
# 73580  lead_changed_dp_consent_last_updated
# 73581  lead_changed_dp_consent_last_updated
# 73582               lead_changed_first_name
# 73583                lead_changed_last_name
# 73584              lead_changed_lead_source
# 73585             lead_changed_phone_mobile
# 73586                   lead_changed_status
# 73587                   lead_changed_status
# 73588                   lead_changed_status
# 73589                  lead_changed_team_id
# 73590              lead_changed_team_set_id
#
#                                  lead_state           event_time account_name  \
# 0      f77e6b82-ac3c-11e8-ae14-4a84e5ceb905  2019-04-15 01:30:02
# 1                                2019-04-15  2019-04-15 01:30:02
# 2      002eb50e-5f1e-11e9-bc1e-b631fb019828  2019-04-15 01:30:02
# 3                                     Санёк  2019-04-15 01:30:02
# 4                                    Болгов  2019-04-15 01:30:02
# 5                                   Marketo  2019-04-15 01:30:02
# 6                               79128044922  2019-04-15 01:30:02
# 7                                       New  2019-04-15 01:30:02
# 8      7cb927ba-b0ed-11e8-b3f8-4c575d9a82b0  2019-04-15 01:30:02
# 9      f77e6b82-ac3c-11e8-ae14-4a84e5ceb905  2019-04-15 01:30:02
# 10                               2019-04-15  2019-04-15 01:30:02
# 11     00aa8882-5f1e-11e9-8449-a307a35f3587  2019-04-15 01:30:02
# 12                                     выыв  2019-04-15 01:30:02
# 13                                      ыыв  2019-04-15 01:30:02
# 14                                  Marketo  2019-04-15 01:30:02
# 15                              79823033508  2019-04-15 01:30:02
# 16                                      New  2019-04-15 01:30:02
# 17     7cb927ba-b0ed-11e8-b3f8-4c575d9a82b0  2019-04-15 01:30:02
# 18     f77e6b82-ac3c-11e8-ae14-4a84e5ceb905  2019-04-15 01:30:02
# 19                               2019-04-15  2019-04-15 01:30:02
# 20     00e2a28a-5f1e-11e9-8489-2448cfd83192  2019-04-15 01:30:02
# 21                            corporate2000  2019-04-15 01:30:02
# 22                            corporate2000  2019-04-15 01:30:02
# 23                                  Marketo  2019-04-15 01:30:02
# 24                              79260709974  2019-04-15 01:30:02
# 25                                      New  2019-04-15 01:30:02
# 26     7cb927ba-b0ed-11e8-b3f8-4c575d9a82b0  2019-04-15 01:30:02
# 27     f77e6b82-ac3c-11e8-ae14-4a84e5ceb905  2019-04-15 01:30:02
# 28                               2019-04-15  2019-04-15 01:30:02
# 29     011a8bc8-5f1e-11e9-9fdc-31017f885812  2019-04-15 01:30:02
# ...                                     ...                  ...          ...
# 73561                                     1  2019-03-12 07:17:53
# 73562                                     1  2019-03-12 07:17:53
# 73563  9e998e38-ad14-11e8-a9c6-85c3ee7fa3be  2019-03-05 06:46:21
# 73564  f77e6b82-ac3c-11e8-ae14-4a84e5ceb905  2019-03-04 06:44:35
# 73565                            03/04/2019  2019-03-04 06:44:35
# 73566                            2019-04-03  2019-03-04 06:44:35
# 73567                               Äìèòðèé  2019-03-04 06:44:35
# 73568                               Дмитрий  2019-03-05 10:46:57
# 73569                        ÄìèòðèéÏåòóõîâ  2019-03-04 06:44:35
# 73570                               Петухов  2019-03-05 10:46:57
# 73571                                 sales  2019-03-04 06:44:35
# 73572                           79224710440  2019-03-04 06:44:35
# 73573                              Assigned  2019-03-05 06:46:21
# 73574                            In Process  2019-03-05 10:52:27
# 73575                                   New  2019-03-04 06:44:35
# 73576                              Recycled  2019-03-05 10:52:37
# 73577                                     1  2019-03-04 06:44:35
# 73578                                     1  2019-03-04 06:44:35
# 73579  b8ae82e2-ad14-11e8-a0c4-5343ab2a9cb3  2019-04-03 09:21:50
# 73580                            03/04/2019  2019-04-03 09:21:50
# 73581                            2019-04-03  2019-04-03 09:21:50
# 73582                                 Nazar  2019-04-03 09:21:50
# 73583                                 Nazar  2019-04-03 09:21:50
# 73584                                 sales  2019-04-03 09:21:50
# 73585                           79162914188  2019-04-03 09:21:50
# 73586                              Assigned  2019-04-03 09:21:50
# 73587                            In Process  2019-04-04 08:55:56
# 73588                              Recycled  2019-04-05 08:58:52
# 73589                                     1  2019-04-03 09:21:50
# 73590                                     1  2019-04-03 09:21:50
#
#       puid    billing_account_id lead_source lead_source_description  \
# 0           dn2083nldm21nm6jcojo     Marketo                    None
# 1           dn2083nldm21nm6jcojo     Marketo                    None
# 2           dn2083nldm21nm6jcojo     Marketo                    None
# 3           dn2083nldm21nm6jcojo     Marketo                    None
# 4           dn2083nldm21nm6jcojo     Marketo                    None
# 5           dn2083nldm21nm6jcojo     Marketo                    None
# 6           dn2083nldm21nm6jcojo     Marketo                    None
# 7           dn2083nldm21nm6jcojo     Marketo                    None
# 8           dn2083nldm21nm6jcojo     Marketo                    None
# 9           dn21aakhhvenq5ddduc8     Marketo                    None
# 10          dn21aakhhvenq5ddduc8     Marketo                    None
# 11          dn21aakhhvenq5ddduc8     Marketo                    None
# 12          dn21aakhhvenq5ddduc8     Marketo                    None
# 13          dn21aakhhvenq5ddduc8     Marketo                    None
# 14          dn21aakhhvenq5ddduc8     Marketo                    None
# 15          dn21aakhhvenq5ddduc8     Marketo                    None
# 16          dn21aakhhvenq5ddduc8     Marketo                    None
# 17          dn21aakhhvenq5ddduc8     Marketo                    None
# 18          dn220sd1g2focm6o31oq     Marketo                    None
# 19          dn220sd1g2focm6o31oq     Marketo                    None
# 20          dn220sd1g2focm6o31oq     Marketo                    None
# 21          dn220sd1g2focm6o31oq     Marketo                    None
# 22          dn220sd1g2focm6o31oq     Marketo                    None
# 23          dn220sd1g2focm6o31oq     Marketo                    None
# 24          dn220sd1g2focm6o31oq     Marketo                    None
# 25          dn220sd1g2focm6o31oq     Marketo                    None
# 26          dn220sd1g2focm6o31oq     Marketo                    None
# 27          dn25uml1u1gs82vr222h     Marketo                    None
# 28          dn25uml1u1gs82vr222h     Marketo                    None
# 29          dn25uml1u1gs82vr222h     Marketo                    None
# ...    ...                   ...         ...                     ...
# 73561    0  dn2adobiithdafhncitg       sales            Lated_trials
# 73562    0  dn2adobiithdafhncitg       sales            Lated_trials
# 73563    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73564    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73565    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73566    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73567    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73568    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73569    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73570    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73571    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73572    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73573    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73574    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73575    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73576    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73577    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73578    0  dn27lp4td73mahkb3cfh       sales            Lated_trials
# 73579    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73580    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73581    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73582    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73583    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73584    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73585    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73586    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73587    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73588    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73589    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
# 73590    0  dn2h8fco4mu1enkppmcc       sales           Lasted_trials
#
#                             lead_email sales_name
# 0              bolgov-saneek@yandex.ru      timag
# 1              bolgov-saneek@yandex.ru       None
# 2              bolgov-saneek@yandex.ru       None
# 3              bolgov-saneek@yandex.ru       None
# 4              bolgov-saneek@yandex.ru       None
# 5              bolgov-saneek@yandex.ru       None
# 6              bolgov-saneek@yandex.ru       None
# 7              bolgov-saneek@yandex.ru       None
# 8              bolgov-saneek@yandex.ru       None
# 9                    iyvvyyv@yandex.ru      timag
# 10                   iyvvyyv@yandex.ru       None
# 11                   iyvvyyv@yandex.ru       None
# 12                   iyvvyyv@yandex.ru       None
# 13                   iyvvyyv@yandex.ru       None
# 14                   iyvvyyv@yandex.ru       None
# 15                   iyvvyyv@yandex.ru       None
# 16                   iyvvyyv@yandex.ru       None
# 17                   iyvvyyv@yandex.ru       None
# 18             corporate2000@yandex.ru      timag
# 19             corporate2000@yandex.ru       None
# 20             corporate2000@yandex.ru       None
# 21             corporate2000@yandex.ru       None
# 22             corporate2000@yandex.ru       None
# 23             corporate2000@yandex.ru       None
# 24             corporate2000@yandex.ru       None
# 25             corporate2000@yandex.ru       None
# 26             corporate2000@yandex.ru       None
# 27              nfedoruk2000@yandex.ru      timag
# 28              nfedoruk2000@yandex.ru       None
# 29              nfedoruk2000@yandex.ru       None
# ...                                ...        ...
# 73561  velichkoolha.velichko@yandex.ru      admin
# 73562  velichkoolha.velichko@yandex.ru      admin
# 73563                Dredd01@yandex.ru     anbalu
# 73564                Dredd01@yandex.ru      timag
# 73565                Dredd01@yandex.ru       None
# 73566                Dredd01@yandex.ru       None
# 73567                Dredd01@yandex.ru       None
# 73568                Dredd01@yandex.ru       None
# 73569                Dredd01@yandex.ru       None
# 73570                Dredd01@yandex.ru       None
# 73571                Dredd01@yandex.ru       None
# 73572                Dredd01@yandex.ru       None
# 73573                Dredd01@yandex.ru       None
# 73574                Dredd01@yandex.ru       None
# 73575                Dredd01@yandex.ru       None
# 73576                Dredd01@yandex.ru       None
# 73577                Dredd01@yandex.ru      admin
# 73578                Dredd01@yandex.ru      admin
# 73579               naz12301@yandex.ru     dmtroe
# 73580               naz12301@yandex.ru       None
# 73581               naz12301@yandex.ru       None
# 73582               naz12301@yandex.ru       None
# 73583               naz12301@yandex.ru       None
# 73584               naz12301@yandex.ru       None
# 73585               naz12301@yandex.ru       None
# 73586               naz12301@yandex.ru       None
# 73587               naz12301@yandex.ru       None
# 73588               naz12301@yandex.ru       None
# 73589               naz12301@yandex.ru      admin
# 73590               naz12301@yandex.ru      admin
#
# [73591 rows x 11 columns]

# %%
schema = {
    "lead_id": str,
    "event_time": str,
    "event": str,
    "lead_state": str,
    "ba_payment_cycle_type": str,
    "ba_person_type": str,
    "ba_state": str,
    "ba_usage_status": str,
    "billing_account_id": str,
    "block_reason": str,
    "call_description": str,
    "call_id": str,
    "call_name": str,
    "call_parent_type": str,
    "call_status": str,
    "call_tag": str,
    "channel": str,
    "cloud_status": str,
    "lead_email": str,
    "lead_phone": str,
    "lead_source": str,
    "lead_source_description": str,
    "paid_comsumption_cloud_ai": float,
    "paid_comsumption_cloud_network": float,
    "paid_comsumption_compute": float,
    "paid_comsumption_mdb": float,
    "paid_comsumption_nlb": float,
    "paid_comsumption_storage": float,
    "paid_comsumption_total": float,
    "sales_name": str,
    "segment": str,
    "trial_comsumption_cloud_ai": float,
    "trial_comsumption_cloud_network": float,
    "trial_comsumption_compute": float,
    "trial_comsumption_mdb": float,
    "trial_comsumption_nlb": float,
    "trial_comsumption_storage": float,
    "trial_comsumption_total": float,
    "puid": str,
    "account_name": str
}

# %%
def get_lead_id(email_lead_id, ba_lead_id, puid_lead_id):
    if ba_lead_id:
        return ba_lead_id
    if puid_lead_id:
        return puid_lead_id
    if email_lead_id:
        return email_lead_id

def reduce_func(groups):
    for key, records in groups:
        sales_changes = {}
        options_dict = {
            'ba_payment_cycle_type': 'unknown',
            'ba_person_type': 'unknown',
            'ba_state': 'unknown',
            'ba_usage_status': 'unknown',
            'billing_account_id': None,
            'block_reason': 'unknown',
            'channel': 'unknown',
            'cloud_status': 'unknown',
            'lead_source': 'unknown',
            'lead_source_description': 'unknown',
            'lead_email': None,
            'puid': None
        }
        consumption_trial = {
            'compute': 0,
            'cloud_network': 0,
            'storage': 0,
            'mdb': 0,
            'cloud_ai': 0,
            'nlb': 0,
            'event_time': None
        }
        consumption_paid = {
            'compute': 0,
            'cloud_network': 0,
            'storage': 0,
            'mdb': 0,
            'cloud_ai': 0,
            'nlb': 0,
            'event_time': None
        }
        call_options = [
            'call_description',
            'call_parent_type',
            'lead_phone',
            'call_name',
            'call_status',
            'call_tag'
        ]
        result_list = []
        have_new = 0
        have_assigned = 0
        have_in_progress = 0
        for rec in records:
            
            if 'lead_state' in rec:
                if rec['lead_state'] == 'New':
                    have_new = 1

                if rec['lead_state'] == 'Assigned':
                    have_assigned = 1

                if rec['lead_state'] == 'In Process':
                    have_in_progress = 1
            
            if rec['event'] == 'day_use':
                
                if 'puid' in rec:
                    options_dict['puid'] = rec['puid']
                
                if 'billing_account_id' in rec:
                    options_dict['billing_account_id'] = rec['billing_account_id']
                
                for service in consumption_paid:
                    if service == rec['service_name']:
                        consumption_trial[service] += rec['trial_consumption']
                        consumption_paid[service] += rec['real_consumption']
                        consumption_paid['event_time'] = rec['event_time']
                        consumption_trial['event_time'] = rec['event_time']
                        break
                        
            if 'sales_name' in rec and rec['event'] == 'call':
                if rec['sales_name']:
                    sales_changes[rec['event_time']] = rec['sales_name']
                    
                    
            for option in options_dict:
                if option in rec:
                    if rec[option]:
                        options_dict[option] = str(rec[option]).lower()
                        
                        
            if rec['event'] in ['call', 'lead_changed_status', 'first_paid_consumption']:
                result_list.append(rec.to_dict())
        
        
        for row in result_list:
            for option in options_dict:
                row[option] = options_dict[option]
                
            for option in call_options:
                if option not in row:
                    row[option] = None
                    
            if row['event'] == 'first_paid_consumption':
                row['lead_state'] = 'first_paid_consumption'
                
            for option in consumption_paid:
                if option != 'event_time':
                    row['paid_comsumption_' + option] = None
                    row['trial_comsumption_' + option] = None
            row['paid_comsumption_total'] = None
            row['trial_comsumption_total'] = None
                    
            if sales_changes:
                row['sales_name'] = None
                for time in sorted(sales_changes):
                    if time >= row['event_time']:
                        row['sales_name'] = sales_changes[time]
                        break
                if not row['sales_name']:
                    row['sales_name'] = sales_changes[sorted(sales_changes, reverse=True)[0]]
            else:
                row['sales_name'] = 'unknown'
            
            
            if have_new ==0:
                row_ = row.copy()
                row_['lead_state'] = 'New'
                yield Record(key, **row_)
                have_new = 1
                
            if have_new ==1 and have_assigned == 0 and have_in_progress == 1:
                row_ = row.copy()
                row_['lead_state'] = 'Assigned'
                yield Record(key, **row_)
                have_assigned = 1

            
            yield Record(key, **row)
            
        if consumption_paid['event_time']:
            last_row = {
                'event': 'Consumption',
                'event_time': consumption_paid['event_time'],
                'lead_state': 'Paid Consumption',
            }
            for option in options_dict:
                last_row[option] = options_dict[option]
                
            for option in call_options:
                if option not in last_row:
                    last_row[option] = None
                    
                    
            paid = 0
            trial = 0
            for option in consumption_paid:
                if option != 'event_time':
                    paid += consumption_paid[option]
                    trial += consumption_trial[option]
                    last_row['paid_comsumption_' + option] = consumption_paid[option]
                    last_row['trial_comsumption_' + option] = consumption_trial[option]
            last_row['paid_comsumption_total'] = paid
            last_row['trial_comsumption_total'] = trial
                    
            if sales_changes:
                last_row['sales_name'] = sales_changes[sorted(sales_changes, reverse=True)[0]]
            else:
                last_row['sales_name'] = 'unknown'
            if paid > 0:
                yield Record(key, **last_row)

# %%
job = cluster.job()

event = job.table(paths_dict['event_cube']) \
.filter(
    nf.custom(lambda x: x in ['day_use', 'first_trial_consumption', 'first_paid_consumption'], 'event'),
    nf.custom(lambda x: x not in [None, ''], 'user_settings_email')
) \
.project(
    'event',
    'trial_consumption',
    'real_consumption',
    'trial_consumption_cum',
    'real_consumption_cum',
    'ba_state',
    'ba_payment_cycle_type',
    'ba_person_type',
    'ba_type',
    'ba_usage_status',
    'billing_account_id',
    'block_reason',
    'channel',
    'cloud_status',
    'name',
    'segment',
    'puid',
    event_time = ne.custom(lambda x: str(datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S') + datetime.timedelta(seconds = 10800)), 'event_time'),
    service_name = ne.custom(lambda x: x.split('.')[0] if '.' in str(x) else x, 'service_name'),
    lead_email = ne.custom( works_with_emails,'user_settings_email')
) \
.put(paths_dict['crm_leads_cube'] + '_test_')

job.run()
# Out:
# VBox()
# 2019-04-16 17:30:06,681	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=e62e627b-aa805e9e-3fe03e8-1b9c2579&tab=details
# 2019-04-16 17:33:20,796	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=bceac6ee-b862ac2d-3fe03e8-c7af1af0&tab=details
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f527283fbafc> in <module>()
#      29 .put(paths_dict['crm_leads_cube'] + '_test_')
#      30
# ---> 31 job.run()
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/api/v1/job.pyc in run(self, checkpoints, store_checkpoints, hide_command, skip_publish, snapshot_filename, type_config_settings)
#     221         with CustomSysArgv(sys_argv):
#     222             self._run_with_finalize(
# --> 223                 execution_plan, snapshot_filename=snapshot_filename
#     224             )
#     225
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/api/v1/job.pyc in _run_with_finalize(execution_plan, *args, **kws)
#     155         try:
#     156             logger.info('Running execution plan...')
# --> 157             execution_plan.run(*args, **kws)
#     158         except Exception:
#     159             exc_info = sys.exc_info()
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/drivers/yt/execution_plan.pyc in run(self, snapshot_filename)
#     111             while self.queues_manager.has_more_work:
#     112                 self._schedule_operations()
# --> 113                 self._observe_until_someone_exits()
#     114         except KeyboardInterrupt:
#     115             self._abort_operations()
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/drivers/yt/execution_plan.pyc in _observe_until_someone_exits(self)
#     170             for node in running_nodes:
#     171                 progress = running_nodes[node]
# --> 172                 if progress.observe_next_state(self.monitor):
#     173                     continue
#     174
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/drivers/common/progress.pyc in observe_next_state(self, monitor)
#     104     def observe_next_state(self, monitor):
#     105         try:
# --> 106             self.last_state = next(self.state_iterator)
#     107         except StopIteration:
#     108             has_more = False
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/drivers/yt/progress.pyc in states(self)
#     110             min_delay=1.0,
#     111             max_delay=5.0,
# --> 112             slowdown_coef=0.1
#     113         ):
#     114             yield state
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/drivers/yt/progress.pyc in _states_monitor(self, min_delay, max_delay, slowdown_coef)
#     123
#     124         state = None
# --> 125         for state in states_monitor:
#     126             yield self.state(state)
#     127         if self.operation.finalize:
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/drivers/yt/tracking.pyc in get_operation_states_monitor(operation, min_delay, max_delay, slowdown_coef)
#      10
#      11     while True:
# ---> 12         state = get_state()
#      13
#      14         yield state
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/utils/misc.pyc in wrapper(*args, **kws)
#     482     def decorator(function):
#     483         def wrapper(*args, **kws):
# --> 484             time_watcher.wait()
#     485             return function(*args, **kws)
#     486
#
# /home/ktereshin/yandex/venv/local/lib/python2.7/site-packages/nile/utils/misc.pyc in wait(self, save_time)
#     466         delay = self.get_delay()
#     467         if delay > 0:
# --> 468             sleep(delay)
#     469
#     470         if save_time:
#
# KeyboardInterrupt:

# %%
job = cluster.job()
leads = job.concat(
    job.table(paths_dict['calls']).project(ne.all(), lead_email = ne.custom( works_with_emails,'lead_email')),
    job.table(paths_dict['leads_history']).project(ne.all(), lead_email = ne.custom( works_with_emails,'lead_email'))
)
email_dict = leads \
.filter(
    nf.custom(lambda x: x not in ['', None], 'lead_email'),
    nf.custom(lambda x: x not in ['', None], 'lead_id')
) \
.unique(
    'lead_email',
    'lead_id'
) \
.project(
    'lead_email',
    email_lead_id = 'lead_id'
)

ba_dict = leads \
.filter(
    nf.custom(lambda x: x not in ['', None], 'billing_account_id'),
    nf.custom(lambda x: x not in ['', None], 'lead_id')
) \
.unique(
    'billing_account_id',
    'lead_id'
) \
.project(
    'billing_account_id',
    ba_lead_id = 'lead_id'
)

puid_dict = leads \
.filter(
    nf.custom(lambda x: x not in ['', None], 'puid'),
    nf.custom(lambda x: x not in ['', None], 'lead_id')
) \
.unique(
    'puid',
    'lead_id'
) \
.project(
    'puid',
    puid_lead_id = 'lead_id'
)

event = job.table(paths_dict['event_cube']) \
.filter(
    nf.custom(lambda x: x in ['day_use', 'first_trial_consumption', 'first_paid_consumption'], 'event'),
    nf.custom(lambda x: x not in [None, ''], 'user_settings_email')
) \
.project(
    'event',
    'trial_consumption',
    'real_consumption',
    'trial_consumption_cum',
    'real_consumption_cum',
    'ba_state',
    'ba_payment_cycle_type',
    'ba_person_type',
    'ba_type',
    'ba_usage_status',
    'billing_account_id',
    'block_reason',
    'channel',
    'cloud_status',
    'name',
    'segment',
    'puid',
    event_time = ne.custom(lambda x: str(datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S') + datetime.timedelta(seconds = 10800)), 'event_time'),
    service_name = ne.custom(lambda x: x.split('.')[0] if '.' in str(x) else x, 'service_name'),
    lead_email = ne.custom( works_with_emails,'user_settings_email')
) \
.join(
    email_dict,
    by = 'lead_email',
    type = 'left'
) \
.join(
    ba_dict,
    by = 'billing_account_id',
    type = 'left'
) \
.join(
    puid_dict,
    by = 'puid',
    type = 'left'
) \
.put(paths_dict['crm_leads_cube'] + '_test_')

event_ = event \
.project(
    ne.all(),
    lead_id = ne.custom(lambda email_lead_id, ba_lead_id, puid_lead_id: get_lead_id(email_lead_id, ba_lead_id, puid_lead_id), 'email_lead_id', 'ba_lead_id', 'puid_lead_id')
) \
.filter(
    nf.custom(lambda x: x not in ['', None], 'lead_id')
) \
.unique(
    'lead_id', 'event_time', 'event'
)
job.concat(
    leads,
    event_
) \
.put(paths_dict['crm_leads_cube'] + '_test')
job.run()
# Out:
# VBox()
# 2019-04-16 17:34:25,376	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=a1d70a82-f1ea51d9-3fe03e8-40ae87a2&tab=details
# 2019-04-16 17:37:56,264	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=49734667-63f7ce03-3fe03e8-1e399cfd&tab=details
# 2019-04-16 17:38:20,688	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=4bd209af-c6b9d519-3fe03e8-a119fb02&tab=details
# 2019-04-16 17:38:34,604	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=9a54ff18-bae9e818-3fe03e8-e147683a&tab=details
# 2019-04-16 17:38:56,161	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=c25cc754-c42693f2-3fe03e8-17c5ed0a&tab=details
# 2019-04-16 17:39:19,233	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=3322dad6-2d10852e-3fe03e8-7dae2a04&tab=details
# 2019-04-16 17:39:42,292	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=8331bc14-2ae6cb7d-3fe03e8-2fed392e&tab=details
# 2019-04-16 17:40:39,244	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=9db40d24-f27a4074-3fe03e8-4ee03310&tab=details
# 2019-04-16 17:41:04,435	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=cc53a3b9-41f0d109-3fe03e8-528ecb25&tab=details
# 2019-04-16 17:41:45,959	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=77c9e1da-f0c2830-3fe03e8-baf622f4&tab=details
# 2019-04-16 17:43:32,900	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=320ff224-11a0dab7-3fe03e8-8b5d0218&tab=details
# 2019-04-16 17:45:55,220	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=5f08cf18-c09c517f-3fe03e8-3d0c89e4&tab=details
# 2019-04-16 17:48:51,648	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=cc005663-9c80184f-3fe03e8-3906f8a9&tab=details
# 2019-04-16 17:50:51,365	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=8cd3ce56-c72d23c0-3fe03e8-5452115d&tab=details
# 2019-04-16 17:56:20,442	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=4e826e89-bc3b8b14-3fe03e8-b082b0c2&tab=details
# 2019-04-16 17:59:35,363	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=5011966b-12396331-3fe03e8-eaf1bd4f&tab=details
# 2019-04-16 18:00:48,774	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=1907f9ca-bb9032b0-3fe03e8-a63d588b&tab=details
# 2019-04-16 18:01:31,803	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=d41b2cda-f251adfc-3fe03e8-ccef9497&tab=details
# 2019-04-16 18:02:48,862	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=4358eb15-46c80a80-3fe03e8-fb564cd8&tab=details

# %%
job = cluster.job()
dat = job.table(paths_dict['crm_leads_cube'] + '_test') \
.groupby(
    'lead_id'
) \
.sort(
    'event_time'
) \
.reduce(
    reduce_func
) \
.project(
    **apply_types_in_project(schema)
) \
.sort(
    'event_time'
) \
.put(paths_dict['crm_leads_cube'], schema = schema)
job.run()
# Out:
# VBox()
# 2019-04-12 07:55:45,156	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=4daf518d-9992606b-3fe03e8-93f944df&tab=details
# 2019-04-12 07:56:17,360	INFO	Operation started: http://hahn.yt.yandex.net/?page=operation&mode=detail&id=8bd472a8-1572df5e-3fe03e8-216f4ccb&tab=details

# %%
def exucute_query(query, hosts, cloud_clickhouse_param_dict_):
    for host in hosts.split(','):
        try:
            print('start on host: %s' % (host))
            cloud_clickhouse_param_dict_['host'] = host
            cloud_clickhouse_param_dict_['query'] = query
            clickhouse.get_clickhouse_data(**cloud_clickhouse_param_dict_)
            print('============================\n\n')
        except:
            break


hosts = 'https://sas-tt9078df91ipro7e.db.yandex.net:8443/,https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/'
table = 'cloud_analytics_testing.crm_lead_cube_test_tm'
query = '''
DROP TABLE IF EXISTS %s
''' % (table)

exucute_query(query, hosts, cloud_clickhouse_param_dict)
time.sleep(3)
query = '''
CREATE TABLE IF NOT EXISTS %s
(
    lead_id Nullable(String),
    event_time DateTime,
    event Nullable(String),
    lead_state Nullable(String),
    ba_payment_cycle_type Nullable(String),
    ba_person_type Nullable(String),
    ba_state Nullable(String),
    ba_usage_status Nullable(String),
    billing_account_id Nullable(String),
    block_reason Nullable(String),
    call_description Nullable(String),
    call_id Nullable(String),
    call_name Nullable(String),
    call_parent_type Nullable(String),
    call_status Nullable(String),
    call_tag Nullable(String),
    channel Nullable(String),
    cloud_status Nullable(String),
    lead_email Nullable(String),
    lead_phone Nullable(String),
    lead_source Nullable(String),
    lead_source_description Nullable(String),
    paid_comsumption_cloud_ai Nullable(Float64),
    paid_comsumption_cloud_network Nullable(Float64),
    paid_comsumption_compute Nullable(Float64),
    paid_comsumption_mdb Nullable(Float64),
    paid_comsumption_nlb Nullable(Float64),
    paid_comsumption_storage Nullable(Float64),
    paid_comsumption_total Nullable(Float64),
    sales_name Nullable(String),
    segment Nullable(String),
    trial_comsumption_cloud_ai Nullable(Float64),
    trial_comsumption_cloud_network Nullable(Float64),
    trial_comsumption_compute Nullable(Float64),
    trial_comsumption_mdb Nullable(Float64),
    trial_comsumption_nlb Nullable(Float64),
    trial_comsumption_storage Nullable(Float64),
    trial_comsumption_total Nullable(Float64),
    puid Nullable(String),
    account_name Nullable(String)
    
)
ENGINE = ReplicatedMergeTree('/clickhouse/tables/{shard}/%s', '{replica}')
ORDER BY(event_time) PARTITION BY toYYYYMM(event_time)
''' % (table, table)

exucute_query(query, hosts, cloud_clickhouse_param_dict)
# Out:
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================

# %%
params = {
    'clickhouse_copy_options': {
        'command': 'append',
    },
    'clickhouse_credentials': {
        'password': yc_ch_creds['value']['pass'],
        'user': yc_ch_creds['value']['login'],
    },
    'mdb_auth': {
        'oauth_token': client.get_version('ver-01d7xxnrs03xmcj6sfzm1ez4p3')['value']['token'],
    },
    'mdb_cluster_address': {
        'cluster_id': '07bc5e8c-c4a7-4c26-b668-5a1503d858b9',
    },
}


tm = TransferManager(token=yt_creds['value']['token'])

task = tm.add_task(
    'hahn',
    paths_dict['crm_leads_cube'],
    'mdb-clickhouse',
    table,
    params=params,
    sync=False
)

task_info = tm.get_task_info(task)

while task_info['state'] in ('pending', 'running'):
    time.sleep(5)
    task_info = tm.get_task_info(task)
if task_info['state'] != 'completed':
    print('Transfer manager task failed with \nthe following state: %s' % task_info['state'])
# Out:
# 2019-04-12 08:45:03,447	INFO	Transfer task started: https://transfer-manager.yt.yandex-team.ru/task?id=eaac374c-b5a21aed-7950b226-9c730d2f&tab=details&backend=production

# %%
query = '''
DROP TABLE IF EXISTS cloud_analytics_testing.crm_lead_cube_test
'''

exucute_query(query, hosts, cloud_clickhouse_param_dict)

query = '''
RENAME TABLE {0} TO cloud_analytics_testing.crm_lead_cube_test
'''.format(table)

exucute_query(query, hosts, cloud_clickhouse_param_dict)

query = '''
DROP TABLE IF EXISTS %s
''' % (table)

exucute_query(query, hosts, cloud_clickhouse_param_dict)
# Out:
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================

# %%
query = '''
CREATE TABLE cloud_analytics_testing.lead_funnel_temp
ENGINE = MergeTree()
ORDER BY(time) PARTITION BY toYYYYMM(time)
AS
SELECT
  lead_id,
  lead_email,
  billing_account_id,
  puid,
  lead_source,
  ba_person_type,
  ba_state,
  ba_usage_status,
  block_reason,
  sales_name,
  groupArray(lead_state) AS events,
  groupArray(event_time) AS events_times,
  events[1] as first_event,
  arrayMap(
    x -> (x > toDate('2017-01-01')),
    groupArray(event_time)
  ) AS events_times_index,
  arraySum(
    arrayMap(x -> (x = 'call'), groupArray(lead_state))
  ) AS calls,
  events[1] as first_state,
  groupArray(trial_comsumption_total) AS trial_consumption_totals,
  groupArray(paid_comsumption_total) AS paid_consumption_totals,
  arrayFilter(
    (t, name) -> (name = 'New'),
    events_times,
    events
  ) [1] AS time,
  
  arrayFilter(
    (events_times_index, t, name) -> (name = 'New'),
    events_times_index,
    events_times,
    events
  ) [1] AS new,
  
  arrayFilter(
    (t, name) -> (name = 'New'),
    events_times,
    events
  ) [1] AS new_time,
  
  arrayFilter(
    (events_times_index, t, name) -> (
      (name = 'Assigned')
      AND (t >= new_time)
      AND (new != 0)
    ),
    events_times_index,
    events_times,
    events
  ) [1] AS new_assigned,
  
  arrayFilter(
    (t, name) -> (
      (name = 'Assigned')
      AND (t >= new_time)
      AND (new != 0)
    ),
    events_times,
    events
  ) [1] AS new_assigned_time,
  
  arrayFilter(
    (events_times_index, t, name) -> (
      (name = 'In Process')
      AND (t >= new_assigned_time)
      AND (new_assigned != 0)
    ),
    events_times_index,
    events_times,
    events
  ) [1] AS assigned_inprocess,
  
  arrayFilter(
    (t, name) -> (
      (name = 'In Process')
      AND (t >= new_assigned_time)
      AND (new_assigned != 0)
    ),
    events_times,
    events
  ) [1] AS assigned_inprocess_time,
  
  arrayFilter(
    (events_times_index, t, name) -> (
      (name = 'Recycled')
      AND (t >= assigned_inprocess_time)
      AND (assigned_inprocess != 0)
    ),
    events_times_index,
    events_times,
    events
  ) [1] AS inprocess_recycled,
  
  arrayFilter(
    (events_times_index, t, name) -> (
      (name = 'first_paid_consumption')
      AND (t >= assigned_inprocess_time)
      AND (assigned_inprocess != 0)
    ),
    events_times_index,
    events_times,
    events
  ) [1] AS inprocess_paid_consumption,
  
  arrayFilter(
    (events_times_index, t, name) -> (
      (name = 'Converted')
      AND (t >= assigned_inprocess_time)
      AND (assigned_inprocess != 0)
    ),
    events_times_index,
    events_times,
    events
  ) [1] AS inprocess_converted,
  
  arrayFilter(
    (t, name) -> (
      (name = 'Converted')
      AND (t >= assigned_inprocess_time)
      AND (assigned_inprocess != 0)
    ),
    events_times,
    events
  ) [1] AS inprocess_converted_time,
  
  arrayFilter(
    (events_times_index, t, name) -> (
      (name = 'first_paid_consumption')
      AND (t >= new_assigned)
      AND (assigned_inprocess != 0)
      AND (inprocess_recycled = 0)
    ),
    events_times_index,
    events_times,
    events
  ) [1] AS converted_paid_consumption,
  
  arrayFilter(
    (events_times_index, t, name) -> (
      (name = 'first_paid_consumption')
      AND (t >= inprocess_recycled)
      AND (inprocess_recycled != 0)
    ),
    events_times_index,
    events_times,
    events
  ) [1] AS recycled_paid_consumption
FROM
  (
    SELECT
      *
    FROM
      cloud_analytics_testing.crm_lead_cube_test
    ORDER BY
      event_time ASC,
      lead_state DESC
  )
GROUP BY
  lead_id,
  lead_email,
  billing_account_id,
  puid,
  lead_source,
  ba_person_type,
  ba_state,
  ba_usage_status,
  block_reason,
  sales_name
'''

exucute_query(query, hosts, cloud_clickhouse_param_dict)

query = '''
DROP TABLE IF EXISTS cloud_analytics_testing.lead_funnel
'''

exucute_query(query, hosts, cloud_clickhouse_param_dict)

query = '''
RENAME TABLE cloud_analytics_testing.lead_funnel_temp TO cloud_analytics_testing.lead_funnel
'''

exucute_query(query, hosts, cloud_clickhouse_param_dict)

query = '''
DROP TABLE IF EXISTS cloud_analytics_testing.lead_funnel_temp
'''

exucute_query(query, hosts, cloud_clickhouse_param_dict)
# Out:
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://sas-tt9078df91ipro7e.db.yandex.net:8443/
# Empty Result
# ============================
#
#
# start on host: https://vla-2z4ktcci90kq2bu2.db.yandex.net:8443/
# Empty Result
# ============================
