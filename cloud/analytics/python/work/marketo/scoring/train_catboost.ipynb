# %%
import pandas as pd, numpy as np, catboost, logging, os, sys, requests, datetime
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, recall_score, precision_score, roc_auc_score
import scipy.stats as stats 
module_path = os.path.abspath(os.path.join('/home/ktereshin/yandex/arcadia/cloud/analytics/python/work'))
if module_path not in sys.path:
    sys.path.append(module_path)

from data_loader import clickhouse
from global_variables import (
    metrika_clickhouse_param_dict,
    cloud_clickhouse_param_dict
)
from nile.api.v1 import (
    clusters,
    aggregators as na,
    extractors as ne,
    filters as nf,
    Record
)
from vault_client import instances

def execute_query(query, cluster, alias, token, timeout=600):
    proxy = "http://{}.yt.yandex.net".format(cluster)
    s = requests.Session()
    url = "{proxy}/query?database={alias}&password={token}".format(proxy=proxy, alias=alias, token=token)
    resp = s.post(url, data=query, timeout=timeout)
    resp.raise_for_status()
    rows = resp.content.strip().split('\n')
    return rows

def chyt_execute_query(query, cluster, alias, token, columns):
    i = 0
    while True:
        try:
            result = execute_query(query=query, cluster=cluster, alias=alias, token=token)
            users = pd.DataFrame([row.split('\t') for row in result], columns = columns)
            return users
        except Exception as err:
            print(err)
            i += 1
            if i > 10:
                print('Break Excecution')
                break

# %%
threshold = 0.2

client = instances.Production()
yt_creds = client.get_version('ver-01d33pgv8pzc7t99s3egm24x47')
cluster_yt = clusters.yt.Hahn(
    token = yt_creds['value']['token'],
    pool = yt_creds['value']['pool'],
    
)

# %%
cluster = 'hahn'
alias = "*ch_public"
token = '%s' % (yt_creds['value']['token'])

query = '''
SELECT
    DISTINCT
    billing_account_id,
    puid
FROM "//home/cloud_analytics_test/cubes/acquisition_cube/cube"
WHERE 
    event = 'ba_created'
    AND puid != ''
'''

columns = ['billing_account_id', 'puid']
puids = chyt_execute_query(query=query, cluster=cluster, alias=alias, token=token, columns = columns)

features = cluster_yt.read('//home/cloud_analytics/scoring/learning_dataset').as_dataframe()
targets = cluster_yt.read('//home/cloud_analytics/scoring/targets').as_dataframe()

train_data = pd.merge(
    targets[targets['dataset_type'] == 'learning_set'][['puid', 'first_trial_consumption_datetime', 'start_paid_consumption']],
    features,
    on = 'puid',
    how = 'left'
).fillna('0')

to_predict = pd.merge(
    targets[targets['dataset_type'] != 'learning_set'][['puid', 'first_trial_consumption_datetime', 'start_paid_consumption']],
    features,
    on = 'puid',
    how = 'left'
).fillna('0')

train_data = shuffle(train_data).reset_index(drop=True)

X_train, X_test, y_train, y_test = train_test_split( train_data, train_data['start_paid_consumption'], test_size=0.33)
X_train, X_eval, y_train, y_eval = train_test_split( X_train, y_train, test_size=0.25)
positive = X_train[y_train == 1]
res = pd.DataFrame()
for i in range(3):
    X_train = pd.concat(
        [
            X_train,
            positive
        ]
    )
    y_train = pd.concat(
        [
            y_train,
            pd.Series([1]*positive.shape[0])
        ]
    )

cat_col = [
    'ba_payment_type',
    'ba_usage_status',
    'ba_state',
    'device_type',
    'ba_person_type',
    'age',
    'ba_payment_cycle_type',
    'ba_type',
    'channel',
    'country',
    'os',
    'promocode_source',
    'segment',
    'sex',
    'first_trial_consumption_datetime',
    'session_start_time',
    'search_phrase',
    'start_paid_consumption',
    'puid'
]
cat_indexes = []
for col in cat_col:
    cat_indexes.append(X_train.columns.get_loc(col))

ignore_col = [
'first_trial_consumption_datetime','session_start_time','search_phrase','start_paid_consumption', 'puid'
]
ignore_indexes = []
for col in ignore_col:
    ignore_indexes.append(X_train.columns.get_loc(col))

site_metrics = []
other_metrics = []
for col in X_test:
    if 'count_v' in col or 'tfidf_' in col:
        site_metrics.append(col)
    else:
        other_metrics.append(col)

features.shape[0]
site_metric_new = []
for col in site_metrics:
    temp = features[col].value_counts()[0]
    if features[col].value_counts()[0]/float(features.shape[0]) < 0.95:
        site_metric_new.append(col)

list_columns = other_metrics + site_metric_new


X_train['rand'] = np.random.rand(X_train.shape[0])
X_eval['rand'] = np.random.rand(X_eval.shape[0])
X_test['rand'] = np.random.rand(X_test.shape[0])
to_predict['rand'] = np.random.rand(to_predict.shape[0])

train_pool = catboost.Pool(X_train, y_train, cat_features = cat_indexes)
eval_pool = catboost.Pool(X_eval, y_eval, cat_features = cat_indexes)
test_pool = catboost.Pool(X_test, cat_features = cat_indexes)
predict_pool = catboost.Pool(to_predict, cat_features = cat_indexes)

learning_rate = 0.5
subsample = 0.3
bootstrap_type = 'Bernoulli'
depth = 1

model = catboost.CatBoostClassifier(
    iterations=1000,
    depth=depth,
    learning_rate=learning_rate,
    bootstrap_type = bootstrap_type,
    subsample = subsample,
    loss_function='Logloss',
    ignored_features = ignore_indexes,
    verbose=False
)
model.fit(train_pool, eval_set = eval_pool, plot = False, early_stopping_rounds = 20,use_best_model = True)

metris_dict = {
    'confusion_matrix': confusion_matrix(y_test, model.predict(test_pool)),
    'recall': recall_score(y_test, model.predict(test_pool)),
    'precision': precision_score(y_test, model.predict(test_pool)),
    'roc_auc': roc_auc_score(y_test, model.predict(test_pool))
}
print('confusion_matrix = \n%s\n' % (metris_dict['confusion_matrix']))
print('recall = %s\n' % (metris_dict['recall']))
print('precision = %s' % (metris_dict['precision']))
print('roc_auc = %s' % (metris_dict['roc_auc']))
# Out:
# /home/ktereshin/yandex/venv/lib/python2.7/site-packages/ipykernel_launcher.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# confusion_matrix =
# [[2229  346]
#  [ 162  214]]
#
# recall = 0.5691489361702128
#
# precision = 0.3821428571428571
# roc_auc = 0.7173900020656889

# %%
pd.DataFrame([model.feature_names_,model.feature_importances_]).T.rename(columns={0:'feature', 1: 'score'}).sort_values(by = 'score', ascending = False)
# Out:
#                                                 feature     score
# 24                                             ba_state   12.8968
# 23                                       ba_person_type   11.5277
# 984                    tfidf_/api/billing/createaccount   10.0412
# 914                   marketplace_trial_consumption_avg   5.72523
# 1658  tfidf_https://console.cloud.yandex.ru/billing/...   3.17832
# 853                                        event2vec_12   3.09329
# 14                          all_trial_consumption_count    3.0213
# 955                                                  os    2.8506
# 20                            all_trial_consumption_sum    1.9959
# 22                                      ba_payment_type   1.47879
# 841         count_v_https://console.cloud.yandex.ru/iam   1.38817
# 1792  tfidf_https://console.cloud.yandex.ru/folders/...   1.36554
# 1019                      tfidf_/api/iam/addcloudmember   1.07764
# 909                                           interests   1.02233
# 1786  tfidf_https://console.cloud.yandex.ru/folders/...   1.00606
# 35                  count_v_/api/billing/setpaidaccount  0.983786
# 1462  tfidf_https://cloud.yandex.ru/docs/solutions/w...  0.908077
# 705   count_v_https://console.cloud.yandex.ru/billin...    0.9044
# 888                                        event2vec_44  0.902502
# 1679  tfidf_https://console.cloud.yandex.ru/folders/...  0.880132
# 884                                        event2vec_40  0.818861
# 12                             ai_trial_consumption_sum  0.800852
# 871                                        event2vec_29  0.767786
# 1236  tfidf_https://cloud.yandex.ru/docs/compute/sec...  0.758392
# 862                                        event2vec_20  0.730092
# 880                                        event2vec_37  0.690603
# 935                        nbs_trial_consumption_median  0.690305
# 1107  tfidf_https://cloud.yandex.ru/docs/billing/con...  0.689488
# 1789  tfidf_https://console.cloud.yandex.ru/folders/...  0.685992
# 1659  tfidf_https://console.cloud.yandex.ru/billing/...  0.669498
# ...                                                 ...       ...
# 566   count_v_https://cloud.yandex.ru/docs/storage/o...         0
# 565   count_v_https://cloud.yandex.ru/docs/storage/o...         0
# 588   count_v_https://cloud.yandex.ru/docs/translate...         0
# 590   count_v_https://cloud.yandex.ru/docs/translate...         0
# 615   count_v_https://cloud.yandex.ru/docs/vpc/conce...         0
# 591   count_v_https://cloud.yandex.ru/docs/translate...         0
# 614   count_v_https://cloud.yandex.ru/docs/vpc/conce...         0
# 613   count_v_https://cloud.yandex.ru/docs/vpc/conce...         0
# 612   count_v_https://cloud.yandex.ru/docs/vpc/conce...         0
# 611   count_v_https://cloud.yandex.ru/docs/vpc/concepts         0
# 610   count_v_https://cloud.yandex.ru/docs/vpc/api-r...         0
# 609   count_v_https://cloud.yandex.ru/docs/vpc/api-r...         0
# 608   count_v_https://cloud.yandex.ru/docs/vpc/api-r...         0
# 607   count_v_https://cloud.yandex.ru/docs/vpc/api-r...         0
# 606   count_v_https://cloud.yandex.ru/docs/vpc/api-r...         0
# 605   count_v_https://cloud.yandex.ru/docs/vpc/api-r...         0
# 604    count_v_https://cloud.yandex.ru/docs/vpc/api-ref         0
# 603            count_v_https://cloud.yandex.ru/docs/vpc         0
# 602   count_v_https://cloud.yandex.ru/docs/vision/qu...         0
# 601   count_v_https://cloud.yandex.ru/docs/vision/pr...         0
# 600   count_v_https://cloud.yandex.ru/docs/vision/op...         0
# 599   count_v_https://cloud.yandex.ru/docs/vision/co...         0
# 598   count_v_https://cloud.yandex.ru/docs/vision/co...         0
# 597   count_v_https://cloud.yandex.ru/docs/vision/co...         0
# 596   count_v_https://cloud.yandex.ru/docs/vision/ap...         0
# 595         count_v_https://cloud.yandex.ru/docs/vision         0
# 594   count_v_https://cloud.yandex.ru/docs/translate...         0
# 593   count_v_https://cloud.yandex.ru/docs/translate...         0
# 592   count_v_https://cloud.yandex.ru/docs/translate...         0
# 900                         image_trial_consumption_avg         0
#
# [1800 rows x 2 columns]

# %%
model.feature_names_
# Out:
# ['puid',
#  'first_trial_consumption_datetime',
#  'start_paid_consumption',
#  'ad_block',
#  'age',
#  'ai_trial_consumption_avg',
#  'ai_trial_consumption_count',
#  'ai_trial_consumption_count_more_avg',
#  'ai_trial_consumption_max',
#  'ai_trial_consumption_median',
#  'ai_trial_consumption_min',
#  'ai_trial_consumption_std',
#  'ai_trial_consumption_sum',
#  'all_trial_consumption_avg',
#  'all_trial_consumption_count',
#  'all_trial_consumption_count_more_avg',
#  'all_trial_consumption_max',
#  'all_trial_consumption_median',
#  'all_trial_consumption_min',
#  'all_trial_consumption_std',
#  'all_trial_consumption_sum',
#  'ba_payment_cycle_type',
#  'ba_payment_type',
#  'ba_person_type',
#  'ba_state',
#  'ba_type',
#  'ba_usage_status',
#  'channel',
#  'count_v_/_/tools/startrek/setalpharequest',
#  'count_v_/api/alpharequest',
#  'count_v_/api/billing/activategrant',
#  'count_v_/api/billing/bindpaymentcard',
#  'count_v_/api/billing/createaccount',
#  'count_v_/api/billing/makecardpayment',
#  'count_v_/api/billing/makeinvoicepayment',
#  'count_v_/api/billing/setpaidaccount',
#  'count_v_/api/clickhouse/createcluster',
#  'count_v_/api/clickhouse/deletecluster',
#  'count_v_/api/compute/addlistener',
#  'count_v_/api/compute/createaddress',
#  'count_v_/api/compute/createbalancer',
#  'count_v_/api/compute/createdefaultnetwork',
#  'count_v_/api/compute/createdisk',
#  'count_v_/api/compute/createimage',
#  'count_v_/api/compute/createinstance',
#  'count_v_/api/compute/createnetwork',
#  'count_v_/api/compute/createsnapshot',
#  'count_v_/api/compute/createsubnet',
#  'count_v_/api/compute/createtargetgroup',
#  'count_v_/api/compute/deleteaddress',
#  'count_v_/api/compute/deletebalancer',
#  'count_v_/api/compute/deletedisk',
#  'count_v_/api/compute/deleteimage',
#  'count_v_/api/compute/deleteinstance',
#  'count_v_/api/compute/deletenetwork',
#  'count_v_/api/compute/deletesnapshot',
#  'count_v_/api/compute/deletesubnet',
#  'count_v_/api/compute/deletetargetgroup',
#  'count_v_/api/compute/restartinstance',
#  'count_v_/api/compute/startinstance',
#  'count_v_/api/compute/stopinstance',
#  'count_v_/api/compute/updateaddress',
#  'count_v_/api/compute/updatedisk',
#  'count_v_/api/compute/updateinstance',
#  'count_v_/api/compute/updatesnapshot',
#  'count_v_/api/compute/updatesubnet',
#  'count_v_/api/datalens/init',
#  'count_v_/api/iam/addcloudmember',
#  'count_v_/api/iam/createcloudpublic',
#  'count_v_/api/iam/createfolder',
#  'count_v_/api/iam/createkey',
#  'count_v_/api/iam/createserviceaccount',
#  'count_v_/api/iam/createserviceaccountkey',
#  'count_v_/api/iam/deletecloudmember',
#  'count_v_/api/iam/deletekey',
#  'count_v_/api/iam/deleteserviceaccount',
#  'count_v_/api/iam/deleteserviceaccountkey',
#  'count_v_/api/iam/updatecloudaccessbinding',
#  'count_v_/api/iam/updatefolder',
#  'count_v_/api/iam/updatefolderaccessbinding',
#  'count_v_/api/iam/updateserviceaccount',
#  'count_v_/api/iam/updateusersettings',
#  'count_v_/api/iam/whoami',
#  'count_v_/api/mongodb/createcluster',
#  'count_v_/api/mongodb/deletecluster',
#  'count_v_/api/mysql/createcluster',
#  'count_v_/api/mysql/deletecluster',
#  'count_v_/api/postgresql/adduser',
#  'count_v_/api/postgresql/createbackup',
#  'count_v_/api/postgresql/createcluster',
#  'count_v_/api/postgresql/createdatabase',
#  'count_v_/api/postgresql/createhosts',
#  'count_v_/api/postgresql/deletecluster',
#  'count_v_/api/postgresql/deletedatabase',
#  'count_v_/api/postgresql/deletehosts',
#  'count_v_/api/postgresql/stopcluster',
#  'count_v_/api/postgresql/updateclusteroptions',
#  'count_v_/api/postgresql/updatehost',
#  'count_v_/api/postgresql/updateuser',
#  'count_v_/api/redis/createcluster',
#  'count_v_/api/storage/createbucket',
#  'count_v_/api/storage/createfolder',
#  'count_v_/api/storage/createpresignurls',
#  'count_v_/api/storage/deletebucket',
#  'count_v_/api/storage/deletebucketwebsite',
#  'count_v_/api/storage/deleteobject',
#  'count_v_/api/storage/updatebucket',
#  'count_v_/api/storage/updatebucketcors',
#  'count_v_/api/storage/updatebucketwebsite',
#  'count_v_/form/alpha',
#  'count_v_/form/partners',
#  'count_v_/form/preview',
#  'count_v_/form/sales',
#  'count_v_/forms/sales',
#  'count_v_/forms/waitlist',
#  'count_v_/grpc/cr/registry/create',
#  'count_v_/grpc/cr/registry/delete',
#  'count_v_https://cloud.yandex.com',
#  'count_v_https://cloud.yandex.ru',
#  'count_v_https://cloud.yandex.ru/api/blog/posts',
#  'count_v_https://cloud.yandex.ru/api/blog/posts/2019/03/wp',
#  'count_v_https://cloud.yandex.ru/api/blog/posts?page=2',
#  'count_v_https://cloud.yandex.ru/api/blog/tags',
#  'count_v_https://cloud.yandex.ru/api/marketplace/categories',
#  'count_v_https://cloud.yandex.ru/api/marketplace/products',
#  'count_v_https://cloud.yandex.ru/api/marketplace/products/id',
#  'count_v_https://cloud.yandex.ru/api/marketplace/products?category=f2e0hv8asm05k96ga3mr',
#  'count_v_https://cloud.yandex.ru/api/marketplace/products?category=f2e68uj9hngmlv862m84',
#  'count_v_https://cloud.yandex.ru/api/marketplace/products?category=f2e98ks7tcqp6rhn1u7a',
#  'count_v_https://cloud.yandex.ru/api/marketplace/products?category=f2ei3bjkd7u5qgke8d2s',
#  'count_v_https://cloud.yandex.ru/api/prices/compute/data',
#  'count_v_https://cloud.yandex.ru/api/prices/translate?data=%7b%22count%22:100000%7d&interval=2592000',
#  'count_v_https://cloud.yandex.ru/blog',
#  'count_v_https://cloud.yandex.ru/blog/posts/2019/03/wp',
#  'count_v_https://cloud.yandex.ru/docs',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/about-async',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/about-methods',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/async',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/custom-methods',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/errors',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/general',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/idempotency',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/operation',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/pagination',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/resources-identification',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/standard-fields',
#  'count_v_https://cloud.yandex.ru/docs/api-design-guide/concepts/standard-methods',
#  'count_v_https://cloud.yandex.ru/docs/billing',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/bill',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/billing-account',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/billing-account-statuses',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/bonus-account',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/contract',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/credit-limit',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/glossary',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/personal-account',
#  'count_v_https://cloud.yandex.ru/docs/billing/concepts/promo-code',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/activate-commercial',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/activate-promocode',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/change-data',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/change-payment-method',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/check-bill-history',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/check-charges',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/check-diagram',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/index',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/pay-the-bill',
#  'count_v_https://cloud.yandex.ru/docs/billing/operations/pin-card',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/billing-cycle',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/billing-cycle-business',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/billing-cycle-individual',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/currency',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/documents',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/index',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/payment-methods',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/payment-methods-business',
#  'count_v_https://cloud.yandex.ru/docs/billing/payment/payment-methods-individual',
#  'count_v_https://cloud.yandex.ru/docs/billing/pricing',
#  'count_v_https://cloud.yandex.ru/docs/billing/qa/all',
#  'count_v_https://cloud.yandex.ru/docs/billing/qa/billing-account',
#  'count_v_https://cloud.yandex.ru/docs/billing/qa/common',
#  'count_v_https://cloud.yandex.ru/docs/billing/qa/payment',
#  'count_v_https://cloud.yandex.ru/docs/billing/qa/trial-commercial',
#  'count_v_https://cloud.yandex.ru/docs/billing/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/billing/quickstart/index',
#  'count_v_https://cloud.yandex.ru/docs/billing/security',
#  'count_v_https://cloud.yandex.ru/docs/billing/trial/activation',
#  'count_v_https://cloud.yandex.ru/docs/cli',
#  'count_v_https://cloud.yandex.ru/docs/cli/command-tree',
#  'count_v_https://cloud.yandex.ru/docs/cli/command-tree/manage-services/compute',
#  'count_v_https://cloud.yandex.ru/docs/cli/command-tree/manage-services/iam',
#  'count_v_https://cloud.yandex.ru/docs/cli/command-tree/manage-yc/components',
#  'count_v_https://cloud.yandex.ru/docs/cli/command-tree/manage-yc/config',
#  'count_v_https://cloud.yandex.ru/docs/cli/command-tree/manage-yc/operation',
#  'count_v_https://cloud.yandex.ru/docs/cli/concepts',
#  'count_v_https://cloud.yandex.ru/docs/cli/concepts/core-propreties',
#  'count_v_https://cloud.yandex.ru/docs/cli/concepts/profile',
#  'count_v_https://cloud.yandex.ru/docs/cli/error',
#  'count_v_https://cloud.yandex.ru/docs/cli/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/compute',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/authentication',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/disk',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/disk/create',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/disk/delete',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/disk/get',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/disk/list',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/disk/update',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/disktype',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/image',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/image/create',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/instance',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/instance/attachdisk',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/instance/create',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/instance/get',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/operation',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/operation/get',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/snapshot',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/zone',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/zone/get',
#  'count_v_https://cloud.yandex.ru/docs/compute/api-ref/zone/list',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/disk',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/images',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/instance-groups',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/network',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/performance-levels',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/preemptible-vm',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/snapshot',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/vm',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/vm-metadata',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/vm-platforms',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/vm-statuses',
#  'count_v_https://cloud.yandex.ru/docs/compute/concepts/vm-types',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/disk-control/create-snapshot',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/disk-control/delete',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/disk-control/disk-update',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/disk-create/empty',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/dsvm',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/dsvm/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/image-create/upload',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/images-with-pre-installed-software/create',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/images-with-pre-installed-software/get-list',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/images-with-pre-installed-software/operate',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/images-with-pre-installed-software/setup',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/serial-console',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/serial-console/connect',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/serial-console/connect-cli',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/serial-console/connect-ssh',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/snapshot-control/delete',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-attach-disk',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-change-zone',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-connect-rdp',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-connect-ssh',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-delete',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-detach-disk',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-set-static-ip',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-stop-and-start',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-update',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-control/vm-update-resources',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-create/create-from-disks',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-create/create-from-snapshots',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-create/create-from-user-image',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-create/create-linux-vm',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-create/create-preemptible-vm',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-create/create-windows-vm',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-info/get-info',
#  'count_v_https://cloud.yandex.ru/docs/compute/operations/vm-info/get-serial-port-output',
#  'count_v_https://cloud.yandex.ru/docs/compute/pricing',
#  'count_v_https://cloud.yandex.ru/docs/compute/pricing-archive/pricing-01012019',
#  'count_v_https://cloud.yandex.ru/docs/compute/pricing-archive/pricing-01032019',
#  'count_v_https://cloud.yandex.ru/docs/compute/qa/all',
#  'count_v_https://cloud.yandex.ru/docs/compute/qa/disks',
#  'count_v_https://cloud.yandex.ru/docs/compute/qa/general',
#  'count_v_https://cloud.yandex.ru/docs/compute/qa/vm',
#  'count_v_https://cloud.yandex.ru/docs/compute/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/compute/quickstart/ig',
#  'count_v_https://cloud.yandex.ru/docs/compute/quickstart/quick-create-linux',
#  'count_v_https://cloud.yandex.ru/docs/compute/quickstart/quick-create-windows',
#  'count_v_https://cloud.yandex.ru/docs/compute/security',
#  'count_v_https://cloud.yandex.ru/docs/container-registry',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/concepts',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/concepts/docker-image',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/concepts/registry',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/concepts/repository',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/operations',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/operations/authentication',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/operations/docker-image/docker-image-create',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/operations/docker-image/docker-image-list',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/operations/docker-image/docker-image-push',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/operations/registry/registry-list',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/pricing',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/container-registry/scenario',
#  'count_v_https://cloud.yandex.ru/docs/datalens',
#  'count_v_https://cloud.yandex.ru/docs/datalens/pricing',
#  'count_v_https://cloud.yandex.ru/docs/datalens/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/free-trial',
#  'count_v_https://cloud.yandex.ru/docs/free-trial/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/free-trial/concepts/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/free-trial/concepts/trial-ending',
#  'count_v_https://cloud.yandex.ru/docs/free-trial/concepts/upgrade-to-paid',
#  'count_v_https://cloud.yandex.ru/docs/free-trial/concepts/usage-monitor',
#  'count_v_https://cloud.yandex.ru/docs/iam',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/accesskey',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/accesskey/create',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/authentication',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/iamtoken',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/iamtoken/create',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/key',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/key/create',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/operation',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/serviceaccount',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/serviceaccount/list',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/useraccount',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/useraccount/get',
#  'count_v_https://cloud.yandex.ru/docs/iam/api-ref/yandexpassportuseraccount',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/access-control',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/access-control/access-bindings',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/access-control/roles',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/access-control/system-group',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/authorization',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/authorization/access-key',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/authorization/authorization',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/authorization/iam-token',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/authorization/key',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/authorization/oauth-token',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/overview',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/users/service-accounts',
#  'count_v_https://cloud.yandex.ru/docs/iam/concepts/users/users',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/iam-token/create',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/iam-token/create-for-sa',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/roles/grant',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/roles/revoke',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/sa/assign-role-for-sa',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/sa/create',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/sa/create-access-key',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/sa/delete',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/sa/set-access-bindings',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/sa/update',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/users/create',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/users/delete',
#  'count_v_https://cloud.yandex.ru/docs/iam/operations/users/get',
#  'count_v_https://cloud.yandex.ru/docs/iam/pricing',
#  'count_v_https://cloud.yandex.ru/docs/iam/qa',
#  'count_v_https://cloud.yandex.ru/docs/iam/qa/access',
#  'count_v_https://cloud.yandex.ru/docs/iam/qa/general',
#  'count_v_https://cloud.yandex.ru/docs/iam/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/iam/security',
#  'count_v_https://cloud.yandex.ru/docs/instance-groups',
#  'count_v_https://cloud.yandex.ru/docs/instance-groups/pricing',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer/best-practices',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer/concepts',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer/concepts/index',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer/concepts/listener',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer/operations/load-balancer-create',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer/pricing',
#  'count_v_https://cloud.yandex.ru/docs/load-balancer/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/concepts',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/concepts/instance-types',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/concepts/network',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/operations',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/operations/cluster-create',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/operations/cluster-list',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/operations/cluster-users',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/operations/connect',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/operations/update',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/operations/web-sql-query',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/pricing',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/qa/clickhouse',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/managed-clickhouse/security',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/concepts',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/concepts/instance-types',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/concepts/network',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/concepts/replication',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/operations',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/operations/cluster-create',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/operations/cluster-list',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/operations/cluster-users',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/operations/connect',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/operations/update',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/pricing',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/qa/mongodb',
#  'count_v_https://cloud.yandex.ru/docs/managed-mongodb/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/concepts',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/concepts/instance-types',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/concepts/network',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/concepts/replication',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/operations',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/operations/cluster-create',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/operations/cluster-users',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/operations/connect',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/operations/databases',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/operations/hosts',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/pricing',
#  'count_v_https://cloud.yandex.ru/docs/managed-mysql/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/api-ref/authentication',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/api-ref/backup',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/api-ref/database',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/concepts',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/concepts/backup',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/concepts/instance-types',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/concepts/network',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/concepts/replication',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/concepts/supported-clients',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/cluster-backups',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/cluster-create',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/cluster-extensions',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/cluster-list',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/cluster-users',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/connect',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/data-migration',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/databases',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/hosts',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/operations/update',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/pricing',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/qa/all',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/qa/general',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/qa/postgresql',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/managed-postgresql/security',
#  'count_v_https://cloud.yandex.ru/docs/managed-redis',
#  'count_v_https://cloud.yandex.ru/docs/managed-redis/concepts',
#  'count_v_https://cloud.yandex.ru/docs/managed-redis/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/managed-redis/pricing',
#  'count_v_https://cloud.yandex.ru/docs/managed-redis/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/mdb',
#  'count_v_https://cloud.yandex.ru/docs/mdb/concepts/instance-types',
#  'count_v_https://cloud.yandex.ru/docs/mdb/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/mdb/pricing',
#  'count_v_https://cloud.yandex.ru/docs/mdb/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/message-queue',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/concepts',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/concepts/queue',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/instruments',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/operations/message-queue-new-queue',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/operations/message-queue-receive-and-delete-message',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/operations/message-queue-send-message',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/pricing',
#  'count_v_https://cloud.yandex.ru/docs/message-queue/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/monitoring',
#  'count_v_https://cloud.yandex.ru/docs/monitoring/pricing',
#  'count_v_https://cloud.yandex.ru/docs/overview',
#  'count_v_https://cloud.yandex.ru/docs/overview/api',
#  'count_v_https://cloud.yandex.ru/docs/overview/concepts/geo-scope',
#  'count_v_https://cloud.yandex.ru/docs/overview/concepts/launch-stages',
#  'count_v_https://cloud.yandex.ru/docs/overview/concepts/services',
#  'count_v_https://cloud.yandex.ru/docs/overview/qa',
#  'count_v_https://cloud.yandex.ru/docs/overview/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/overview/sla',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/api-ref/authentication',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/api-ref/cloud',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/api-ref/cloud/get',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/api-ref/cloud/list',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/api-ref/folder',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/api-ref/folder/list',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/concepts/resources-hierarchy',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/operations',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/operations/cloud/set-access-bindings',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/operations/cloud/switch-cloud',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/operations/folder/create',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/operations/folder/delete',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/operations/folder/get-id',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/operations/folder/set-access-bindings',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/operations/folder/update',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/pricing',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/resource-manager/security',
#  'count_v_https://cloud.yandex.ru/docs/solutions',
#  'count_v_https://cloud.yandex.ru/docs/solutions/archive',
#  'count_v_https://cloud.yandex.ru/docs/solutions/archive/object-storage-acronis',
#  'count_v_https://cloud.yandex.ru/docs/solutions/archive/object-storage-cloudberry',
#  'count_v_https://cloud.yandex.ru/docs/solutions/archive/object-storage-duplicati',
#  'count_v_https://cloud.yandex.ru/docs/solutions/archive/single-node-file-server',
#  'count_v_https://cloud.yandex.ru/docs/solutions/infrastructure-management',
#  'count_v_https://cloud.yandex.ru/docs/solutions/infrastructure-management/terraform-quickstart',
#  'count_v_https://cloud.yandex.ru/docs/solutions/testing',
#  'count_v_https://cloud.yandex.ru/docs/solutions/testing/ci-for-snapshots',
#  'count_v_https://cloud.yandex.ru/docs/solutions/web',
#  'count_v_https://cloud.yandex.ru/docs/solutions/web/dns-load-balancer',
#  'count_v_https://cloud.yandex.ru/docs/solutions/web/joomla-postgresql',
#  'count_v_https://cloud.yandex.ru/docs/solutions/web/lamp-lemp',
#  'count_v_https://cloud.yandex.ru/docs/solutions/web/static',
#  'count_v_https://cloud.yandex.ru/docs/solutions/web/wordpress',
#  'count_v_https://cloud.yandex.ru/docs/speechkit',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/concepts/auth',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/concepts/ivr-integration',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/concepts/response',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/pricing',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/pricing-archive/pricing-01012019',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/stt',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/stt/formats',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/stt/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/stt/request',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/stt/streaming',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/tts',
#  'count_v_https://cloud.yandex.ru/docs/speechkit/tts/request',
#  'count_v_https://cloud.yandex.ru/docs/storage',
#  'count_v_https://cloud.yandex.ru/docs/storage/concepts',
#  'count_v_https://cloud.yandex.ru/docs/storage/concepts/bucket',
#  'count_v_https://cloud.yandex.ru/docs/storage/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/storage/concepts/multipart',
#  'count_v_https://cloud.yandex.ru/docs/storage/concepts/object',
#  'count_v_https://cloud.yandex.ru/docs/storage/concepts/storage-class',
#  'count_v_https://cloud.yandex.ru/docs/storage/cors',
#  'count_v_https://cloud.yandex.ru/docs/storage/cors/configuration',
#  'count_v_https://cloud.yandex.ru/docs/storage/cors/setup',
#  'count_v_https://cloud.yandex.ru/docs/storage/hosting',
#  'count_v_https://cloud.yandex.ru/docs/storage/hosting/answer-codes',
#  'count_v_https://cloud.yandex.ru/docs/storage/hosting/bucket-configuration',
#  'count_v_https://cloud.yandex.ru/docs/storage/hosting/setup',
#  'count_v_https://cloud.yandex.ru/docs/storage/id',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/bucket',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/common-request-headers',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/common-response-headers',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/cors',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/hosting',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/hosting/upload',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/multipart',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/multipart/startupload',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/object',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/object/get',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/object/getobjectmeta',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/object/options',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/object/upload',
#  'count_v_https://cloud.yandex.ru/docs/storage/id/api-ref/response-codes',
#  'count_v_https://cloud.yandex.ru/docs/storage/instruments',
#  'count_v_https://cloud.yandex.ru/docs/storage/instruments/aws-cli',
#  'count_v_https://cloud.yandex.ru/docs/storage/instruments/aws-sdk-java',
#  'count_v_https://cloud.yandex.ru/docs/storage/instruments/boto',
#  'count_v_https://cloud.yandex.ru/docs/storage/instruments/cyberduck',
#  'count_v_https://cloud.yandex.ru/docs/storage/instruments/id',
#  'count_v_https://cloud.yandex.ru/docs/storage/lifecycles',
#  'count_v_https://cloud.yandex.ru/docs/storage/lifecycles/configuration',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/buckets/bucket-availability',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/buckets/create',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/buckets/delete',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/buckets/limit-max-volume',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/index',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/objects/delete',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/objects/download',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/objects/info',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/objects/link-for-download',
#  'count_v_https://cloud.yandex.ru/docs/storage/operations/objects/upload',
#  'count_v_https://cloud.yandex.ru/docs/storage/pricing',
#  'count_v_https://cloud.yandex.ru/docs/storage/qa',
#  'count_v_https://cloud.yandex.ru/docs/storage/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/storage/security',
#  'count_v_https://cloud.yandex.ru/docs/support',
#  'count_v_https://cloud.yandex.ru/docs/support/overview',
#  'count_v_https://cloud.yandex.ru/docs/support/qa',
#  'count_v_https://cloud.yandex.ru/docs/translate',
#  'count_v_https://cloud.yandex.ru/docs/translate/api-ref/detect',
#  'count_v_https://cloud.yandex.ru/docs/translate/api-ref/languages',
#  'count_v_https://cloud.yandex.ru/docs/translate/api-ref/translate',
#  'count_v_https://cloud.yandex.ru/docs/translate/api-ref/translation',
#  'count_v_https://cloud.yandex.ru/docs/translate/api-ref/translation/translate',
#  'count_v_https://cloud.yandex.ru/docs/translate/concepts/auth',
#  'count_v_https://cloud.yandex.ru/docs/translate/concepts/response',
#  'count_v_https://cloud.yandex.ru/docs/translate/operations',
#  'count_v_https://cloud.yandex.ru/docs/translate/operations/detect',
#  'count_v_https://cloud.yandex.ru/docs/translate/operations/index',
#  'count_v_https://cloud.yandex.ru/docs/translate/operations/translate',
#  'count_v_https://cloud.yandex.ru/docs/translate/pricing',
#  'count_v_https://cloud.yandex.ru/docs/vision',
#  'count_v_https://cloud.yandex.ru/docs/vision/api-ref/vision/batchanalyze',
#  'count_v_https://cloud.yandex.ru/docs/vision/concepts',
#  'count_v_https://cloud.yandex.ru/docs/vision/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/vision/concepts/ocr',
#  'count_v_https://cloud.yandex.ru/docs/vision/operations/ocr/text-detection',
#  'count_v_https://cloud.yandex.ru/docs/vision/pricing',
#  'count_v_https://cloud.yandex.ru/docs/vision/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/vpc',
#  'count_v_https://cloud.yandex.ru/docs/vpc/api-ref',
#  'count_v_https://cloud.yandex.ru/docs/vpc/api-ref/authentication',
#  'count_v_https://cloud.yandex.ru/docs/vpc/api-ref/network',
#  'count_v_https://cloud.yandex.ru/docs/vpc/api-ref/network/create',
#  'count_v_https://cloud.yandex.ru/docs/vpc/api-ref/operation',
#  'count_v_https://cloud.yandex.ru/docs/vpc/api-ref/operation/get',
#  'count_v_https://cloud.yandex.ru/docs/vpc/api-ref/subnet',
#  'count_v_https://cloud.yandex.ru/docs/vpc/concepts',
#  'count_v_https://cloud.yandex.ru/docs/vpc/concepts/address',
#  'count_v_https://cloud.yandex.ru/docs/vpc/concepts/index',
#  'count_v_https://cloud.yandex.ru/docs/vpc/concepts/limits',
#  'count_v_https://cloud.yandex.ru/docs/vpc/concepts/mtu-mss',
#  'count_v_https://cloud.yandex.ru/docs/vpc/concepts/network',
#  'count_v_https://cloud.yandex.ru/docs/vpc/ddos-protection',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/address-delete',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/enable-ddos-protection',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/get-static-ip',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/index',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/network-create',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/network-delete',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/network-update',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/set-dynamic-ip',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/set-static-ip',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/subnet-create',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/subnet-delete',
#  'count_v_https://cloud.yandex.ru/docs/vpc/operations/subnet-update',
#  'count_v_https://cloud.yandex.ru/docs/vpc/pricing',
#  'count_v_https://cloud.yandex.ru/docs/vpc/pricing-archive/pricing-01012019',
#  'count_v_https://cloud.yandex.ru/docs/vpc/qa',
#  'count_v_https://cloud.yandex.ru/docs/vpc/quickstart',
#  'count_v_https://cloud.yandex.ru/docs/vpc/security',
#  'count_v_https://cloud.yandex.ru/form/alpha?service=container-registry',
#  'count_v_https://cloud.yandex.ru/form/alpha?service=instance-groups',
#  'count_v_https://cloud.yandex.ru/form/alpha?service=load-balancer',
#  'count_v_https://cloud.yandex.ru/form/alpha?service=managed-mysql',
#  'count_v_https://cloud.yandex.ru/form/alpha?service=managed-redis',
#  'count_v_https://cloud.yandex.ru/form/alpha?service=message-queue',
#  'count_v_https://cloud.yandex.ru/form/preview?service=datalens',
#  'count_v_https://cloud.yandex.ru/form/preview?service=monitoring',
#  'count_v_https://cloud.yandex.ru/marketplace',
#  'count_v_https://cloud.yandex.ru/marketplace/products/id',
#  'count_v_https://cloud.yandex.ru/partners',
#  'count_v_https://cloud.yandex.ru/partners/find',
#  'count_v_https://cloud.yandex.ru/partners/service',
#  'count_v_https://cloud.yandex.ru/partners/tech',
#  'count_v_https://cloud.yandex.ru/prices',
#  'count_v_https://cloud.yandex.ru/services',
#  'count_v_https://cloud.yandex.ru/services/compute',
#  'count_v_https://cloud.yandex.ru/services/container-registry',
#  'count_v_https://cloud.yandex.ru/services/datalens',
#  'count_v_https://cloud.yandex.ru/services/iam',
#  'count_v_https://cloud.yandex.ru/services/instance-groups',
#  'count_v_https://cloud.yandex.ru/services/load-balancer',
#  'count_v_https://cloud.yandex.ru/services/managed-clickhouse',
#  'count_v_https://cloud.yandex.ru/services/managed-mongodb',
#  'count_v_https://cloud.yandex.ru/services/managed-mysql',
#  'count_v_https://cloud.yandex.ru/services/managed-postgresql',
#  'count_v_https://cloud.yandex.ru/services/mdb',
#  'count_v_https://cloud.yandex.ru/services/message-queue',
#  'count_v_https://cloud.yandex.ru/services/monitoring',
#  'count_v_https://cloud.yandex.ru/services/resource-manager',
#  'count_v_https://cloud.yandex.ru/services/speechkit',
#  'count_v_https://cloud.yandex.ru/services/storage',
#  'count_v_https://cloud.yandex.ru/services/translate',
#  'count_v_https://cloud.yandex.ru/services/vision',
#  'count_v_https://cloud.yandex.ru/services/vpc',
#  'count_v_https://cloud.yandex.ru/solutions/archive',
#  'count_v_https://cloud.yandex.ru/solutions/web-service',
#  'count_v_https://cloud.yandex.ru/support',
#  'count_v_https://console.cloud.yandex.com',
#  'count_v_https://console.cloud.yandex.com/?section=quotas',
#  'count_v_https://console.cloud.yandex.com/billing/accounts/id',
#  'count_v_https://console.cloud.yandex.com/billing/create-account',
#  'count_v_https://console.cloud.yandex.com/folders/id',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute/create-instance',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute/instance/id',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute/instance/id/edit-instance',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute/instance/id?section=monitoring',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute/instance/id?section=operations',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute/instance/id?section=overview',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute/instance/id?section=service-console',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute?section=disks',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute?section=images',
#  'count_v_https://console.cloud.yandex.com/folders/id/compute?section=operations',
#  'count_v_https://console.cloud.yandex.com/folders/id/storage',
#  'count_v_https://console.cloud.yandex.com/folders/id/vpc',
#  'count_v_https://console.cloud.yandex.com/folders/id/vpc/network/id',
#  'count_v_https://console.cloud.yandex.com/folders/id/vpc?section=addresses',
#  'count_v_https://console.cloud.yandex.com/folders/id/vpc?section=list',
#  'count_v_https://console.cloud.yandex.com/folders/id?section=service-accounts',
#  'count_v_https://console.cloud.yandex.com/settings',
#  'count_v_https://console.cloud.yandex.com/settings?section=lang',
#  'count_v_https://console.cloud.yandex.ru',
#  'count_v_https://console.cloud.yandex.ru/?section=info',
#  'count_v_https://console.cloud.yandex.ru/?section=overview',
#  'count_v_https://console.cloud.yandex.ru/?section=quotas',
#  'count_v_https://console.cloud.yandex.ru/?source=&status=action-not-required',
#  'count_v_https://console.cloud.yandex.ru/billing',
#  'count_v_https://console.cloud.yandex.ru/billing/accounts/id',
#  'count_v_https://console.cloud.yandex.ru/billing/accounts/id?section=detail',
#  'count_v_https://console.cloud.yandex.ru/billing/accounts/id?section=history',
#  'count_v_https://console.cloud.yandex.ru/billing/accounts/id?section=overview',
#  'count_v_https://console.cloud.yandex.ru/billing/create-account',
#  'count_v_https://console.cloud.yandex.ru/clouds/id',
#  'count_v_https://console.cloud.yandex.ru/clouds/id/id',
#  'count_v_https://console.cloud.yandex.ru/create-folder',
#  'count_v_https://console.cloud.yandex.ru/folders',
#  'count_v_https://console.cloud.yandex.ru/folders/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api/speechkit',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api/speechkit?section=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api/speechkit?section=overview',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api/translate',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api/translate?section=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api/translate?section=overview',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api/vision',
#  'count_v_https://console.cloud.yandex.ru/folders/id/api/vision?section=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/clickhouse',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/create-disk',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/create-group',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/create-instance',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/disks/id/edit-disk',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance-group/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance/id/disks/id/edit-disk',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance/id/edit-instance',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance/id?section=disks',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance/id?section=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance/id?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance/id?section=overview',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute/instance/id?section=service-console',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute?section=disks',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute?section=images',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute?section=instance-groups',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/compute?section=snapshots',
#  'count_v_https://console.cloud.yandex.ru/folders/id/container-registry',
#  'count_v_https://console.cloud.yandex.ru/folders/id/container-registry/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/container-registry?create=true',
#  'count_v_https://console.cloud.yandex.ru/folders/id/datalens',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer/balancer/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer/balancer/id/edit-balancer',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer/balancer/id?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer/balancer/id?section=overview',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer/create-balancer',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer/create-target-group',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer?section=balancers',
#  'count_v_https://console.cloud.yandex.ru/folders/id/load-balancer?section=target-groups',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id/edit',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=backups',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=databases',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=hosts',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=hosts&tab=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=logs',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=sql',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/cluster/id?section=users',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse/create-cluster',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-clickhouse?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id/edit',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id?section=backups',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id?section=databases',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id?section=hosts',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id?section=hosts&tab=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id?section=logs',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id?section=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/cluster/id?section=users',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb/create-cluster',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mongodb?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id/edit',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id?section=backups',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id?section=databases',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id?section=hosts',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id?section=hosts&tab=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id?section=logs',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id?section=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/cluster/id?section=users',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql/create-cluster',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-mysql?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id/edit',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id?section=backups',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id?section=databases',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id?section=hosts',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id?section=hosts&tab=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id?section=logs',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id?section=monitoring',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/cluster/id?section=users',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql/create-cluster',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-postgresql?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-redis',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-redis/cluster/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-redis/create-cluster',
#  'count_v_https://console.cloud.yandex.ru/folders/id/managed-redis?section=operations',
#  'count_v_https://console.cloud.yandex.ru/folders/id/mdb',
#  'count_v_https://console.cloud.yandex.ru/folders/id/message-queue',
#  'count_v_https://console.cloud.yandex.ru/folders/id/message-queue/create',
#  'count_v_https://console.cloud.yandex.ru/folders/id/message-queue?section=statistics',
#  'count_v_https://console.cloud.yandex.ru/folders/id/mongodb',
#  'count_v_https://console.cloud.yandex.ru/folders/id/postgresql',
#  'count_v_https://console.cloud.yandex.ru/folders/id/service-account/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/.com',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/.com?section=website',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/.ru',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/.ru?section=cors',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/.ru?section=website',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/?section=cors',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/?section=lifecycle',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/?section=settings',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/bucket/?section=website',
#  'count_v_https://console.cloud.yandex.ru/folders/id/storage/create-bucket',
#  'count_v_https://console.cloud.yandex.ru/folders/id/vpc',
#  'count_v_https://console.cloud.yandex.ru/folders/id/vpc/create-network',
#  'count_v_https://console.cloud.yandex.ru/folders/id/vpc/network/id',
#  'count_v_https://console.cloud.yandex.ru/folders/id/vpc/network/id/create-subnetwork',
#  'count_v_https://console.cloud.yandex.ru/folders/id/vpc/network/id/subnet/id/edit-subnetwork',
#  'count_v_https://console.cloud.yandex.ru/folders/id/vpc?section=addresses',
#  'count_v_https://console.cloud.yandex.ru/folders/id/vpc?section=list',
#  'count_v_https://console.cloud.yandex.ru/folders/id?section=robots',
#  'count_v_https://console.cloud.yandex.ru/folders/id?section=service-accounts',
#  'count_v_https://console.cloud.yandex.ru/iam',
#  'count_v_https://console.cloud.yandex.ru/settings',
#  'count_v_https://console.cloud.yandex.ru/settings?section=lang',
#  'count_v_https://console.cloud.yandex.ru/support',
#  'country',
#  'days_between_cloud_ba',
#  'days_between_first_visit_cloud',
#  'device_type',
#  'event2vec_0',
#  'event2vec_1',
#  'event2vec_10',
#  'event2vec_11',
#  'event2vec_12',
#  'event2vec_13',
#  'event2vec_14',
#  'event2vec_15',
#  'event2vec_16',
#  'event2vec_17',
#  'event2vec_18',
#  'event2vec_19',
#  'event2vec_2',
#  'event2vec_20',
#  'event2vec_21',
#  'event2vec_22',
#  'event2vec_23',
#  'event2vec_24',
#  'event2vec_25',
#  'event2vec_26',
#  'event2vec_27',
#  'event2vec_28',
#  'event2vec_29',
#  'event2vec_3',
#  'event2vec_30',
#  'event2vec_31',
#  'event2vec_32',
#  'event2vec_33',
#  'event2vec_34',
#  'event2vec_35',
#  'event2vec_36',
#  'event2vec_37',
#  'event2vec_38',
#  'event2vec_39',
#  'event2vec_4',
#  'event2vec_40',
#  'event2vec_41',
#  'event2vec_42',
#  'event2vec_43',
#  'event2vec_44',
#  'event2vec_45',
#  'event2vec_46',
#  'event2vec_47',
#  'event2vec_48',
#  'event2vec_49',
#  'event2vec_5',
#  'event2vec_6',
#  'event2vec_7',
#  'event2vec_8',
#  'event2vec_9',
#  'hits',
#  'image_trial_consumption_avg',
#  'image_trial_consumption_count',
#  'image_trial_consumption_count_more_avg',
#  'image_trial_consumption_max',
#  'image_trial_consumption_median',
#  'image_trial_consumption_min',
#  'image_trial_consumption_std',
#  'image_trial_consumption_sum',
#  'income',
#  'interests',
#  'is_corporate_email',
#  'is_robot',
#  'is_see_in_metriks',
#  'is_yandex_email',
#  'marketplace_trial_consumption_avg',
#  'marketplace_trial_consumption_count',
#  'marketplace_trial_consumption_count_more_avg',
#  'marketplace_trial_consumption_max',
#  'marketplace_trial_consumption_median',
#  'marketplace_trial_consumption_min',
#  'marketplace_trial_consumption_std',
#  'marketplace_trial_consumption_sum',
#  'mdb_trial_consumption_avg',
#  'mdb_trial_consumption_count',
#  'mdb_trial_consumption_count_more_avg',
#  'mdb_trial_consumption_max',
#  'mdb_trial_consumption_median',
#  'mdb_trial_consumption_min',
#  'mdb_trial_consumption_std',
#  'mdb_trial_consumption_sum',
#  'mobile_phone_vendor',
#  'nbs_trial_consumption_avg',
#  'nbs_trial_consumption_count',
#  'nbs_trial_consumption_count_more_avg',
#  'nbs_trial_consumption_max',
#  'nbs_trial_consumption_median',
#  'nbs_trial_consumption_min',
#  'nbs_trial_consumption_std',
#  'nbs_trial_consumption_sum',
#  'network_trial_consumption_avg',
#  'network_trial_consumption_count',
#  'network_trial_consumption_count_more_avg',
#  'network_trial_consumption_max',
#  'network_trial_consumption_median',
#  'network_trial_consumption_min',
#  'network_trial_consumption_std',
#  'network_trial_consumption_sum',
#  'nlb_trial_consumption_avg',
#  'nlb_trial_consumption_count',
#  'nlb_trial_consumption_count_more_avg',
#  'nlb_trial_consumption_max',
#  'nlb_trial_consumption_median',
#  'nlb_trial_consumption_min',
#  'nlb_trial_consumption_std',
#  'nlb_trial_consumption_sum',
#  'os',
#  'promocode_source',
#  'resolution_height',
#  'resolution_width',
#  'search_phrase',
#  'segment',
#  'session_start_time',
#  'sex',
#  'size_cat',
#  'snapshot_trial_consumption_avg',
#  'snapshot_trial_consumption_count',
#  'snapshot_trial_consumption_count_more_avg',
#  'snapshot_trial_consumption_max',
#  'snapshot_trial_consumption_median',
#  'snapshot_trial_consumption_min',
#  'snapshot_trial_consumption_std',
#  'snapshot_trial_consumption_sum',
#  'storage_trial_consumption_avg',
#  'storage_trial_consumption_count',
#  'storage_trial_consumption_count_more_avg',
#  'storage_trial_consumption_max',
#  'storage_trial_consumption_median',
#  'storage_trial_consumption_min',
#  'storage_trial_consumption_std',
#  'storage_trial_consumption_sum',
#  'tfidf_/_/tools/startrek/setalpharequest',
#  'tfidf_/api/alpharequest',
#  'tfidf_/api/billing/activategrant',
#  'tfidf_/api/billing/bindpaymentcard',
#  'tfidf_/api/billing/createaccount',
#  'tfidf_/api/billing/makecardpayment',
#  'tfidf_/api/billing/makeinvoicepayment',
#  'tfidf_/api/billing/setpaidaccount',
#  'tfidf_/api/clickhouse/createcluster',
#  'tfidf_/api/clickhouse/deletecluster',
#  'tfidf_/api/compute/addlistener',
#  'tfidf_/api/compute/createaddress',
#  'tfidf_/api/compute/createbalancer',
#  'tfidf_/api/compute/createdefaultnetwork',
#  'tfidf_/api/compute/createdisk',
#  'tfidf_/api/compute/createimage',
#  'tfidf_/api/compute/createinstance',
#  'tfidf_/api/compute/createnetwork',
#  'tfidf_/api/compute/createsnapshot',
#  'tfidf_/api/compute/createsubnet',
#  ...]

# %%
cluster = 'hahn'
alias = "*ch_public"
token = '%s' % (yt_creds['value']['token'])

query = '''
SELECT
    DISTINCT
    billing_account_id,
    puid
FROM "//home/cloud_analytics_test/cubes/acquisition_cube/cube"
WHERE 
    event = 'ba_created'
    AND puid != ''
'''

columns = ['billing_account_id', 'puid']
puids = chyt_execute_query(query=query, cluster=cluster, alias=alias, token=token, columns = columns)

# %%
features = cluster_yt.read('//home/cloud_analytics/scoring/learning_dataset').as_dataframe()
targets = cluster_yt.read('//home/cloud_analytics/scoring/targets').as_dataframe()

train_data = pd.merge(
    targets[targets['dataset_type'] == 'learning_set'][['puid', 'first_trial_consumption_datetime', 'start_paid_consumption']],
    features,
    on = 'puid',
    how = 'left'
).fillna('0')

to_predict = pd.merge(
    targets[targets['dataset_type'] != 'learning_set'][['puid', 'first_trial_consumption_datetime', 'start_paid_consumption']],
    features,
    on = 'puid',
    how = 'left'
).fillna('0')

train_data = shuffle(train_data).reset_index(drop=True)

# %%
X_train, X_test, y_train, y_test = train_test_split( train_data, train_data['start_paid_consumption'], test_size=0.33)
X_train, X_eval, y_train, y_eval = train_test_split( X_train, y_train, test_size=0.25)
positive = X_train[y_train == 1]
res = pd.DataFrame()
for i in range(3):
    X_train = pd.concat(
        [
            X_train,
            positive
        ]
    )
    y_train = pd.concat(
        [
            y_train,
            pd.Series([1]*positive.shape[0])
        ]
    )
    
cat_col = [
    'ba_payment_type',
    'ba_usage_status',
    'ba_state',
    'device_type',
    'ba_person_type',
    'age',
    'ba_payment_cycle_type',
    'ba_type',
    'channel',
    'country',
    'os',
    'promocode_source',
    'segment',
    'sex',
    'first_trial_consumption_datetime',
    'session_start_time',
    'search_phrase',
    'start_paid_consumption',
    'puid'
]
cat_indexes = []
for col in cat_col:
    cat_indexes.append(X_train.columns.get_loc(col))
    
ignore_col = [
'first_trial_consumption_datetime','session_start_time','search_phrase','start_paid_consumption', 'puid'
]
ignore_indexes = []
for col in ignore_col:
    ignore_indexes.append(X_train.columns.get_loc(col))

# %%
site_metrics = []
other_metrics = []
for col in X_test:
    if 'count_v' in col or 'tfidf_' in col:
        site_metrics.append(col)
    else:
        other_metrics.append(col)

features.shape[0]
site_metric_new = []
for col in site_metrics:
    temp = features[col].value_counts()[0]
    if features[col].value_counts()[0]/float(features.shape[0]) < 0.95:
        site_metric_new.append(col)

list_columns = other_metrics + site_metric_new

# %%
X_train['rand'] = np.random.rand(X_train.shape[0])
X_eval['rand'] = np.random.rand(X_eval.shape[0])
X_test['rand'] = np.random.rand(X_test.shape[0])
to_predict['rand'] = np.random.rand(to_predict.shape[0])

# %%
train_pool = catboost.Pool(X_train, y_train, cat_features = cat_indexes)
eval_pool = catboost.Pool(X_eval, y_eval, cat_features = cat_indexes)
test_pool = catboost.Pool(X_test, cat_features = cat_indexes)
predict_pool = catboost.Pool(to_predict, cat_features = cat_indexes)

# %%
learning_rate = 0.5
subsample = 0.3
bootstrap_type = 'Bernoulli'
depth = 1

# %%
model = catboost.CatBoostClassifier(
    iterations=1000,
    depth=depth,
    learning_rate=learning_rate,
    bootstrap_type = bootstrap_type,
    subsample = subsample,
    loss_function='Logloss',
    ignored_features = ignore_indexes,
    verbose=False
)
model.fit(train_pool, eval_set = eval_pool, plot = False, early_stopping_rounds = 20,use_best_model = True)

# %%
metris_dict = {
    'confusion_matrix': confusion_matrix(y_test, model.predict(test_pool)),
    'recall': recall_score(y_test, model.predict(test_pool)),
    'precision': precision_score(y_test, model.predict(test_pool)),
    'roc_auc': roc_auc_score(y_test, model.predict(test_pool))
}
print('confusion_matrix = \n%s\n' % (metris_dict['confusion_matrix']))
print('recall = %s\n' % (metris_dict['recall']))
print('precision = %s' % (metris_dict['precision']))
print('roc_auc = %s' % (metris_dict['roc_auc']))

# %%
today = str(datetime.date.today()-datetime.timedelta(days = 0))
metris_dict['date'] = today
cluster_yt.write('//home/cloud_analytics/scoring/model_quality/metrics', pd.DataFrame([metris_dict]), append=True)

# %%
pd.merge(X_test,puids,on = 'puid',how = 'left')

# %%
site_metrics = []
other_metrics = []
for col in X_test:
    if 'count_v' in col or 'tfidf_' in col:
        site_metrics.append(col)
    else:
        other_metrics.append()

# %%
research = pd.concat(
    [
        X_test.reset_index(drop=True),
        pd.DataFrame(model.predict_proba(test_pool)).rename(columns={0:'not_paid_prob', 1: 'paid_prob'})
    ],
    axis = 1
)
research['paid_consumption'] = y_test.reset_index(drop=True)

research = pd.merge(research,puids,on = 'puid',how = 'left')
research['prob_cat'] = research['paid_prob'].apply(lambda x: str(int(x*10)*10) + '% - ' + str(int(x*10 + 1)*10) + '%' )

if len(research.columns[research.isna().any()].tolist()) == 0:
    research['model_date'] = today
    cluster_yt.write('//home/cloud_analytics/scoring/model_quality/test_dataset/%s' % (today), research[['model_date', 'billing_account_id', 'paid_consumption', 'paid_prob', 'prob_cat']+list_columns])

# %%
predict_research = pd.concat(
    [
        to_predict.reset_index(drop=True),
        pd.DataFrame(model.predict_proba(predict_pool)).rename(columns={0:'not_paid_prob', 1: 'paid_prob'})
    ],
    axis = 1
)
predict_research = pd.merge(predict_research,puids,on = 'puid',how = 'left')
predict_research['prob_cat'] = predict_research['paid_prob'].apply(lambda x: str(int(x*10)*10) + '% - ' + str(int(x*10 + 1)*10) + '%' )

if len(predict_research.columns[predict_research.isna().any()].tolist()) == 0:
    research['model_dict'] = today
    cluster_yt.write('//home/cloud_analytics/scoring/model_quality/scored_users/%s' % (today), predict_researchresearch[['model_date', 'billing_account_id','paid_consumption', 'paid_prob', 'prob_cat']+list_columns])

# %%
predict_research['first_trial_consumption_date'] = predict_research['first_trial_consumption_datetime'].apply(lambda x: str(x).split(' ')[0])

leads = predict_research[predict_research['first_trial_consumption_date'] == str(datetime.date.today()-datetime.timedelta(days = 8))]
leads['group'] = leads['first_trial_consumption_date'].apply(lambda x: np.random.choice(['control', 'test']))
leads_test = leads[leads['group'] == 'test']
leads_control = leads[leads['group'] == 'control']

# %%
fit_alpha, fit_loc, fit_beta=stats.gamma.fit(leads_test['paid_prob'].values)
max_ = np.max(leads_test['paid_prob'].values)
leads_control['score'] = stats.gamma.rvs(fit_alpha, loc=fit_loc, scale=fit_beta, size=leads_control['paid_prob'].shape[0])
leads_control['score'] = leads_control['score']
leads_control['score'] = leads_control['score'].apply(lambda x: max_ - np.random.normal(0,0.001, 1)[0] if x > max_ else x )
leads_test['score'] = leads_test['paid_prob']
leads_control['score_cat'] = leads_control['score'].apply(lambda x: str(int(x*10)*10) + '% - ' + str(int(x*10 + 1)*10) + '%' )
leads_test['score_cat'] = leads_test['score'].apply(lambda x: str(int(x*10)*10) + '% - ' + str(int(x*10 + 1)*10) + '%' )
leads_control['prob_threshold'] =  leads_control['score'].apply(lambda x: 0 if x > threshold else 1)
leads_test['prob_threshold'] = leads_test['score'].apply(lambda x: 0 if x > threshold else 1)

leads = pd.concat(
    [
        leads_control,
        leads_test
    ]
)

# %%
columns = [
    'puid',
    'billing_account_id',
    'first_trial_consumption_date',
    'paid_prob',
    'group',
    'score',
    'score_cat',
    'prob_threshold',
    'prob_cat'
]
leads['model_dict'] = today
cluster_yt.write('//home/cloud_analytics/scoring/leads/%s' % (today), leads[columns])
